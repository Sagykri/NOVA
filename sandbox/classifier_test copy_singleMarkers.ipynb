# %%
import os
import sys
import numpy as np
from sklearn.decomposition import PCA

from umap import UMAP
sys.path.insert(1, os.getenv("MOMAPS_HOME"))
from src.common.lib.utils import load_config_file
from src.datasets.dataset_spd import DatasetSPD
from src.common.lib.embeddings_utils import load_embeddings
import src.common.lib.synthetic_multiplexing as synthetic_multiplexing

from matplotlib import cm
import matplotlib.pyplot as plt

from sklearn.metrics import precision_recall_curve, average_precision_score, roc_curve, auc, RocCurveDisplay, \
    balanced_accuracy_score, roc_auc_score, classification_report, confusion_matrix, multilabel_confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
import matplotlib
from collections import defaultdict, Counter

from sklearn.preprocessing import label_binarize

from sklearn.base import clone

# %matplotlib inline
# %load_ext autoreload 
# %autoreload 2
# Out:
# /home/labs/hornsteinlab/Collaboration/MOmaps/anaconda3/momaps_torch/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/labs/hornsteinlab/Collaboration/MOmaps/anaconda3/momaps_torch/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/labs/hornsteinlab/Collaboration/MOmaps/anaconda3/momaps_torch/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /home/labs/hornsteinlab/Collaboration/MOmaps/anaconda3/momaps_torch/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# MOMAPS_HOME: /home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps

# %% [markdown]
# # utils

# %%
def fit_and_plot_multiclass_cv_auc_roc_curves(estimator, cv_k_fold, X, y, n_classes,
                                              class_names, colors, sample_weight=None, title="", minimal_legend=False):
    """
    For every class, plot a curve per fold.
    A total of (n_classes * n_folds) AUC ROC curves are presented in the plot
    :param estimator:
    :param cv_k_fold:
    :param X:
    :param y:
    :param n_classes:
    :param title:
    :return:
    """

    tprs, aucs = [], []
    mean_fpr = np.linspace(0, 1, 100)
    _tpr, _fpr, _roc_auc = dict(), dict(), dict()
    _roc_auc2 = defaultdict(list)
    fig, ax = plt.subplots(figsize=(5, 5))
    

    for i, (train_fold, test_fold) in enumerate(cv_k_fold.split(X, y)):
        estimator_copy = clone(estimator)
        # -------- -------- -------- -------- -------- --------
        # Train a model on the train set
        estimator_copy.fit(X[train_fold], y[train_fold])
        # Get the true labels (classes)
        # Binarize labels in a one-vs-all fashion
        y_true = label_binarize(y[test_fold], classes=class_names)
        # -------- -------- -------- -------- -------- --------
        # Validate on test set
        y_proba = estimator_copy.predict_proba(X[test_fold])
        # -------- -------- -------- -------- -------- --------
        # For every class, plot a curve per fold (n_class * n_folds)
        for j, class_color, class_name in zip(range(n_classes), colors, class_names):

            # calculate AUC ROC - generate TPR and FPR curves
            _fpr[j], _tpr[j], _ = roc_curve(y_true[:, j],
                                          y_proba[:, j],
                                          #sample_weight=sample_weight,
                                          drop_intermediate=True)

            _roc_auc[j] = auc(_fpr[j], _tpr[j])
            _roc_auc2[class_name].append(_roc_auc[j])

            viz = RocCurveDisplay(fpr=_fpr[j], tpr=_tpr[j], roc_auc=_roc_auc[j], estimator_name=class_name)
            # Set a legend for each fold and each class
            viz.plot(ax=ax, name=class_name + ' fold {}'.format(i + 1), alpha=0.8, lw=1.8, linestyle=':',
                         color=class_color)

            interp_tpr = np.interp(mean_fpr, viz.fpr, viz.tpr)
            interp_tpr[0] = 0.0
            tprs.append(interp_tpr)
            aucs.append(viz.roc_auc)
        # -------- -------- -------- -------- -------- --------

    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='dimgray', label='Chance', alpha=.5)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    ax.plot(mean_fpr, mean_tpr, color='black',
            label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
            lw=2, alpha=1.0)

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    ax.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                    label=r'$\pm$ 1 std. dev.')

    ax.set(xlim=[-0.01, 1.05], ylim=[-0.01, 1.05])

    plt.title(title, color='black', fontsize=20)
    plt.xlabel('False Positive Rate (%)', fontsize=20, color='black')
    plt.ylabel('True Positive Rate (%)', fontsize=20, color='black')

    ax.legend(loc="lower right", prop={"size": 14}, bbox_to_anchor=(1.5, 1.5))

    plt.show()
    # plt.savefig(os.path.join(MAIN_FOLDER, 'figures', 'multiclass', 'AUC_ROC_per_class_training.png'), bbox_inches='tight',
    #             dpi=1200)
    plt.close()
    return np.asarray(aucs)

def plot_conf_matrix(clf, X_test, y_test, normalize='true'):
    from sklearn.metrics import ConfusionMatrixDisplay, multilabel_confusion_matrix, confusion_matrix

    unique_labels = np.unique(clf.classes_)
    print(unique_labels)

    predictions = clf.predict(X_test)
    conf_matrix = confusion_matrix(y_true=y_test, y_pred=predictions, labels=unique_labels, normalize=normalize)

    import seaborn as sns

    if normalize is None:
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
    else:
        sns.heatmap(conf_matrix, annot=True, fmt='.2%', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
    plt.show()

def validate_classifier(model, X, y, default_model_scorer, class_names, colors, sample_weight=None, title='', show_plot=False):
    """
    Perform full evaluation for a multi-class classifier on a given X and y

    :param model: sklearn Estimator (classifier)
    :param X: features matrix in a numpy matrix
    :param y: true labels in a numpy array (multi-class)
    :param default_model_scorer: string, sklearn.metric
    :param class_names: list of strings
    :param sample_weight: list of real numbers
    :param title: text
    :param show_plot: Boolean
    :return:

    """

    print("Validating - " + str(title) + "\n\n------------------")

    # -------- -------- -------- -------- -------- --------
    # Infer the probabilities for every class
    y_pred_prob = model.predict_proba(X)

    # Infer binary label to be used in classification_report()
    # by default, samples are classified to whichever class has the greatest probability (max)
    # y_pred_label = np.argmax(y_pred_prob, axis=1)  # nancy test
    y_pred = model.predict(X)
    # -------- -------- -------- -------- -------- --------

    print("\nBalanced accuracy score: " + str(balanced_accuracy_score(y_true=y, y_pred=y_pred, #sample_weight=sample_weight,
                            adjusted=False)) + ". \nBalanced accuracy score (adjusted): " + str(balanced_accuracy_score(y_true=y,
                                                                                                                        y_pred=y_pred,
                                                                                                                        #sample_weight=sample_weight,
                            adjusted=True)))
    # -------- -------- -------- -------- -------- --------
    macro_roc_auc_ovo = roc_auc_score(y, y_pred_prob, multi_class="ovo",
                                      average="macro")
    weighted_roc_auc_ovo = roc_auc_score(y, y_pred_prob, multi_class="ovo",
                                         average="weighted")

    macro_roc_auc_ovr = roc_auc_score(y, y_pred_prob, multi_class="ovr",
                                      average="macro" #, sample_weight=sample_weight
                                      )
    weighted_roc_auc_ovr = roc_auc_score(y, y_pred_prob, multi_class="ovr",
                                         average="weighted" #, sample_weight=sample_weight
    )
    print("\n\nOne-vs-One ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
          "(weighted by prevalence)"
          .format(macro_roc_auc_ovo, weighted_roc_auc_ovo))
    print("\n\nOne-vs-Rest ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
          "(weighted by prevalence)"
          .format(macro_roc_auc_ovr, weighted_roc_auc_ovr))
    # -------- -------- -------- -------- -------- --------
    # ROC AUC curves for each class (one-vs-rest)
    _roc_auc_scores = plot_multiclass_area_under_curves(y_true=y, y_proba=y_pred_prob, n_classes=len(class_names),
                                                        class_names=class_names, colors=colors)#, sample_weight=sample_weight)

    print("\nHELDOUT SET - AUC ROC scores of each class: " + str(_roc_auc_scores))
    # -------- -------- -------- -------- -------- --------
    print("'nHELDOUT SET - Classification Report: \n" + str(
        classification_report(y_true=y, y_pred=y_pred, target_names=class_names)))#, sample_weight=sample_weight)))
    # -------- -------- -------- -------- -------- --------
    print("HELDOUT SET - Multilabel Confusion Matrix: \n" + str(
        multilabel_confusion_matrix(y_true=y, y_pred=y_pred, labels=class_names)))#, sample_weight=sample_weight)))
    # -------- -------- -------- -------- -------- --------
    matplotlib.rcParams.update({'font.size': 8})
    plot_conf_matrix(model, X, y)
    # fig = plt.figure(figsize=(4, 4))
    # conf_mat = multilabel_confusion_matrix(y, y_pred)
    # ConfusionMatrixDisplay(conf_mat, display_labels=class_names)
    # plt.title('Confusion matrix "one vs. rest"', fontsize=20, color='black')
    # plt.show(block=True)
    # plt.savefig(os.path.join(MAIN_FOLDER, 'figures', 'multiclass', 'ovr_confusion_matrix_all_classes_heldout.png'),bbox_inches='tight',dpi=1200)
    plt.close()
    # -------- -------- -------- -------- -------- --------
    cnf_matrix = confusion_matrix(y_true=y, y_pred=y_pred, #sample_weight=sample_weight,
                                  labels=class_names)
    print("\nHELDOUT SET - One-vs-rest Confusion Matrix:\n" + str(cnf_matrix))

    FP = cnf_matrix.sum(axis=0) - np.diag(cnf_matrix)
    FN = cnf_matrix.sum(axis=1) - np.diag(cnf_matrix)
    TP = np.diag(cnf_matrix)
    TN = cnf_matrix.sum() - (FP + FN + TP)

    FP = FP.astype(float)
    FN = FN.astype(float)
    TP = TP.astype(float)
    TN = TN.astype(float)

    TPR = TP / (TP + FN)
    print("Sensitivity, hit rate, recall, or true positive rate: " + str(TPR))

    TNR = TN / (TN + FP)
    print("Specificity or true negative rate: " + str(TNR))

    PPV = TP / (TP + FP)
    print("Precision or positive predictive value: " + str(PPV))

    NPV = TN / (TN + FN)
    print("Negative predictive value: " + str(NPV))

    FPR = FP / (FP + TN)
    print("Fall out or false positive rate: " + str(FPR))

    FNR = FN / (TP + FN)
    print("False negative rate: " + str(FNR))

    FDR = FP / (TP + FP)
    print("False discovery rate: " + str(FDR))

    ACC = (TP + TN) / (TP + FP + FN + TN)
    print("Overall accuracy: " + str(ACC))

    # -------- -------- -------- -------- -------- --------
    test_score = model.score(X, y)#, sample_weight=sample_weight)

    print(
        "Performance score " + str(default_model_scorer) + " on the held-out test-set (25%): " + str(test_score))

    return test_score




def plot_multiclass_area_under_curves(y_true, y_proba, n_classes, class_names, colors):#, sample_weight):
    """
    Study the output of a multi-class classifier.
    One curve can be drawn per class/label and consider precision-recall and roc curves for each class.

    Note: it is necessary to binarize y_true, and y_proba should be class probabilities (using "predict_proba()").

    :param y_true: numpy
    :param y_proba: numpy
    :param n_classes: int

    :return: roc_auc
    """

    # Binarize labels in a one-vs-all fashion
    y = label_binarize(y_true, classes=class_names)

    # ROC curve
    tpr, fpr = dict(), dict()

    # ROC score
    roc_auc = dict()

    # precision recall curve
    precision = dict()
    recall = dict()
    # precision score
    precision_score = dict()

    # colors = cycle(['deepskyblue', 'orangered', 'seagreen'])
    fig = plt.figure(figsize=(5, 5))

    for i in range(n_classes):
        # calculate AUC ROC - generate TPR and FPR curves
        fpr[i], tpr[i], _ = roc_curve(y[:, i], y_proba[:, i])#, sample_weight=sample_weight)
        roc_auc[i] = auc(fpr[i], tpr[i])
        # calculate precision-recall
        precision[i], recall[i], _ = precision_recall_curve(y_true=y[:, i], probas_pred=y_proba[:, i])#,sample_weight=sample_weight)
        precision_score[i] = average_precision_score(y_true=y[:, i], y_score=y_proba[:, i], average="weighted")

    # ----------------------------------------------------------------
    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y.ravel(), y_proba.ravel())#, sample_weight=sample_weight)
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # ----------------------------------------------------------------
    # aggregate all false positive rates
    all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

    # interpolate all ROC curves at this points
    mean_tpr = np.zeros_like(all_fpr)
    for i in range(n_classes):
        mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

    # average it and compute AUC
    mean_tpr /= n_classes

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

    # ----------------------------------------------------------------
    # Draw ROC curves for all classes
    for i, color, name in zip(range(n_classes), colors, class_names):
        plt.plot(fpr[i], tpr[i], color=color, lw=1.4,
                 label='{0} (AUC = {1:0.2f})'
                       ''.format(name, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlim([-0.05, 1.0])
    plt.ylim([0.0, 1.05])
    ax = fig.gca()
    ax.tick_params(axis='both', which='major', labelsize=14)
    plt.xlabel('False Positive Rate', fontsize=20)
    plt.ylabel('True Positive Rate', fontsize=20)
    plt.title("ROC multi-class prediction in held-out data", fontsize=20, color='black')
    plt.legend(loc="best", prop={'size': 14})
    plt.show(block=True)
    # plt.savefig(os.path.join(MAIN_FOLDER, 'figures', 'multiclass', 'AUC_ROC_per_class_heldout.png'), bbox_inches='tight', dpi=1200)
    plt.close()

    # ----------------------------------------------------------------
    # Draw Precision-Recall curves
    fig = plt.figure(figsize=(5, 5))
    for i, color, name in zip(range(n_classes), colors, class_names):
        plt.plot(recall[i], precision[i], color=color, lw=1.4, label=' {0} (weighted avg. precision = {1:0.2f})'
                                                                     ''.format(name, precision_score[i]))

    ax = fig.gca()
    ax.tick_params(axis='both', which='major', labelsize=14)
    plt.xlabel("Recall", fontsize=20)
    plt.ylabel("Precision", fontsize=20)

    plt.legend(loc="best", prop={'size': 14})
    plt.suptitle("Precision-Recall curves in held-out data", fontsize=20, color='black')
    plt.show(block=True)
    # plt.savefig(os.path.join(MAIN_FOLDER, 'figures', 'multiclass', 'precision_recall_curves_per_class_heldout.png'), bbox_inches='tight',
    #             dpi=1200)
    plt.close()

    # ----------------------------------------------------------------
    # Plot all ROC curves (EXTENDED PLOT..)
    # ----------------------------------------------------------------
    fig = plt.figure(figsize=(5, 5))

    plt.plot(fpr["micro"], tpr["micro"],
             label='micro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["micro"]),
             color='deeppink', linestyle=':', linewidth=1.4)

    plt.plot(fpr["macro"], tpr["macro"],
             label='macro-average ROC curve (area = {0:0.2f})'
                   ''.format(roc_auc["macro"]),
             color='navy', linestyle=':', linewidth=1.4)

    for i, color, name in zip(range(n_classes), colors, class_names):
        plt.plot(fpr[i], tpr[i], color=color, lw=1.4,
                 label='ROC curve of class {0} (area = {1:0.2f})'
                       ''.format(name, roc_auc[i]))

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])

    ax1 = fig.gca()
    ax1.tick_params(axis='both', which='major', labelsize=14)

    plt.xlabel('False Positive Rate', fontsize=20)
    plt.ylabel('True Positive Rate', fontsize=20)
    plt.title("ROC multi-class prediction in held-out data", fontsize=20, color='black')
    plt.legend(loc="best", prop={'size': 14})

    plt.show(block=True)
    # plt.savefig(os.path.join(MAIN_FOLDER, 'figures', 'multiclass', 'extension_AUC_ROC_per_class_heldout.png'), bbox_inches='tight',
    #             dpi=1200)
    plt.close()

    return roc_auc

def val_classifier(clf, X, y, unique_labels):
    validate_classifier(clf, X, y, 'roc_auc_ovr_weighted',
                        unique_labels, sample_weight=None, colors=plt.cm.get_cmap('Set1', len(unique_labels)).colors,
                        title='Validate classifier', show_plot=True)

def fit_eval(clf, X, y, cv=5, random_state=1):
    from sklearn.model_selection import train_test_split, StratifiedKFold
    
    clf_clone = clone(clf)
    
    y = y.reshape(-1,)

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, stratify=y, random_state=random_state, shuffle=True)
    print(f"X_train shape {X_train.shape}, X_test shape: {X_test.shape}, y_train shape: {y_train.shape}, y_test shape: {y_test.shape}")
    
    unique_labels = np.unique(y)

    skf = StratifiedKFold(n_splits=cv, random_state=random_state, shuffle=True)
    result = fit_and_plot_multiclass_cv_auc_roc_curves(clf_clone, skf, X_train, y_train,
                                                        n_classes=len(unique_labels),
                                                        class_names=unique_labels,
                                                        colors=plt.cm.get_cmap('Set1', len(unique_labels)).colors,
                                                        title='ROC multi-class one-vs-rest in training')

    print("\n\nTraining dataset (80%): K-Fold Cross Validation score: " + str(model_scorer) + " " + str(
        result) + " Mean: " + str(result.mean()))
    

    clf_clone = clone(clf)
    clf_clone = clf_clone.fit(X_train, y_train)
    val_classifier(clf_clone, X_test, y_test, unique_labels)

# %% [markdown]
# # Configs

# %%
config_path_model = "./src/models/neuroself/configs/model_config/TLNeuroselfB78NoDSModelConfig"
config_path_data = "./src/datasets/configs/embeddings_data_config/EmbeddingsB9VQ1DatasetConfig"

# %%
model_scorer = 'roc_auc_ovr_weighted'

# %% [markdown]
# # Load data

# %%
config_model = load_config_file(config_path_model, 'model')
config_data = load_config_file(config_path_data, 'data', config_model.CONFIGS_USED_FOLDER)
# Out:
# 2023-09-03 17:43:34 INFO [TLNeuroselfB78NoDSModelConfig] Init (log path: /home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/outputs/models_outputs_batch78_nods_tl_ep23/logs/030923_174334_085968.log)
# 2023-09-03 17:43:34 INFO [TLNeuroselfB78NoDSModelConfig] MOMAPS_HOME=/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps, MOMAPS_DATA_HOME=/home/labs/hornsteinlab/Collaboration/MOmaps/input

# %%
config_data.SAMPLE_PCT
# Out:
# 1

# %%
config_data.INPUT_FOLDERS
# Out:
# ['/home/labs/hornsteinlab/Collaboration/MOmaps/input/images/processed/spd2/SpinningDisk/batch9_16bit_no_downsample']

# %%
config_data.EMBEDDINGS_LAYER
# Out:
# 'vqvec1'

# %%
embeddings, labels = load_embeddings(embeddings_type='all', config_model=config_model, config_data=config_data)
# Out:
# 2023-09-03 17:43:34 INFO [load_embeddings] Model: preloaded                    Dataset: preloaded,                        embeddings_type: all
# 2023-09-03 17:43:34 INFO [load_embeddings] experiment_type = neurons
# 2023-09-03 17:43:34 INFO [load_embeddings] embeddings_layer = vqvec1
# 2023-09-03 17:43:34 INFO Input folder: /home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/outputs/models_outputs_batch78_nods_tl_ep23/embeddings/neurons/vqvec1/batch9_16bit_no_downsample, depth used: 4
# 2023-09-03 17:43:34 INFO Running in parallel: 52 processes
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_FUS of shape (270, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_CLTC of shape (379, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TOMM20 of shape (468, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_KIF5A of shape (415, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_CLTC of shape (578, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NCL of shape (548, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PURA of shape (561, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_GM130 of shape (468, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_Calreticulin of shape (597, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_FMRP of shape (516, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_ANXA11 of shape (527, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_SQSTM1 of shape (516, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_Phalloidin of shape (558, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_mitotracker of shape (613, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PML of shape (613, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NEMO of shape (632, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_CLTC of shape (726, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_G3BP1 of shape (747, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_Phalloidin of shape (755, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PSD95 of shape (754, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PEX14 of shape (700, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TDP43 of shape (631, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_FMRP of shape (688, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_FMRP of shape (755, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_KIF5A of shape (695, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_Calreticulin of shape (776, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_Phalloidin of shape (751, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_KIF5A of shape (786, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_FUS of shape (775, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_ANXA11 of shape (862, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_Calreticulin of shape (900, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_G3BP1 of shape (415, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_TDP43 of shape (918, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_Phalloidin of shape (888, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NEMO of shape (957, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_DCP1A of shape (969, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PML of shape (925, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_mitotracker of shape (974, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_KIF5A of shape (859, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_TDP43 of shape (882, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_mitotracker of shape (995, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PML of shape (974, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_CD41 of shape (1003, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_Calreticulin of shape (579, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_Calreticulin of shape (476, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_LAMP1 of shape (597, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PML of shape (995, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NEMO of shape (1008, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NONO of shape (1003, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TDP43 of shape (1021, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_LAMP1 of shape (1013, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NEMO of shape (538, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NEMO of shape (1206, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_FUS of shape (1087, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_SCNA of shape (893, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_mitotracker of shape (700, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TIA1 of shape (937, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_ANXA11 of shape (1178, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_FUS of shape (548, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_Phalloidin of shape (516, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_SCNA of shape (527, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PSD95 of shape (432, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_KIF5A of shape (561, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_ANXA11 of shape (672, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_FUS of shape (358, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_CD41 of shape (631, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NONO of shape (631, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TDP43 of shape (682, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_DCP1A of shape (632, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TIA1 of shape (453, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_GM130 of shape (647, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NCL of shape (270, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PURA of shape (747, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_FUS of shape (638, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PSD95 of shape (726, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_G3BP1 of shape (786, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_ANXA11 of shape (429, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_Calreticulin of shape (832, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PML of shape (700, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_CD41 of shape (918, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_DCP1A of shape (528, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_DCP1A of shape (538, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NONO of shape (882, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_LAMP1 of shape (832, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_GM130 of shape (980, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_SCNA of shape (929, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_LAMP1 of shape (776, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_ANXA11 of shape (929, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_SCNA of shape (862, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_TIA1 of shape (797, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PURA of shape (415, 64, 25, 25)
# 2023-09-03 17:43:35 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_TIA1 of shape (739, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_LAMP1 of shape (900, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_DCP1A of shape (1008, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_FMRP of shape (1059, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_CLTC of shape (754, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_DCP1A of shape (1206, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_G3BP1 of shape (561, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_CLTC of shape (432, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_SCNA of shape (1178, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_LAMP1 of shape (476, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_G3BP1 of shape (459, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_NONO of shape (682, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TIA1 of shape (425, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_SQSTM1 of shape (558, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PSD95 of shape (865, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NONO of shape (918, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_SCNA of shape (672, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PSD95 of shape (1004, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NCL of shape (797, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_G3BP1 of shape (859, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_FMRP of shape (558, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_ANXA11 of shape (893, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PEX14 of shape (613, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_CD41 of shape (682, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NONO of shape (1021, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_TOMM20 of shape (647, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_CD41 of shape (1021, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PEX14 of shape (966, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TOMM20 of shape (980, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_SQSTM1 of shape (1059, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_CD41 of shape (559, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PURA of shape (695, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TIA1 of shape (1098, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_G3BP1 of shape (695, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHeterozygous_Untreated_PSD95 of shape (578, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NCL of shape (638, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_GM130 of shape (784, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_CLTC of shape (865, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_SQSTM1 of shape (751, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PEX14 of shape (925, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_KIF5A of shape (747, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_DCP1A of shape (957, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_NCL of shape (775, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_Phalloidin of shape (1059, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_TOMM20 of shape (784, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_SQSTM1 of shape (755, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_FUS of shape (797, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_FMRP of shape (751, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_CD41 of shape (882, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_FMRP of shape (888, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_mitotracker of shape (925, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_SQSTM1 of shape (888, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PURA of shape (786, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PURA of shape (859, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NCL of shape (1087, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_Calreticulin of shape (1013, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_GM130 of shape (880, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_CLTC of shape (1004, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PEX14 of shape (974, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_PML of shape (966, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_mitotracker of shape (966, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_NEMO of shape (969, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSRevertant_Untreated_PEX14 of shape (995, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TOMM20 of shape (880, 64, 25, 25)
# 2023-09-03 17:43:36 INFO [_load_stored_embeddings] Loading stored embeddings of label FUSHomozygous_Untreated_TDP43 of shape (1003, 64, 25, 25)
# 2023-09-03 17:43:37 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_GM130 of shape (558, 64, 25, 25)
# 2023-09-03 17:43:37 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_KIF5A of shape (459, 64, 25, 25)
# 2023-09-03 17:43:37 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_LAMP1 of shape (579, 64, 25, 25)
# 2023-09-03 17:43:37 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NCL of shape (358, 64, 25, 25)
# 2023-09-03 17:43:37 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NEMO of shape (528, 64, 25, 25)
# 2023-09-03 17:43:38 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NONO of shape (559, 64, 25, 25)
# 2023-09-03 17:43:38 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PEX14 of shape (560, 64, 25, 25)
# 2023-09-03 17:43:38 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PML of shape (560, 64, 25, 25)
# 2023-09-03 17:43:38 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PSD95 of shape (379, 64, 25, 25)
# 2023-09-03 17:43:38 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PURA of shape (459, 64, 25, 25)
# 2023-09-03 17:43:39 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_Phalloidin of shape (688, 64, 25, 25)
# 2023-09-03 17:43:39 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_SCNA of shape (429, 64, 25, 25)
# 2023-09-03 17:43:39 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_SQSTM1 of shape (688, 64, 25, 25)
# 2023-09-03 17:43:39 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TDP43 of shape (559, 64, 25, 25)
# 2023-09-03 17:43:39 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TIA1 of shape (394, 64, 25, 25)
# 2023-09-03 17:43:40 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TOMM20 of shape (558, 64, 25, 25)
# 2023-09-03 17:43:40 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_mitotracker of shape (560, 64, 25, 25)
# 2023-09-03 17:43:40 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_ANXA11 of shape (717, 64, 25, 25)
# 2023-09-03 17:43:40 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_CD41 of shape (677, 64, 25, 25)
# 2023-09-03 17:43:41 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_CLTC of shape (577, 64, 25, 25)
# 2023-09-03 17:43:41 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_Calreticulin of shape (470, 64, 25, 25)
# 2023-09-03 17:43:41 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_FMRP of shape (525, 64, 25, 25)
# 2023-09-03 17:43:41 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_DCP1A of shape (589, 64, 25, 25)
# 2023-09-03 17:43:41 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_FUS of shape (490, 64, 25, 25)
# 2023-09-03 17:43:42 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_G3BP1 of shape (458, 64, 25, 25)
# 2023-09-03 17:43:42 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_GM130 of shape (416, 64, 25, 25)
# 2023-09-03 17:43:42 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_KIF5A of shape (458, 64, 25, 25)
# 2023-09-03 17:43:42 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_LAMP1 of shape (470, 64, 25, 25)
# 2023-09-03 17:43:42 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NCL of shape (490, 64, 25, 25)
# 2023-09-03 17:43:43 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NEMO of shape (589, 64, 25, 25)
# 2023-09-03 17:43:43 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_NONO of shape (677, 64, 25, 25)
# 2023-09-03 17:43:43 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PEX14 of shape (510, 64, 25, 25)
# 2023-09-03 17:43:43 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PML of shape (510, 64, 25, 25)
# 2023-09-03 17:43:44 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PSD95 of shape (577, 64, 25, 25)
# 2023-09-03 17:43:44 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_PURA of shape (458, 64, 25, 25)
# 2023-09-03 17:43:44 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_Phalloidin of shape (525, 64, 25, 25)
# 2023-09-03 17:43:44 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_SCNA of shape (717, 64, 25, 25)
# 2023-09-03 17:43:45 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_SQSTM1 of shape (525, 64, 25, 25)
# 2023-09-03 17:43:45 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TDP43 of shape (677, 64, 25, 25)
# 2023-09-03 17:43:45 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TOMM20 of shape (416, 64, 25, 25)
# 2023-09-03 17:43:45 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_TIA1 of shape (491, 64, 25, 25)
# 2023-09-03 17:43:45 INFO [_load_stored_embeddings] Loading stored embeddings of label OPTN_Untreated_mitotracker of shape (510, 64, 25, 25)
# 2023-09-03 17:43:46 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_ANXA11 of shape (359, 64, 25, 25)
# 2023-09-03 17:43:46 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_CD41 of shape (673, 64, 25, 25)
# 2023-09-03 17:43:46 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_CLTC of shape (470, 64, 25, 25)
# 2023-09-03 17:43:47 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_Calreticulin of shape (519, 64, 25, 25)
# 2023-09-03 17:43:47 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_DCP1A of shape (537, 64, 25, 25)
# 2023-09-03 17:43:47 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_FMRP of shape (500, 64, 25, 25)
# 2023-09-03 17:43:47 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_FUS of shape (214, 64, 25, 25)
# 2023-09-03 17:43:47 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_G3BP1 of shape (510, 64, 25, 25)
# 2023-09-03 17:43:48 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_GM130 of shape (438, 64, 25, 25)
# 2023-09-03 17:43:48 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_KIF5A of shape (510, 64, 25, 25)
# 2023-09-03 17:43:48 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_LAMP1 of shape (519, 64, 25, 25)
# 2023-09-03 17:43:48 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NCL of shape (214, 64, 25, 25)
# 2023-09-03 17:43:49 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NEMO of shape (537, 64, 25, 25)
# 2023-09-03 17:43:49 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NONO of shape (673, 64, 25, 25)
# 2023-09-03 17:43:49 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PEX14 of shape (683, 64, 25, 25)
# 2023-09-03 17:43:50 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PML of shape (683, 64, 25, 25)
# 2023-09-03 17:43:50 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PSD95 of shape (470, 64, 25, 25)
# 2023-09-03 17:43:50 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PURA of shape (510, 64, 25, 25)
# 2023-09-03 17:43:50 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_Phalloidin of shape (500, 64, 25, 25)
# 2023-09-03 17:43:51 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_SCNA of shape (359, 64, 25, 25)
# 2023-09-03 17:43:51 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_SQSTM1 of shape (500, 64, 25, 25)
# 2023-09-03 17:43:51 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TDP43 of shape (673, 64, 25, 25)
# 2023-09-03 17:43:51 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TIA1 of shape (469, 64, 25, 25)
# 2023-09-03 17:43:52 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TOMM20 of shape (438, 64, 25, 25)
# 2023-09-03 17:43:52 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_mitotracker of shape (683, 64, 25, 25)
# 2023-09-03 17:43:52 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_ANXA11 of shape (450, 64, 25, 25)
# 2023-09-03 17:43:52 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_CD41 of shape (652, 64, 25, 25)
# 2023-09-03 17:43:53 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_CLTC of shape (595, 64, 25, 25)
# 2023-09-03 17:43:53 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_DCP1A of shape (481, 64, 25, 25)
# 2023-09-03 17:43:53 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_Calreticulin of shape (489, 64, 25, 25)
# 2023-09-03 17:43:54 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_FMRP of shape (593, 64, 25, 25)
# 2023-09-03 17:43:54 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_FUS of shape (464, 64, 25, 25)
# 2023-09-03 17:43:54 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_G3BP1 of shape (652, 64, 25, 25)
# 2023-09-03 17:43:55 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_GM130 of shape (446, 64, 25, 25)
# 2023-09-03 17:43:55 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_LAMP1 of shape (489, 64, 25, 25)
# 2023-09-03 17:43:55 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_KIF5A of shape (652, 64, 25, 25)
# 2023-09-03 17:43:56 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NCL of shape (464, 64, 25, 25)
# 2023-09-03 17:43:56 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NEMO of shape (481, 64, 25, 25)
# 2023-09-03 17:43:56 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_NONO of shape (652, 64, 25, 25)
# 2023-09-03 17:43:57 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PEX14 of shape (537, 64, 25, 25)
# 2023-09-03 17:43:57 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PML of shape (537, 64, 25, 25)
# 2023-09-03 17:43:57 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PSD95 of shape (595, 64, 25, 25)
# 2023-09-03 17:43:58 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_PURA of shape (652, 64, 25, 25)
# 2023-09-03 17:43:58 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_Phalloidin of shape (593, 64, 25, 25)
# 2023-09-03 17:43:58 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_SCNA of shape (450, 64, 25, 25)
# 2023-09-03 17:43:59 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_SQSTM1 of shape (593, 64, 25, 25)
# 2023-09-03 17:43:59 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TDP43 of shape (652, 64, 25, 25)
# 2023-09-03 17:44:00 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TIA1 of shape (497, 64, 25, 25)
# 2023-09-03 17:44:00 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_TOMM20 of shape (446, 64, 25, 25)
# 2023-09-03 17:44:01 INFO [_load_stored_embeddings] Loading stored embeddings of label SCNA_Untreated_mitotracker of shape (537, 64, 25, 25)
# 2023-09-03 17:44:01 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_ANXA11 of shape (857, 64, 25, 25)
# 2023-09-03 17:44:02 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_CD41 of shape (897, 64, 25, 25)
# 2023-09-03 17:44:02 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_CLTC of shape (982, 64, 25, 25)
# 2023-09-03 17:44:02 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_Calreticulin of shape (918, 64, 25, 25)
# 2023-09-03 17:44:02 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_DCP1A of shape (1034, 64, 25, 25)
# 2023-09-03 17:44:03 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_FMRP of shape (886, 64, 25, 25)
# 2023-09-03 17:44:03 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_FUS of shape (845, 64, 25, 25)
# 2023-09-03 17:44:03 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_G3BP1 of shape (965, 64, 25, 25)
# 2023-09-03 17:44:04 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_GM130 of shape (985, 64, 25, 25)
# 2023-09-03 17:44:04 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_KIF5A of shape (965, 64, 25, 25)
# 2023-09-03 17:44:04 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_LAMP1 of shape (918, 64, 25, 25)
# 2023-09-03 17:44:05 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NCL of shape (845, 64, 25, 25)
# 2023-09-03 17:44:05 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NEMO of shape (1034, 64, 25, 25)
# 2023-09-03 17:44:05 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NONO of shape (897, 64, 25, 25)
# 2023-09-03 17:44:06 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PEX14 of shape (945, 64, 25, 25)
# 2023-09-03 17:44:06 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PML of shape (945, 64, 25, 25)
# 2023-09-03 17:44:07 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PSD95 of shape (982, 64, 25, 25)
# 2023-09-03 17:44:07 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PURA of shape (965, 64, 25, 25)
# 2023-09-03 17:44:07 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_Phalloidin of shape (886, 64, 25, 25)
# 2023-09-03 17:44:08 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_SCNA of shape (857, 64, 25, 25)
# 2023-09-03 17:44:08 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_SQSTM1 of shape (886, 64, 25, 25)
# 2023-09-03 17:44:08 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TDP43 of shape (897, 64, 25, 25)
# 2023-09-03 17:44:09 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TIA1 of shape (1014, 64, 25, 25)
# 2023-09-03 17:44:09 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TOMM20 of shape (985, 64, 25, 25)
# 2023-09-03 17:44:09 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_mitotracker of shape (945, 64, 25, 25)
# 2023-09-03 17:44:10 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_ANXA11 of shape (1056, 64, 25, 25)
# 2023-09-03 17:44:10 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_CD41 of shape (895, 64, 25, 25)
# 2023-09-03 17:44:10 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_CLTC of shape (1012, 64, 25, 25)
# 2023-09-03 17:44:11 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_Calreticulin of shape (738, 64, 25, 25)
# 2023-09-03 17:44:11 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_DCP1A of shape (1030, 64, 25, 25)
# 2023-09-03 17:44:11 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_FMRP of shape (903, 64, 25, 25)
# 2023-09-03 17:44:12 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_FUS of shape (1001, 64, 25, 25)
# 2023-09-03 17:44:12 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_G3BP1 of shape (966, 64, 25, 25)
# 2023-09-03 17:44:13 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_GM130 of shape (915, 64, 25, 25)
# 2023-09-03 17:44:13 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_KIF5A of shape (966, 64, 25, 25)
# 2023-09-03 17:44:13 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_LAMP1 of shape (738, 64, 25, 25)
# 2023-09-03 17:44:14 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NCL of shape (1001, 64, 25, 25)
# 2023-09-03 17:44:14 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NEMO of shape (1030, 64, 25, 25)
# 2023-09-03 17:44:15 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_NONO of shape (895, 64, 25, 25)
# 2023-09-03 17:44:15 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PEX14 of shape (883, 64, 25, 25)
# 2023-09-03 17:44:15 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PML of shape (883, 64, 25, 25)
# 2023-09-03 17:44:16 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PSD95 of shape (1012, 64, 25, 25)
# 2023-09-03 17:44:16 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_PURA of shape (966, 64, 25, 25)
# 2023-09-03 17:44:16 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_Phalloidin of shape (903, 64, 25, 25)
# 2023-09-03 17:44:17 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_SCNA of shape (1056, 64, 25, 25)
# 2023-09-03 17:44:17 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_SQSTM1 of shape (903, 64, 25, 25)
# 2023-09-03 17:44:18 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TDP43 of shape (895, 64, 25, 25)
# 2023-09-03 17:44:18 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TIA1 of shape (738, 64, 25, 25)
# 2023-09-03 17:44:18 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_TOMM20 of shape (915, 64, 25, 25)
# 2023-09-03 17:44:19 INFO [_load_stored_embeddings] Loading stored embeddings of label TBK1_Untreated_mitotracker of shape (883, 64, 25, 25)
# 2023-09-03 17:44:19 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_ANXA11 of shape (766, 64, 25, 25)
# 2023-09-03 17:44:19 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_CD41 of shape (695, 64, 25, 25)
# 2023-09-03 17:44:20 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_CLTC of shape (556, 64, 25, 25)
# 2023-09-03 17:44:20 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_Calreticulin of shape (693, 64, 25, 25)
# 2023-09-03 17:44:20 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_DCP1A of shape (777, 64, 25, 25)
# 2023-09-03 17:44:21 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_FMRP of shape (717, 64, 25, 25)
# 2023-09-03 17:44:21 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_G3BP1 of shape (592, 64, 25, 25)
# 2023-09-03 17:44:21 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_FUS of shape (431, 64, 25, 25)
# 2023-09-03 17:44:22 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_GM130 of shape (764, 64, 25, 25)
# 2023-09-03 17:44:22 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_KIF5A of shape (592, 64, 25, 25)
# 2023-09-03 17:44:23 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_LAMP1 of shape (693, 64, 25, 25)
# 2023-09-03 17:44:23 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NCL of shape (431, 64, 25, 25)
# 2023-09-03 17:44:24 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NEMO of shape (777, 64, 25, 25)
# 2023-09-03 17:44:24 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NONO of shape (695, 64, 25, 25)
# 2023-09-03 17:44:24 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PEX14 of shape (654, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PML of shape (654, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PSD95 of shape (556, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PURA of shape (592, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_Phalloidin of shape (717, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_SCNA of shape (766, 64, 25, 25)
# 2023-09-03 17:44:25 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_SQSTM1 of shape (717, 64, 25, 25)
# 2023-09-03 17:44:26 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TDP43 of shape (695, 64, 25, 25)
# 2023-09-03 17:44:26 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TIA1 of shape (451, 64, 25, 25)
# 2023-09-03 17:44:26 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TOMM20 of shape (764, 64, 25, 25)
# 2023-09-03 17:44:26 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_mitotracker of shape (654, 64, 25, 25)
# 2023-09-03 17:44:27 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_ANXA11 of shape (789, 64, 25, 25)
# 2023-09-03 17:44:27 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_CD41 of shape (802, 64, 25, 25)
# 2023-09-03 17:44:27 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_CLTC of shape (726, 64, 25, 25)
# 2023-09-03 17:44:27 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_Calreticulin of shape (431, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_DCP1A of shape (813, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_FMRP of shape (564, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_FUS of shape (591, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_GM130 of shape (211, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_G3BP1 of shape (729, 64, 25, 25)
# 2023-09-03 17:44:28 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_KIF5A of shape (729, 64, 25, 25)
# 2023-09-03 17:44:29 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_LAMP1 of shape (431, 64, 25, 25)
# 2023-09-03 17:44:29 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NCL of shape (591, 64, 25, 25)
# 2023-09-03 17:44:29 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NEMO of shape (813, 64, 25, 25)
# 2023-09-03 17:44:29 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_NONO of shape (802, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PEX14 of shape (773, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PML of shape (773, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PSD95 of shape (726, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_PURA of shape (729, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_Phalloidin of shape (564, 64, 25, 25)
# 2023-09-03 17:44:30 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_SCNA of shape (789, 64, 25, 25)
# 2023-09-03 17:44:31 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_SQSTM1 of shape (564, 64, 25, 25)
# 2023-09-03 17:44:31 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TDP43 of shape (802, 64, 25, 25)
# 2023-09-03 17:44:31 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TIA1 of shape (660, 64, 25, 25)
# 2023-09-03 17:44:31 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_TOMM20 of shape (211, 64, 25, 25)
# 2023-09-03 17:44:32 INFO [_load_stored_embeddings] Loading stored embeddings of label TDP43_Untreated_mitotracker of shape (773, 64, 25, 25)
# 2023-09-03 17:44:32 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_ANXA11 of shape (938, 64, 25, 25)
# 2023-09-03 17:44:32 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_CD41 of shape (742, 64, 25, 25)
# 2023-09-03 17:44:32 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_CLTC of shape (583, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_Calreticulin of shape (989, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_DCP1A of shape (754, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_FUS of shape (655, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_FMRP of shape (755, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_G3BP1 of shape (716, 64, 25, 25)
# 2023-09-03 17:44:33 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_GM130 of shape (851, 64, 25, 25)
# 2023-09-03 17:44:34 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_KIF5A of shape (716, 64, 25, 25)
# 2023-09-03 17:44:34 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_LAMP1 of shape (989, 64, 25, 25)
# 2023-09-03 17:44:34 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NEMO of shape (754, 64, 25, 25)
# 2023-09-03 17:44:34 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NCL of shape (655, 64, 25, 25)
# 2023-09-03 17:44:34 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NONO of shape (742, 64, 25, 25)
# 2023-09-03 17:44:35 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PEX14 of shape (730, 64, 25, 25)
# 2023-09-03 17:44:35 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PML of shape (730, 64, 25, 25)
# 2023-09-03 17:44:35 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PSD95 of shape (583, 64, 25, 25)
# 2023-09-03 17:44:37 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PURA of shape (716, 64, 25, 25)
# 2023-09-03 17:44:37 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_mitotracker of shape (730, 64, 25, 25)
# 2023-09-03 17:44:37 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_ANXA11 of shape (996, 64, 25, 25)
# 2023-09-03 17:44:37 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_CD41 of shape (796, 64, 25, 25)
# 2023-09-03 17:44:37 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_CLTC of shape (707, 64, 25, 25)
# 2023-09-03 17:44:38 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_Calreticulin of shape (843, 64, 25, 25)
# 2023-09-03 17:44:38 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_DCP1A of shape (844, 64, 25, 25)
# 2023-09-03 17:44:38 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_FMRP of shape (718, 64, 25, 25)
# 2023-09-03 17:44:38 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_FUS of shape (794, 64, 25, 25)
# 2023-09-03 17:44:38 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_G3BP1 of shape (759, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_GM130 of shape (507, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_KIF5A of shape (759, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_LAMP1 of shape (843, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_Phalloidin of shape (755, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NCL of shape (794, 64, 25, 25)
# 2023-09-03 17:44:39 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NEMO of shape (844, 64, 25, 25)
# 2023-09-03 17:44:40 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_NONO of shape (796, 64, 25, 25)
# 2023-09-03 17:44:40 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PEX14 of shape (835, 64, 25, 25)
# 2023-09-03 17:44:40 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TDP43 of shape (742, 64, 25, 25)
# 2023-09-03 17:44:40 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PML of shape (835, 64, 25, 25)
# 2023-09-03 17:44:40 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PSD95 of shape (707, 64, 25, 25)
# 2023-09-03 17:44:41 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_PURA of shape (759, 64, 25, 25)
# 2023-09-03 17:44:41 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_Phalloidin of shape (718, 64, 25, 25)
# 2023-09-03 17:44:41 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_SCNA of shape (996, 64, 25, 25)
# 2023-09-03 17:44:41 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_SQSTM1 of shape (718, 64, 25, 25)
# 2023-09-03 17:44:41 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TDP43 of shape (796, 64, 25, 25)
# 2023-09-03 17:44:42 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TIA1 of shape (592, 64, 25, 25)
# 2023-09-03 17:44:42 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TOMM20 of shape (507, 64, 25, 25)
# 2023-09-03 17:44:42 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_mitotracker of shape (835, 64, 25, 25)
# 2023-09-03 17:44:42 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_ANXA11 of shape (819, 64, 25, 25)
# 2023-09-03 17:44:43 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_CD41 of shape (782, 64, 25, 25)
# 2023-09-03 17:44:43 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_CLTC of shape (564, 64, 25, 25)
# 2023-09-03 17:44:43 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_Calreticulin of shape (867, 64, 25, 25)
# 2023-09-03 17:44:43 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_DCP1A of shape (777, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_FMRP of shape (663, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TIA1 of shape (726, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_SCNA of shape (938, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_FUS of shape (553, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_TOMM20 of shape (851, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_G3BP1 of shape (560, 64, 25, 25)
# 2023-09-03 17:44:44 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_GM130 of shape (745, 64, 25, 25)
# 2023-09-03 17:44:45 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_KIF5A of shape (560, 64, 25, 25)
# 2023-09-03 17:44:45 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_LAMP1 of shape (867, 64, 25, 25)
# 2023-09-03 17:44:46 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NCL of shape (553, 64, 25, 25)
# 2023-09-03 17:44:46 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NEMO of shape (777, 64, 25, 25)
# 2023-09-03 17:44:46 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NONO of shape (782, 64, 25, 25)
# 2023-09-03 17:44:47 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PML of shape (465, 64, 25, 25)
# 2023-09-03 17:44:47 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_Untreated_SQSTM1 of shape (755, 64, 25, 25)
# 2023-09-03 17:44:47 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PEX14 of shape (465, 64, 25, 25)
# 2023-09-03 17:44:48 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PSD95 of shape (564, 64, 25, 25)
# 2023-09-03 17:44:48 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_Phalloidin of shape (663, 64, 25, 25)
# 2023-09-03 17:44:48 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PURA of shape (560, 64, 25, 25)
# 2023-09-03 17:44:49 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_SCNA of shape (819, 64, 25, 25)
# 2023-09-03 17:44:49 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_SQSTM1 of shape (663, 64, 25, 25)
# 2023-09-03 17:44:49 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TDP43 of shape (782, 64, 25, 25)
# 2023-09-03 17:44:50 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TIA1 of shape (689, 64, 25, 25)
# 2023-09-03 17:44:50 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TOMM20 of shape (745, 64, 25, 25)
# 2023-09-03 17:44:50 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_mitotracker of shape (465, 64, 25, 25)
# 2023-09-03 17:44:51 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_ANXA11 of shape (878, 64, 25, 25)
# 2023-09-03 17:44:51 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_CD41 of shape (822, 64, 25, 25)
# 2023-09-03 17:44:51 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_CLTC of shape (697, 64, 25, 25)
# 2023-09-03 17:44:52 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_Calreticulin of shape (833, 64, 25, 25)
# 2023-09-03 17:44:52 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_DCP1A of shape (782, 64, 25, 25)
# 2023-09-03 17:44:53 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_FMRP of shape (765, 64, 25, 25)
# 2023-09-03 17:44:53 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_FUS of shape (718, 64, 25, 25)
# 2023-09-03 17:44:54 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_GM130 of shape (153, 64, 25, 25)
# 2023-09-03 17:44:54 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_G3BP1 of shape (783, 64, 25, 25)
# 2023-09-03 17:44:55 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_KIF5A of shape (783, 64, 25, 25)
# 2023-09-03 17:44:55 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_LAMP1 of shape (833, 64, 25, 25)
# 2023-09-03 17:44:55 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NCL of shape (718, 64, 25, 25)
# 2023-09-03 17:44:56 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NEMO of shape (782, 64, 25, 25)
# 2023-09-03 17:44:56 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_NONO of shape (822, 64, 25, 25)
# 2023-09-03 17:44:56 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PEX14 of shape (676, 64, 25, 25)
# 2023-09-03 17:44:57 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PML of shape (676, 64, 25, 25)
# 2023-09-03 17:44:57 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PSD95 of shape (697, 64, 25, 25)
# 2023-09-03 17:44:57 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_PURA of shape (783, 64, 25, 25)
# 2023-09-03 17:44:58 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_Phalloidin of shape (765, 64, 25, 25)
# 2023-09-03 17:44:58 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_SCNA of shape (878, 64, 25, 25)
# 2023-09-03 17:44:59 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_SQSTM1 of shape (765, 64, 25, 25)
# 2023-09-03 17:44:59 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TDP43 of shape (822, 64, 25, 25)
# 2023-09-03 17:44:59 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TOMM20 of shape (153, 64, 25, 25)
# 2023-09-03 17:44:59 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_TIA1 of shape (238, 64, 25, 25)
# 2023-09-03 17:45:00 INFO [_load_stored_embeddings] Loading stored embeddings of label WT_stress_mitotracker of shape (676, 64, 25, 25)
# 2023-09-03 17:46:43 INFO [load_embeddings] all_embedings_data: (320151, 64, 25, 25) all_labels: (320151, 1)

# %%
embeddings_raw = embeddings.copy()

# %%
embeddings_raw.shape
# Out:
# (320151, 64, 25, 25)

# %% [markdown]
# ---

# %% [markdown]
# # Single marker

# %%
# ERROR: cannot assign slice from input of different size - Because of too many features (embeddings_marker.shape[1] is huge)...

reducer = UMAP(n_components=100, random_state=1)
reducer.fit(embeddings_marker[:,:10000])
# Out:
# UMAP(n_components=100, random_state=1, tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True})

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier

sm_dict = {}

unique_ll = np.unique(labels)
labels_npy = np.asarray(labels)
for l in unique_ll[:len(unique_ll)]:
    marker = l.split('_')[-1]
    print('---------------------')
    print(f"Marker: {marker}")
    print('---------------------')
    marker_indexes = np.where(np.char.endswith(labels_npy, f'_{marker}'))[0]
    embeddings_marker, labels_marker = embeddings[marker_indexes], labels_npy[marker_indexes]
    
    print(np.unique(labels_marker))
    print(f"[{marker}] embeddings_marker shape: {embeddings_marker.shape}, labels_marker shape: {labels_marker.shape}")
    
    print(f"[{marker}] SM")
    df = synthetic_multiplexing.__embeddings_to_df(embeddings_marker, labels_marker.reshape(-1,), dataset_conf=config_data)
    embeddings_marker, y_marker, unique_groups_marker = synthetic_multiplexing.__get_multiplexed_embeddings(df, random_state=config_data.SEED)

    print(f"[{marker}] Save to dict")
    sm_dict[marker] = {'embeddings': embeddings_marker, 'y': y_marker, 'unique_groups': unique_groups_marker}

    print(f"[{marker}] UMAP...")
    reducer = UMAP(n_components=100, random_state=1)
    
    print("embeddings_marker shape: ", embeddings_marker.shape, embeddings_marker.reshape(embeddings_marker.shape[0], -1).shape)
    print("!!!!!!!!! TAKING ONLY FIRST 10000 FEATURES since otherwise there for bigger numbers there is an error (cannot assign slice from input of different size) !!!!!!")
    X_marker = reducer.fit_transform(embeddings_marker[:,:10000])
    
    print(f"[{marker}] Print X to dict..")
    sm_dict[marker]['X'] = X_marker
    
    print(f"[{marker}] Init model")
    mlp = MLPClassifier(hidden_layer_sizes=(20,), activation='relu', random_state=1)
    # rfc = RandomForestClassifier(n_estimators=10, max_depth=3, random_state=1)
    
    print(f"[{marker}] fit_eval")
    fit_eval(mlp, X_marker, y_marker)
# Out:
# ---------------------
# Marker: ANXA11
# ---------------------
# ['FUSHeterozygous_Untreated_ANXA11' 'FUSHomozygous_Untreated_ANXA11'
#  'FUSRevertant_Untreated_ANXA11' 'OPTN_Untreated_ANXA11'
#  'SCNA_Untreated_ANXA11' 'TBK1_Untreated_ANXA11' 'TDP43_Untreated_ANXA11'
#  'WT_Untreated_ANXA11' 'WT_stress_ANXA11']
# [ANXA11] embeddings_marker shape: (14115, 64, 25, 25), labels_marker shape: (14115, 1)
# [ANXA11] SM
# 2023-09-03 18:32:04 INFO [SM] Common markers: {'ANXA11'}
# 2023-09-03 18:32:04 INFO Pheno: FUSHeterozygous_Untreated
# 2023-09-03 18:32:04 INFO Detected 1199 subgroups
# 2023-09-03 18:32:04 INFO 1/1199
# 2023-09-03 18:32:04 INFO [1/1199] Shape: (1199, 3)
# 2023-09-03 18:32:04 INFO 2/1199
# 2023-09-03 18:32:04 INFO [2/1199] Shape: (1198, 3)
# 2023-09-03 18:32:04 INFO 3/1199
# 2023-09-03 18:32:04 INFO [3/1199] Shape: (1197, 3)
# 2023-09-03 18:32:04 INFO 4/1199
# 2023-09-03 18:32:04 INFO [4/1199] Shape: (1196, 3)
# 2023-09-03 18:32:04 INFO 5/1199
# 2023-09-03 18:32:04 INFO [5/1199] Shape: (1195, 3)
# 2023-09-03 18:32:04 INFO 6/1199
# 2023-09-03 18:32:04 INFO [6/1199] Shape: (1194, 3)
# 2023-09-03 18:32:04 INFO 7/1199
# 2023-09-03 18:32:04 INFO [7/1199] Shape: (1193, 3)
# 2023-09-03 18:32:04 INFO 8/1199
# 2023-09-03 18:32:04 INFO [8/1199] Shape: (1192, 3)
# 2023-09-03 18:32:04 INFO 9/1199
# 2023-09-03 18:32:04 INFO [9/1199] Shape: (1191, 3)
# 2023-09-03 18:32:04 INFO 10/1199
# 2023-09-03 18:32:04 INFO [10/1199] Shape: (1190, 3)
# 2023-09-03 18:32:04 INFO 11/1199
# 2023-09-03 18:32:04 INFO [11/1199] Shape: (1189, 3)
# 2023-09-03 18:32:04 INFO 12/1199
# 2023-09-03 18:32:04 INFO [12/1199] Shape: (1188, 3)
# 2023-09-03 18:32:04 INFO 13/1199
# 2023-09-03 18:32:04 INFO [13/1199] Shape: (1187, 3)
# 2023-09-03 18:32:04 INFO 14/1199
# 2023-09-03 18:32:04 INFO [14/1199] Shape: (1186, 3)
# 2023-09-03 18:32:04 INFO 15/1199
# 2023-09-03 18:32:04 INFO [15/1199] Shape: (1185, 3)
# 2023-09-03 18:32:04 INFO 16/1199
# 2023-09-03 18:32:04 INFO [16/1199] Shape: (1184, 3)
# 2023-09-03 18:32:04 INFO 17/1199
# 2023-09-03 18:32:04 INFO [17/1199] Shape: (1183, 3)
# 2023-09-03 18:32:04 INFO 18/1199
# 2023-09-03 18:32:04 INFO [18/1199] Shape: (1182, 3)
# 2023-09-03 18:32:04 INFO 19/1199
# 2023-09-03 18:32:04 INFO [19/1199] Shape: (1181, 3)
# 2023-09-03 18:32:04 INFO 20/1199
# 2023-09-03 18:32:04 INFO [20/1199] Shape: (1180, 3)
# 2023-09-03 18:32:04 INFO 21/1199
# 2023-09-03 18:32:04 INFO [21/1199] Shape: (1179, 3)
# 2023-09-03 18:32:04 INFO 22/1199
# 2023-09-03 18:32:04 INFO [22/1199] Shape: (1178, 3)
# 2023-09-03 18:32:04 INFO 23/1199
# 2023-09-03 18:32:04 INFO [23/1199] Shape: (1177, 3)
# 2023-09-03 18:32:04 INFO 24/1199
# 2023-09-03 18:32:04 INFO [24/1199] Shape: (1176, 3)
# 2023-09-03 18:32:04 INFO 25/1199
# 2023-09-03 18:32:04 INFO [25/1199] Shape: (1175, 3)
# 2023-09-03 18:32:04 INFO 26/1199
# 2023-09-03 18:32:04 INFO [26/1199] Shape: (1174, 3)
# 2023-09-03 18:32:04 INFO 27/1199
# 2023-09-03 18:32:04 INFO [27/1199] Shape: (1173, 3)
# 2023-09-03 18:32:04 INFO 28/1199
# 2023-09-03 18:32:04 INFO [28/1199] Shape: (1172, 3)
# 2023-09-03 18:32:04 INFO 29/1199
# 2023-09-03 18:32:04 INFO [29/1199] Shape: (1171, 3)
# 2023-09-03 18:32:04 INFO 30/1199
# 2023-09-03 18:32:04 INFO [30/1199] Shape: (1170, 3)
# 2023-09-03 18:32:04 INFO 31/1199
# 2023-09-03 18:32:04 INFO [31/1199] Shape: (1169, 3)
# 2023-09-03 18:32:04 INFO 32/1199
# 2023-09-03 18:32:04 INFO [32/1199] Shape: (1168, 3)
# 2023-09-03 18:32:04 INFO 33/1199
# 2023-09-03 18:32:04 INFO [33/1199] Shape: (1167, 3)
# 2023-09-03 18:32:04 INFO 34/1199
# 2023-09-03 18:32:04 INFO [34/1199] Shape: (1166, 3)
# 2023-09-03 18:32:04 INFO 35/1199
# 2023-09-03 18:32:04 INFO [35/1199] Shape: (1165, 3)
# 2023-09-03 18:32:04 INFO 36/1199
# 2023-09-03 18:32:04 INFO [36/1199] Shape: (1164, 3)
# 2023-09-03 18:32:04 INFO 37/1199
# 2023-09-03 18:32:04 INFO [37/1199] Shape: (1163, 3)
# 2023-09-03 18:32:04 INFO 38/1199
# 2023-09-03 18:32:04 INFO [38/1199] Shape: (1162, 3)
# 2023-09-03 18:32:04 INFO 39/1199
# 2023-09-03 18:32:04 INFO [39/1199] Shape: (1161, 3)
# 2023-09-03 18:32:04 INFO 40/1199
# 2023-09-03 18:32:04 INFO [40/1199] Shape: (1160, 3)
# 2023-09-03 18:32:04 INFO 41/1199
# 2023-09-03 18:32:04 INFO [41/1199] Shape: (1159, 3)
# 2023-09-03 18:32:04 INFO 42/1199
# 2023-09-03 18:32:04 INFO [42/1199] Shape: (1158, 3)
# 2023-09-03 18:32:04 INFO 43/1199
# 2023-09-03 18:32:04 INFO [43/1199] Shape: (1157, 3)
# 2023-09-03 18:32:04 INFO 44/1199
# 2023-09-03 18:32:04 INFO [44/1199] Shape: (1156, 3)
# 2023-09-03 18:32:04 INFO 45/1199
# 2023-09-03 18:32:04 INFO [45/1199] Shape: (1155, 3)
# 2023-09-03 18:32:04 INFO 46/1199
# 2023-09-03 18:32:04 INFO [46/1199] Shape: (1154, 3)
# 2023-09-03 18:32:04 INFO 47/1199
# 2023-09-03 18:32:04 INFO [47/1199] Shape: (1153, 3)
# 2023-09-03 18:32:04 INFO 48/1199
# 2023-09-03 18:32:04 INFO [48/1199] Shape: (1152, 3)
# 2023-09-03 18:32:04 INFO 49/1199
# 2023-09-03 18:32:04 INFO [49/1199] Shape: (1151, 3)
# 2023-09-03 18:32:04 INFO 50/1199
# 2023-09-03 18:32:04 INFO [50/1199] Shape: (1150, 3)
# 2023-09-03 18:32:04 INFO 51/1199
# 2023-09-03 18:32:04 INFO [51/1199] Shape: (1149, 3)
# 2023-09-03 18:32:04 INFO 52/1199
# 2023-09-03 18:32:04 INFO [52/1199] Shape: (1148, 3)
# 2023-09-03 18:32:04 INFO 53/1199
# 2023-09-03 18:32:04 INFO [53/1199] Shape: (1147, 3)
# 2023-09-03 18:32:04 INFO 54/1199
# 2023-09-03 18:32:04 INFO [54/1199] Shape: (1146, 3)
# 2023-09-03 18:32:04 INFO 55/1199
# 2023-09-03 18:32:04 INFO [55/1199] Shape: (1145, 3)
# 2023-09-03 18:32:04 INFO 56/1199
# 2023-09-03 18:32:04 INFO [56/1199] Shape: (1144, 3)
# 2023-09-03 18:32:04 INFO 57/1199
# 2023-09-03 18:32:04 INFO [57/1199] Shape: (1143, 3)
# 2023-09-03 18:32:04 INFO 58/1199
# 2023-09-03 18:32:04 INFO [58/1199] Shape: (1142, 3)
# 2023-09-03 18:32:04 INFO 59/1199
# 2023-09-03 18:32:04 INFO [59/1199] Shape: (1141, 3)
# 2023-09-03 18:32:04 INFO 60/1199
# 2023-09-03 18:32:04 INFO [60/1199] Shape: (1140, 3)
# 2023-09-03 18:32:04 INFO 61/1199
# 2023-09-03 18:32:04 INFO [61/1199] Shape: (1139, 3)
# 2023-09-03 18:32:04 INFO 62/1199
# 2023-09-03 18:32:04 INFO [62/1199] Shape: (1138, 3)
# 2023-09-03 18:32:04 INFO 63/1199
# 2023-09-03 18:32:04 INFO [63/1199] Shape: (1137, 3)
# 2023-09-03 18:32:04 INFO 64/1199
# 2023-09-03 18:32:04 INFO [64/1199] Shape: (1136, 3)
# 2023-09-03 18:32:04 INFO 65/1199
# 2023-09-03 18:32:04 INFO [65/1199] Shape: (1135, 3)
# 2023-09-03 18:32:04 INFO 66/1199
# 2023-09-03 18:32:04 INFO [66/1199] Shape: (1134, 3)
# 2023-09-03 18:32:05 INFO 67/1199
# 2023-09-03 18:32:05 INFO [67/1199] Shape: (1133, 3)
# 2023-09-03 18:32:05 INFO 68/1199
# 2023-09-03 18:32:05 INFO [68/1199] Shape: (1132, 3)
# 2023-09-03 18:32:05 INFO 69/1199
# 2023-09-03 18:32:05 INFO [69/1199] Shape: (1131, 3)
# 2023-09-03 18:32:05 INFO 70/1199
# 2023-09-03 18:32:05 INFO [70/1199] Shape: (1130, 3)
# 2023-09-03 18:32:05 INFO 71/1199
# 2023-09-03 18:32:05 INFO [71/1199] Shape: (1129, 3)
# 2023-09-03 18:32:05 INFO 72/1199
# 2023-09-03 18:32:05 INFO [72/1199] Shape: (1128, 3)
# 2023-09-03 18:32:05 INFO 73/1199
# 2023-09-03 18:32:05 INFO [73/1199] Shape: (1127, 3)
# 2023-09-03 18:32:05 INFO 74/1199
# 2023-09-03 18:32:05 INFO [74/1199] Shape: (1126, 3)
# 2023-09-03 18:32:05 INFO 75/1199
# 2023-09-03 18:32:05 INFO [75/1199] Shape: (1125, 3)
# 2023-09-03 18:32:05 INFO 76/1199
# 2023-09-03 18:32:05 INFO [76/1199] Shape: (1124, 3)
# 2023-09-03 18:32:05 INFO 77/1199
# 2023-09-03 18:32:05 INFO [77/1199] Shape: (1123, 3)
# 2023-09-03 18:32:05 INFO 78/1199
# 2023-09-03 18:32:05 INFO [78/1199] Shape: (1122, 3)
# 2023-09-03 18:32:05 INFO 79/1199
# 2023-09-03 18:32:05 INFO [79/1199] Shape: (1121, 3)
# 2023-09-03 18:32:05 INFO 80/1199
# 2023-09-03 18:32:05 INFO [80/1199] Shape: (1120, 3)
# 2023-09-03 18:32:05 INFO 81/1199
# 2023-09-03 18:32:05 INFO [81/1199] Shape: (1119, 3)
# 2023-09-03 18:32:05 INFO 82/1199
# 2023-09-03 18:32:05 INFO [82/1199] Shape: (1118, 3)
# 2023-09-03 18:32:05 INFO 83/1199
# 2023-09-03 18:32:05 INFO [83/1199] Shape: (1117, 3)
# 2023-09-03 18:32:05 INFO 84/1199
# 2023-09-03 18:32:05 INFO [84/1199] Shape: (1116, 3)
# 2023-09-03 18:32:05 INFO 85/1199
# 2023-09-03 18:32:05 INFO [85/1199] Shape: (1115, 3)
# 2023-09-03 18:32:05 INFO 86/1199
# 2023-09-03 18:32:05 INFO [86/1199] Shape: (1114, 3)
# 2023-09-03 18:32:05 INFO 87/1199
# 2023-09-03 18:32:05 INFO [87/1199] Shape: (1113, 3)
# 2023-09-03 18:32:05 INFO 88/1199
# 2023-09-03 18:32:05 INFO [88/1199] Shape: (1112, 3)
# 2023-09-03 18:32:05 INFO 89/1199
# 2023-09-03 18:32:05 INFO [89/1199] Shape: (1111, 3)
# 2023-09-03 18:32:05 INFO 90/1199
# 2023-09-03 18:32:05 INFO [90/1199] Shape: (1110, 3)
# 2023-09-03 18:32:05 INFO 91/1199
# 2023-09-03 18:32:05 INFO [91/1199] Shape: (1109, 3)
# 2023-09-03 18:32:05 INFO 92/1199
# 2023-09-03 18:32:05 INFO [92/1199] Shape: (1108, 3)
# 2023-09-03 18:32:05 INFO 93/1199
# 2023-09-03 18:32:05 INFO [93/1199] Shape: (1107, 3)
# 2023-09-03 18:32:05 INFO 94/1199
# 2023-09-03 18:32:05 INFO [94/1199] Shape: (1106, 3)
# 2023-09-03 18:32:05 INFO 95/1199
# 2023-09-03 18:32:05 INFO [95/1199] Shape: (1105, 3)
# 2023-09-03 18:32:05 INFO 96/1199
# 2023-09-03 18:32:05 INFO [96/1199] Shape: (1104, 3)
# 2023-09-03 18:32:05 INFO 97/1199
# 2023-09-03 18:32:05 INFO [97/1199] Shape: (1103, 3)
# 2023-09-03 18:32:05 INFO 98/1199
# 2023-09-03 18:32:05 INFO [98/1199] Shape: (1102, 3)
# 2023-09-03 18:32:05 INFO 99/1199
# 2023-09-03 18:32:05 INFO [99/1199] Shape: (1101, 3)
# 2023-09-03 18:32:05 INFO 100/1199
# 2023-09-03 18:32:05 INFO [100/1199] Shape: (1100, 3)
# 2023-09-03 18:32:05 INFO 101/1199
# 2023-09-03 18:32:05 INFO [101/1199] Shape: (1099, 3)
# 2023-09-03 18:32:05 INFO 102/1199
# 2023-09-03 18:32:05 INFO [102/1199] Shape: (1098, 3)
# 2023-09-03 18:32:05 INFO 103/1199
# 2023-09-03 18:32:05 INFO [103/1199] Shape: (1097, 3)
# 2023-09-03 18:32:05 INFO 104/1199
# 2023-09-03 18:32:05 INFO [104/1199] Shape: (1096, 3)
# 2023-09-03 18:32:05 INFO 105/1199
# 2023-09-03 18:32:05 INFO [105/1199] Shape: (1095, 3)
# 2023-09-03 18:32:05 INFO 106/1199
# 2023-09-03 18:32:05 INFO [106/1199] Shape: (1094, 3)
# 2023-09-03 18:32:05 INFO 107/1199
# 2023-09-03 18:32:05 INFO [107/1199] Shape: (1093, 3)
# 2023-09-03 18:32:05 INFO 108/1199
# 2023-09-03 18:32:05 INFO [108/1199] Shape: (1092, 3)
# 2023-09-03 18:32:05 INFO 109/1199
# 2023-09-03 18:32:05 INFO [109/1199] Shape: (1091, 3)
# 2023-09-03 18:32:05 INFO 110/1199
# 2023-09-03 18:32:05 INFO [110/1199] Shape: (1090, 3)
# 2023-09-03 18:32:05 INFO 111/1199
# 2023-09-03 18:32:05 INFO [111/1199] Shape: (1089, 3)
# 2023-09-03 18:32:05 INFO 112/1199
# 2023-09-03 18:32:05 INFO [112/1199] Shape: (1088, 3)
# 2023-09-03 18:32:05 INFO 113/1199
# 2023-09-03 18:32:05 INFO [113/1199] Shape: (1087, 3)
# 2023-09-03 18:32:05 INFO 114/1199
# 2023-09-03 18:32:05 INFO [114/1199] Shape: (1086, 3)
# 2023-09-03 18:32:05 INFO 115/1199
# 2023-09-03 18:32:05 INFO [115/1199] Shape: (1085, 3)
# 2023-09-03 18:32:05 INFO 116/1199
# 2023-09-03 18:32:05 INFO [116/1199] Shape: (1084, 3)
# 2023-09-03 18:32:05 INFO 117/1199
# 2023-09-03 18:32:05 INFO [117/1199] Shape: (1083, 3)
# 2023-09-03 18:32:05 INFO 118/1199
# 2023-09-03 18:32:05 INFO [118/1199] Shape: (1082, 3)
# 2023-09-03 18:32:05 INFO 119/1199
# 2023-09-03 18:32:05 INFO [119/1199] Shape: (1081, 3)
# 2023-09-03 18:32:05 INFO 120/1199
# 2023-09-03 18:32:05 INFO [120/1199] Shape: (1080, 3)
# 2023-09-03 18:32:05 INFO 121/1199
# 2023-09-03 18:32:05 INFO [121/1199] Shape: (1079, 3)
# 2023-09-03 18:32:05 INFO 122/1199
# 2023-09-03 18:32:05 INFO [122/1199] Shape: (1078, 3)
# 2023-09-03 18:32:05 INFO 123/1199
# 2023-09-03 18:32:05 INFO [123/1199] Shape: (1077, 3)
# 2023-09-03 18:32:05 INFO 124/1199
# 2023-09-03 18:32:05 INFO [124/1199] Shape: (1076, 3)
# 2023-09-03 18:32:05 INFO 125/1199
# 2023-09-03 18:32:05 INFO [125/1199] Shape: (1075, 3)
# 2023-09-03 18:32:05 INFO 126/1199
# 2023-09-03 18:32:05 INFO [126/1199] Shape: (1074, 3)
# 2023-09-03 18:32:05 INFO 127/1199
# 2023-09-03 18:32:05 INFO [127/1199] Shape: (1073, 3)
# 2023-09-03 18:32:05 INFO 128/1199
# 2023-09-03 18:32:05 INFO [128/1199] Shape: (1072, 3)
# 2023-09-03 18:32:05 INFO 129/1199
# 2023-09-03 18:32:05 INFO [129/1199] Shape: (1071, 3)
# 2023-09-03 18:32:05 INFO 130/1199
# 2023-09-03 18:32:05 INFO [130/1199] Shape: (1070, 3)
# 2023-09-03 18:32:05 INFO 131/1199
# 2023-09-03 18:32:05 INFO [131/1199] Shape: (1069, 3)
# 2023-09-03 18:32:05 INFO 132/1199
# 2023-09-03 18:32:05 INFO [132/1199] Shape: (1068, 3)
# 2023-09-03 18:32:05 INFO 133/1199
# 2023-09-03 18:32:05 INFO [133/1199] Shape: (1067, 3)
# 2023-09-03 18:32:05 INFO 134/1199
# 2023-09-03 18:32:05 INFO [134/1199] Shape: (1066, 3)
# 2023-09-03 18:32:05 INFO 135/1199
# 2023-09-03 18:32:05 INFO [135/1199] Shape: (1065, 3)
# 2023-09-03 18:32:05 INFO 136/1199
# 2023-09-03 18:32:05 INFO [136/1199] Shape: (1064, 3)
# 2023-09-03 18:32:05 INFO 137/1199
# 2023-09-03 18:32:05 INFO [137/1199] Shape: (1063, 3)
# 2023-09-03 18:32:05 INFO 138/1199
# 2023-09-03 18:32:05 INFO [138/1199] Shape: (1062, 3)
# 2023-09-03 18:32:05 INFO 139/1199
# 2023-09-03 18:32:05 INFO [139/1199] Shape: (1061, 3)
# 2023-09-03 18:32:05 INFO 140/1199
# 2023-09-03 18:32:05 INFO [140/1199] Shape: (1060, 3)
# 2023-09-03 18:32:05 INFO 141/1199
# 2023-09-03 18:32:05 INFO [141/1199] Shape: (1059, 3)
# 2023-09-03 18:32:05 INFO 142/1199
# 2023-09-03 18:32:05 INFO [142/1199] Shape: (1058, 3)
# 2023-09-03 18:32:05 INFO 143/1199
# 2023-09-03 18:32:05 INFO [143/1199] Shape: (1057, 3)
# 2023-09-03 18:32:05 INFO 144/1199
# 2023-09-03 18:32:05 INFO [144/1199] Shape: (1056, 3)
# 2023-09-03 18:32:05 INFO 145/1199
# 2023-09-03 18:32:05 INFO [145/1199] Shape: (1055, 3)
# 2023-09-03 18:32:05 INFO 146/1199
# 2023-09-03 18:32:05 INFO [146/1199] Shape: (1054, 3)
# 2023-09-03 18:32:05 INFO 147/1199
# 2023-09-03 18:32:05 INFO [147/1199] Shape: (1053, 3)
# 2023-09-03 18:32:05 INFO 148/1199
# 2023-09-03 18:32:05 INFO [148/1199] Shape: (1052, 3)
# 2023-09-03 18:32:05 INFO 149/1199
# 2023-09-03 18:32:05 INFO [149/1199] Shape: (1051, 3)
# 2023-09-03 18:32:05 INFO 150/1199
# 2023-09-03 18:32:05 INFO [150/1199] Shape: (1050, 3)
# 2023-09-03 18:32:05 INFO 151/1199
# 2023-09-03 18:32:05 INFO [151/1199] Shape: (1049, 3)
# 2023-09-03 18:32:05 INFO 152/1199
# 2023-09-03 18:32:05 INFO [152/1199] Shape: (1048, 3)
# 2023-09-03 18:32:05 INFO 153/1199
# 2023-09-03 18:32:05 INFO [153/1199] Shape: (1047, 3)
# 2023-09-03 18:32:05 INFO 154/1199
# 2023-09-03 18:32:05 INFO [154/1199] Shape: (1046, 3)
# 2023-09-03 18:32:05 INFO 155/1199
# 2023-09-03 18:32:05 INFO [155/1199] Shape: (1045, 3)
# 2023-09-03 18:32:05 INFO 156/1199
# 2023-09-03 18:32:05 INFO [156/1199] Shape: (1044, 3)
# 2023-09-03 18:32:05 INFO 157/1199
# 2023-09-03 18:32:05 INFO [157/1199] Shape: (1043, 3)
# 2023-09-03 18:32:05 INFO 158/1199
# 2023-09-03 18:32:05 INFO [158/1199] Shape: (1042, 3)
# 2023-09-03 18:32:05 INFO 159/1199
# 2023-09-03 18:32:05 INFO [159/1199] Shape: (1041, 3)
# 2023-09-03 18:32:05 INFO 160/1199
# 2023-09-03 18:32:05 INFO [160/1199] Shape: (1040, 3)
# 2023-09-03 18:32:05 INFO 161/1199
# 2023-09-03 18:32:05 INFO [161/1199] Shape: (1039, 3)
# 2023-09-03 18:32:05 INFO 162/1199
# 2023-09-03 18:32:05 INFO [162/1199] Shape: (1038, 3)
# 2023-09-03 18:32:05 INFO 163/1199
# 2023-09-03 18:32:05 INFO [163/1199] Shape: (1037, 3)
# 2023-09-03 18:32:05 INFO 164/1199
# 2023-09-03 18:32:05 INFO [164/1199] Shape: (1036, 3)
# 2023-09-03 18:32:05 INFO 165/1199
# 2023-09-03 18:32:05 INFO [165/1199] Shape: (1035, 3)
# 2023-09-03 18:32:05 INFO 166/1199
# 2023-09-03 18:32:05 INFO [166/1199] Shape: (1034, 3)
# 2023-09-03 18:32:05 INFO 167/1199
# 2023-09-03 18:32:05 INFO [167/1199] Shape: (1033, 3)
# 2023-09-03 18:32:05 INFO 168/1199
# 2023-09-03 18:32:05 INFO [168/1199] Shape: (1032, 3)
# 2023-09-03 18:32:05 INFO 169/1199
# 2023-09-03 18:32:05 INFO [169/1199] Shape: (1031, 3)
# 2023-09-03 18:32:05 INFO 170/1199
# 2023-09-03 18:32:05 INFO [170/1199] Shape: (1030, 3)
# 2023-09-03 18:32:05 INFO 171/1199
# 2023-09-03 18:32:05 INFO [171/1199] Shape: (1029, 3)
# 2023-09-03 18:32:05 INFO 172/1199
# 2023-09-03 18:32:05 INFO [172/1199] Shape: (1028, 3)
# 2023-09-03 18:32:05 INFO 173/1199
# 2023-09-03 18:32:05 INFO [173/1199] Shape: (1027, 3)
# 2023-09-03 18:32:05 INFO 174/1199
# 2023-09-03 18:32:05 INFO [174/1199] Shape: (1026, 3)
# 2023-09-03 18:32:05 INFO 175/1199
# 2023-09-03 18:32:05 INFO [175/1199] Shape: (1025, 3)
# 2023-09-03 18:32:05 INFO 176/1199
# 2023-09-03 18:32:05 INFO [176/1199] Shape: (1024, 3)
# 2023-09-03 18:32:05 INFO 177/1199
# 2023-09-03 18:32:05 INFO [177/1199] Shape: (1023, 3)
# 2023-09-03 18:32:05 INFO 178/1199
# 2023-09-03 18:32:05 INFO [178/1199] Shape: (1022, 3)
# 2023-09-03 18:32:05 INFO 179/1199
# 2023-09-03 18:32:05 INFO [179/1199] Shape: (1021, 3)
# 2023-09-03 18:32:05 INFO 180/1199
# 2023-09-03 18:32:05 INFO [180/1199] Shape: (1020, 3)
# 2023-09-03 18:32:05 INFO 181/1199
# 2023-09-03 18:32:05 INFO [181/1199] Shape: (1019, 3)
# 2023-09-03 18:32:05 INFO 182/1199
# 2023-09-03 18:32:05 INFO [182/1199] Shape: (1018, 3)
# 2023-09-03 18:32:05 INFO 183/1199
# 2023-09-03 18:32:05 INFO [183/1199] Shape: (1017, 3)
# 2023-09-03 18:32:05 INFO 184/1199
# 2023-09-03 18:32:05 INFO [184/1199] Shape: (1016, 3)
# 2023-09-03 18:32:05 INFO 185/1199
# 2023-09-03 18:32:05 INFO [185/1199] Shape: (1015, 3)
# 2023-09-03 18:32:05 INFO 186/1199
# 2023-09-03 18:32:05 INFO [186/1199] Shape: (1014, 3)
# 2023-09-03 18:32:05 INFO 187/1199
# 2023-09-03 18:32:05 INFO [187/1199] Shape: (1013, 3)
# 2023-09-03 18:32:05 INFO 188/1199
# 2023-09-03 18:32:05 INFO [188/1199] Shape: (1012, 3)
# 2023-09-03 18:32:05 INFO 189/1199
# 2023-09-03 18:32:05 INFO [189/1199] Shape: (1011, 3)
# 2023-09-03 18:32:05 INFO 190/1199
# 2023-09-03 18:32:05 INFO [190/1199] Shape: (1010, 3)
# 2023-09-03 18:32:05 INFO 191/1199
# 2023-09-03 18:32:05 INFO [191/1199] Shape: (1009, 3)
# 2023-09-03 18:32:05 INFO 192/1199
# 2023-09-03 18:32:05 INFO [192/1199] Shape: (1008, 3)
# 2023-09-03 18:32:05 INFO 193/1199
# 2023-09-03 18:32:05 INFO [193/1199] Shape: (1007, 3)
# 2023-09-03 18:32:05 INFO 194/1199
# 2023-09-03 18:32:05 INFO [194/1199] Shape: (1006, 3)
# 2023-09-03 18:32:05 INFO 195/1199
# 2023-09-03 18:32:05 INFO [195/1199] Shape: (1005, 3)
# 2023-09-03 18:32:05 INFO 196/1199
# 2023-09-03 18:32:05 INFO [196/1199] Shape: (1004, 3)
# 2023-09-03 18:32:05 INFO 197/1199
# 2023-09-03 18:32:05 INFO [197/1199] Shape: (1003, 3)
# 2023-09-03 18:32:05 INFO 198/1199
# 2023-09-03 18:32:05 INFO [198/1199] Shape: (1002, 3)
# 2023-09-03 18:32:05 INFO 199/1199
# 2023-09-03 18:32:05 INFO [199/1199] Shape: (1001, 3)
# 2023-09-03 18:32:05 INFO 200/1199
# 2023-09-03 18:32:05 INFO [200/1199] Shape: (1000, 3)
# 2023-09-03 18:32:05 INFO 201/1199
# 2023-09-03 18:32:05 INFO [201/1199] Shape: (999, 3)
# 2023-09-03 18:32:05 INFO 202/1199
# 2023-09-03 18:32:05 INFO [202/1199] Shape: (998, 3)
# 2023-09-03 18:32:05 INFO 203/1199
# 2023-09-03 18:32:05 INFO [203/1199] Shape: (997, 3)
# 2023-09-03 18:32:05 INFO 204/1199
# 2023-09-03 18:32:05 INFO [204/1199] Shape: (996, 3)
# 2023-09-03 18:32:05 INFO 205/1199
# 2023-09-03 18:32:05 INFO [205/1199] Shape: (995, 3)
# 2023-09-03 18:32:05 INFO 206/1199
# 2023-09-03 18:32:05 INFO [206/1199] Shape: (994, 3)
# 2023-09-03 18:32:05 INFO 207/1199
# 2023-09-03 18:32:05 INFO [207/1199] Shape: (993, 3)
# 2023-09-03 18:32:05 INFO 208/1199
# 2023-09-03 18:32:05 INFO [208/1199] Shape: (992, 3)
# 2023-09-03 18:32:05 INFO 209/1199
# 2023-09-03 18:32:05 INFO [209/1199] Shape: (991, 3)
# 2023-09-03 18:32:05 INFO 210/1199
# 2023-09-03 18:32:05 INFO [210/1199] Shape: (990, 3)
# 2023-09-03 18:32:05 INFO 211/1199
# 2023-09-03 18:32:05 INFO [211/1199] Shape: (989, 3)
# 2023-09-03 18:32:05 INFO 212/1199
# 2023-09-03 18:32:05 INFO [212/1199] Shape: (988, 3)
# 2023-09-03 18:32:05 INFO 213/1199
# 2023-09-03 18:32:05 INFO [213/1199] Shape: (987, 3)
# 2023-09-03 18:32:05 INFO 214/1199
# 2023-09-03 18:32:05 INFO [214/1199] Shape: (986, 3)
# 2023-09-03 18:32:05 INFO 215/1199
# 2023-09-03 18:32:05 INFO [215/1199] Shape: (985, 3)
# 2023-09-03 18:32:05 INFO 216/1199
# 2023-09-03 18:32:05 INFO [216/1199] Shape: (984, 3)
# 2023-09-03 18:32:05 INFO 217/1199
# 2023-09-03 18:32:05 INFO [217/1199] Shape: (983, 3)
# 2023-09-03 18:32:05 INFO 218/1199
# 2023-09-03 18:32:05 INFO [218/1199] Shape: (982, 3)
# 2023-09-03 18:32:05 INFO 219/1199
# 2023-09-03 18:32:05 INFO [219/1199] Shape: (981, 3)
# 2023-09-03 18:32:05 INFO 220/1199
# 2023-09-03 18:32:05 INFO [220/1199] Shape: (980, 3)
# 2023-09-03 18:32:05 INFO 221/1199
# 2023-09-03 18:32:05 INFO [221/1199] Shape: (979, 3)
# 2023-09-03 18:32:05 INFO 222/1199
# 2023-09-03 18:32:05 INFO [222/1199] Shape: (978, 3)
# 2023-09-03 18:32:05 INFO 223/1199
# 2023-09-03 18:32:05 INFO [223/1199] Shape: (977, 3)
# 2023-09-03 18:32:05 INFO 224/1199
# 2023-09-03 18:32:05 INFO [224/1199] Shape: (976, 3)
# 2023-09-03 18:32:05 INFO 225/1199
# 2023-09-03 18:32:05 INFO [225/1199] Shape: (975, 3)
# 2023-09-03 18:32:05 INFO 226/1199
# 2023-09-03 18:32:05 INFO [226/1199] Shape: (974, 3)
# 2023-09-03 18:32:05 INFO 227/1199
# 2023-09-03 18:32:05 INFO [227/1199] Shape: (973, 3)
# 2023-09-03 18:32:05 INFO 228/1199
# 2023-09-03 18:32:05 INFO [228/1199] Shape: (972, 3)
# 2023-09-03 18:32:05 INFO 229/1199
# 2023-09-03 18:32:05 INFO [229/1199] Shape: (971, 3)
# 2023-09-03 18:32:05 INFO 230/1199
# 2023-09-03 18:32:05 INFO [230/1199] Shape: (970, 3)
# 2023-09-03 18:32:05 INFO 231/1199
# 2023-09-03 18:32:05 INFO [231/1199] Shape: (969, 3)
# 2023-09-03 18:32:05 INFO 232/1199
# 2023-09-03 18:32:05 INFO [232/1199] Shape: (968, 3)
# 2023-09-03 18:32:05 INFO 233/1199
# 2023-09-03 18:32:05 INFO [233/1199] Shape: (967, 3)
# 2023-09-03 18:32:05 INFO 234/1199
# 2023-09-03 18:32:05 INFO [234/1199] Shape: (966, 3)
# 2023-09-03 18:32:05 INFO 235/1199
# 2023-09-03 18:32:05 INFO [235/1199] Shape: (965, 3)
# 2023-09-03 18:32:05 INFO 236/1199
# 2023-09-03 18:32:05 INFO [236/1199] Shape: (964, 3)
# 2023-09-03 18:32:05 INFO 237/1199
# 2023-09-03 18:32:05 INFO [237/1199] Shape: (963, 3)
# 2023-09-03 18:32:05 INFO 238/1199
# 2023-09-03 18:32:05 INFO [238/1199] Shape: (962, 3)
# 2023-09-03 18:32:05 INFO 239/1199
# 2023-09-03 18:32:05 INFO [239/1199] Shape: (961, 3)
# 2023-09-03 18:32:05 INFO 240/1199
# 2023-09-03 18:32:05 INFO [240/1199] Shape: (960, 3)
# 2023-09-03 18:32:05 INFO 241/1199
# 2023-09-03 18:32:05 INFO [241/1199] Shape: (959, 3)
# 2023-09-03 18:32:05 INFO 242/1199
# 2023-09-03 18:32:05 INFO [242/1199] Shape: (958, 3)
# 2023-09-03 18:32:05 INFO 243/1199
# 2023-09-03 18:32:05 INFO [243/1199] Shape: (957, 3)
# 2023-09-03 18:32:05 INFO 244/1199
# 2023-09-03 18:32:05 INFO [244/1199] Shape: (956, 3)
# 2023-09-03 18:32:05 INFO 245/1199
# 2023-09-03 18:32:05 INFO [245/1199] Shape: (955, 3)
# 2023-09-03 18:32:05 INFO 246/1199
# 2023-09-03 18:32:05 INFO [246/1199] Shape: (954, 3)
# 2023-09-03 18:32:05 INFO 247/1199
# 2023-09-03 18:32:05 INFO [247/1199] Shape: (953, 3)
# 2023-09-03 18:32:05 INFO 248/1199
# 2023-09-03 18:32:05 INFO [248/1199] Shape: (952, 3)
# 2023-09-03 18:32:05 INFO 249/1199
# 2023-09-03 18:32:05 INFO [249/1199] Shape: (951, 3)
# 2023-09-03 18:32:05 INFO 250/1199
# 2023-09-03 18:32:05 INFO [250/1199] Shape: (950, 3)
# 2023-09-03 18:32:05 INFO 251/1199
# 2023-09-03 18:32:05 INFO [251/1199] Shape: (949, 3)
# 2023-09-03 18:32:05 INFO 252/1199
# 2023-09-03 18:32:05 INFO [252/1199] Shape: (948, 3)
# 2023-09-03 18:32:05 INFO 253/1199
# 2023-09-03 18:32:05 INFO [253/1199] Shape: (947, 3)
# 2023-09-03 18:32:05 INFO 254/1199
# 2023-09-03 18:32:05 INFO [254/1199] Shape: (946, 3)
# 2023-09-03 18:32:05 INFO 255/1199
# 2023-09-03 18:32:05 INFO [255/1199] Shape: (945, 3)
# 2023-09-03 18:32:05 INFO 256/1199
# 2023-09-03 18:32:05 INFO [256/1199] Shape: (944, 3)
# 2023-09-03 18:32:05 INFO 257/1199
# 2023-09-03 18:32:05 INFO [257/1199] Shape: (943, 3)
# 2023-09-03 18:32:05 INFO 258/1199
# 2023-09-03 18:32:05 INFO [258/1199] Shape: (942, 3)
# 2023-09-03 18:32:05 INFO 259/1199
# 2023-09-03 18:32:05 INFO [259/1199] Shape: (941, 3)
# 2023-09-03 18:32:05 INFO 260/1199
# 2023-09-03 18:32:05 INFO [260/1199] Shape: (940, 3)
# 2023-09-03 18:32:05 INFO 261/1199
# 2023-09-03 18:32:05 INFO [261/1199] Shape: (939, 3)
# 2023-09-03 18:32:05 INFO 262/1199
# 2023-09-03 18:32:05 INFO [262/1199] Shape: (938, 3)
# 2023-09-03 18:32:05 INFO 263/1199
# 2023-09-03 18:32:05 INFO [263/1199] Shape: (937, 3)
# 2023-09-03 18:32:05 INFO 264/1199
# 2023-09-03 18:32:05 INFO [264/1199] Shape: (936, 3)
# 2023-09-03 18:32:05 INFO 265/1199
# 2023-09-03 18:32:05 INFO [265/1199] Shape: (935, 3)
# 2023-09-03 18:32:05 INFO 266/1199
# 2023-09-03 18:32:05 INFO [266/1199] Shape: (934, 3)
# 2023-09-03 18:32:05 INFO 267/1199
# 2023-09-03 18:32:05 INFO [267/1199] Shape: (933, 3)
# 2023-09-03 18:32:05 INFO 268/1199
# 2023-09-03 18:32:05 INFO [268/1199] Shape: (932, 3)
# 2023-09-03 18:32:05 INFO 269/1199
# 2023-09-03 18:32:05 INFO [269/1199] Shape: (931, 3)
# 2023-09-03 18:32:05 INFO 270/1199
# 2023-09-03 18:32:05 INFO [270/1199] Shape: (930, 3)
# 2023-09-03 18:32:05 INFO 271/1199
# 2023-09-03 18:32:05 INFO [271/1199] Shape: (929, 3)
# 2023-09-03 18:32:05 INFO 272/1199
# 2023-09-03 18:32:05 INFO [272/1199] Shape: (928, 3)
# 2023-09-03 18:32:05 INFO 273/1199
# 2023-09-03 18:32:05 INFO [273/1199] Shape: (927, 3)
# 2023-09-03 18:32:05 INFO 274/1199
# 2023-09-03 18:32:05 INFO [274/1199] Shape: (926, 3)
# 2023-09-03 18:32:05 INFO 275/1199
# 2023-09-03 18:32:05 INFO [275/1199] Shape: (925, 3)
# 2023-09-03 18:32:05 INFO 276/1199
# 2023-09-03 18:32:05 INFO [276/1199] Shape: (924, 3)
# 2023-09-03 18:32:05 INFO 277/1199
# 2023-09-03 18:32:05 INFO [277/1199] Shape: (923, 3)
# 2023-09-03 18:32:05 INFO 278/1199
# 2023-09-03 18:32:05 INFO [278/1199] Shape: (922, 3)
# 2023-09-03 18:32:05 INFO 279/1199
# 2023-09-03 18:32:05 INFO [279/1199] Shape: (921, 3)
# 2023-09-03 18:32:05 INFO 280/1199
# 2023-09-03 18:32:05 INFO [280/1199] Shape: (920, 3)
# 2023-09-03 18:32:05 INFO 281/1199
# 2023-09-03 18:32:05 INFO [281/1199] Shape: (919, 3)
# 2023-09-03 18:32:05 INFO 282/1199
# 2023-09-03 18:32:05 INFO [282/1199] Shape: (918, 3)
# 2023-09-03 18:32:05 INFO 283/1199
# 2023-09-03 18:32:05 INFO [283/1199] Shape: (917, 3)
# 2023-09-03 18:32:05 INFO 284/1199
# 2023-09-03 18:32:05 INFO [284/1199] Shape: (916, 3)
# 2023-09-03 18:32:05 INFO 285/1199
# 2023-09-03 18:32:05 INFO [285/1199] Shape: (915, 3)
# 2023-09-03 18:32:05 INFO 286/1199
# 2023-09-03 18:32:05 INFO [286/1199] Shape: (914, 3)
# 2023-09-03 18:32:05 INFO 287/1199
# 2023-09-03 18:32:05 INFO [287/1199] Shape: (913, 3)
# 2023-09-03 18:32:05 INFO 288/1199
# 2023-09-03 18:32:05 INFO [288/1199] Shape: (912, 3)
# 2023-09-03 18:32:05 INFO 289/1199
# 2023-09-03 18:32:05 INFO [289/1199] Shape: (911, 3)
# 2023-09-03 18:32:05 INFO 290/1199
# 2023-09-03 18:32:05 INFO [290/1199] Shape: (910, 3)
# 2023-09-03 18:32:05 INFO 291/1199
# 2023-09-03 18:32:05 INFO [291/1199] Shape: (909, 3)
# 2023-09-03 18:32:05 INFO 292/1199
# 2023-09-03 18:32:05 INFO [292/1199] Shape: (908, 3)
# 2023-09-03 18:32:05 INFO 293/1199
# 2023-09-03 18:32:05 INFO [293/1199] Shape: (907, 3)
# 2023-09-03 18:32:05 INFO 294/1199
# 2023-09-03 18:32:05 INFO [294/1199] Shape: (906, 3)
# 2023-09-03 18:32:05 INFO 295/1199
# 2023-09-03 18:32:05 INFO [295/1199] Shape: (905, 3)
# 2023-09-03 18:32:05 INFO 296/1199
# 2023-09-03 18:32:05 INFO [296/1199] Shape: (904, 3)
# 2023-09-03 18:32:05 INFO 297/1199
# 2023-09-03 18:32:05 INFO [297/1199] Shape: (903, 3)
# 2023-09-03 18:32:05 INFO 298/1199
# 2023-09-03 18:32:05 INFO [298/1199] Shape: (902, 3)
# 2023-09-03 18:32:05 INFO 299/1199
# 2023-09-03 18:32:05 INFO [299/1199] Shape: (901, 3)
# 2023-09-03 18:32:05 INFO 300/1199
# 2023-09-03 18:32:05 INFO [300/1199] Shape: (900, 3)
# 2023-09-03 18:32:05 INFO 301/1199
# 2023-09-03 18:32:05 INFO [301/1199] Shape: (899, 3)
# 2023-09-03 18:32:05 INFO 302/1199
# 2023-09-03 18:32:05 INFO [302/1199] Shape: (898, 3)
# 2023-09-03 18:32:05 INFO 303/1199
# 2023-09-03 18:32:05 INFO [303/1199] Shape: (897, 3)
# 2023-09-03 18:32:05 INFO 304/1199
# 2023-09-03 18:32:05 INFO [304/1199] Shape: (896, 3)
# 2023-09-03 18:32:05 INFO 305/1199
# 2023-09-03 18:32:05 INFO [305/1199] Shape: (895, 3)
# 2023-09-03 18:32:05 INFO 306/1199
# 2023-09-03 18:32:05 INFO [306/1199] Shape: (894, 3)
# 2023-09-03 18:32:05 INFO 307/1199
# 2023-09-03 18:32:05 INFO [307/1199] Shape: (893, 3)
# 2023-09-03 18:32:05 INFO 308/1199
# 2023-09-03 18:32:05 INFO [308/1199] Shape: (892, 3)
# 2023-09-03 18:32:05 INFO 309/1199
# 2023-09-03 18:32:05 INFO [309/1199] Shape: (891, 3)
# 2023-09-03 18:32:05 INFO 310/1199
# 2023-09-03 18:32:05 INFO [310/1199] Shape: (890, 3)
# 2023-09-03 18:32:05 INFO 311/1199
# 2023-09-03 18:32:05 INFO [311/1199] Shape: (889, 3)
# 2023-09-03 18:32:05 INFO 312/1199
# 2023-09-03 18:32:05 INFO [312/1199] Shape: (888, 3)
# 2023-09-03 18:32:05 INFO 313/1199
# 2023-09-03 18:32:05 INFO [313/1199] Shape: (887, 3)
# 2023-09-03 18:32:05 INFO 314/1199
# 2023-09-03 18:32:05 INFO [314/1199] Shape: (886, 3)
# 2023-09-03 18:32:05 INFO 315/1199
# 2023-09-03 18:32:05 INFO [315/1199] Shape: (885, 3)
# 2023-09-03 18:32:05 INFO 316/1199
# 2023-09-03 18:32:05 INFO [316/1199] Shape: (884, 3)
# 2023-09-03 18:32:05 INFO 317/1199
# 2023-09-03 18:32:05 INFO [317/1199] Shape: (883, 3)
# 2023-09-03 18:32:05 INFO 318/1199
# 2023-09-03 18:32:05 INFO [318/1199] Shape: (882, 3)
# 2023-09-03 18:32:05 INFO 319/1199
# 2023-09-03 18:32:05 INFO [319/1199] Shape: (881, 3)
# 2023-09-03 18:32:05 INFO 320/1199
# 2023-09-03 18:32:05 INFO [320/1199] Shape: (880, 3)
# 2023-09-03 18:32:05 INFO 321/1199
# 2023-09-03 18:32:05 INFO [321/1199] Shape: (879, 3)
# 2023-09-03 18:32:05 INFO 322/1199
# 2023-09-03 18:32:05 INFO [322/1199] Shape: (878, 3)
# 2023-09-03 18:32:05 INFO 323/1199
# 2023-09-03 18:32:05 INFO [323/1199] Shape: (877, 3)
# 2023-09-03 18:32:05 INFO 324/1199
# 2023-09-03 18:32:05 INFO [324/1199] Shape: (876, 3)
# 2023-09-03 18:32:05 INFO 325/1199
# 2023-09-03 18:32:05 INFO [325/1199] Shape: (875, 3)
# 2023-09-03 18:32:05 INFO 326/1199
# 2023-09-03 18:32:05 INFO [326/1199] Shape: (874, 3)
# 2023-09-03 18:32:05 INFO 327/1199
# 2023-09-03 18:32:05 INFO [327/1199] Shape: (873, 3)
# 2023-09-03 18:32:05 INFO 328/1199
# 2023-09-03 18:32:05 INFO [328/1199] Shape: (872, 3)
# 2023-09-03 18:32:05 INFO 329/1199
# 2023-09-03 18:32:05 INFO [329/1199] Shape: (871, 3)
# 2023-09-03 18:32:05 INFO 330/1199
# 2023-09-03 18:32:05 INFO [330/1199] Shape: (870, 3)
# 2023-09-03 18:32:05 INFO 331/1199
# 2023-09-03 18:32:05 INFO [331/1199] Shape: (869, 3)
# 2023-09-03 18:32:05 INFO 332/1199
# 2023-09-03 18:32:05 INFO [332/1199] Shape: (868, 3)
# 2023-09-03 18:32:05 INFO 333/1199
# 2023-09-03 18:32:05 INFO [333/1199] Shape: (867, 3)
# 2023-09-03 18:32:05 INFO 334/1199
# 2023-09-03 18:32:05 INFO [334/1199] Shape: (866, 3)
# 2023-09-03 18:32:05 INFO 335/1199
# 2023-09-03 18:32:05 INFO [335/1199] Shape: (865, 3)
# 2023-09-03 18:32:05 INFO 336/1199
# 2023-09-03 18:32:05 INFO [336/1199] Shape: (864, 3)
# 2023-09-03 18:32:05 INFO 337/1199
# 2023-09-03 18:32:05 INFO [337/1199] Shape: (863, 3)
# 2023-09-03 18:32:05 INFO 338/1199
# 2023-09-03 18:32:05 INFO [338/1199] Shape: (862, 3)
# 2023-09-03 18:32:05 INFO 339/1199
# 2023-09-03 18:32:05 INFO [339/1199] Shape: (861, 3)
# 2023-09-03 18:32:05 INFO 340/1199
# 2023-09-03 18:32:05 INFO [340/1199] Shape: (860, 3)
# 2023-09-03 18:32:05 INFO 341/1199
# 2023-09-03 18:32:05 INFO [341/1199] Shape: (859, 3)
# 2023-09-03 18:32:05 INFO 342/1199
# 2023-09-03 18:32:05 INFO [342/1199] Shape: (858, 3)
# 2023-09-03 18:32:05 INFO 343/1199
# 2023-09-03 18:32:05 INFO [343/1199] Shape: (857, 3)
# 2023-09-03 18:32:05 INFO 344/1199
# 2023-09-03 18:32:05 INFO [344/1199] Shape: (856, 3)
# 2023-09-03 18:32:05 INFO 345/1199
# 2023-09-03 18:32:05 INFO [345/1199] Shape: (855, 3)
# 2023-09-03 18:32:05 INFO 346/1199
# 2023-09-03 18:32:05 INFO [346/1199] Shape: (854, 3)
# 2023-09-03 18:32:05 INFO 347/1199
# 2023-09-03 18:32:05 INFO [347/1199] Shape: (853, 3)
# 2023-09-03 18:32:05 INFO 348/1199
# 2023-09-03 18:32:05 INFO [348/1199] Shape: (852, 3)
# 2023-09-03 18:32:05 INFO 349/1199
# 2023-09-03 18:32:05 INFO [349/1199] Shape: (851, 3)
# 2023-09-03 18:32:05 INFO 350/1199
# 2023-09-03 18:32:05 INFO [350/1199] Shape: (850, 3)
# 2023-09-03 18:32:05 INFO 351/1199
# 2023-09-03 18:32:05 INFO [351/1199] Shape: (849, 3)
# 2023-09-03 18:32:05 INFO 352/1199
# 2023-09-03 18:32:05 INFO [352/1199] Shape: (848, 3)
# 2023-09-03 18:32:05 INFO 353/1199
# 2023-09-03 18:32:05 INFO [353/1199] Shape: (847, 3)
# 2023-09-03 18:32:05 INFO 354/1199
# 2023-09-03 18:32:05 INFO [354/1199] Shape: (846, 3)
# 2023-09-03 18:32:05 INFO 355/1199
# 2023-09-03 18:32:05 INFO [355/1199] Shape: (845, 3)
# 2023-09-03 18:32:05 INFO 356/1199
# 2023-09-03 18:32:05 INFO [356/1199] Shape: (844, 3)
# 2023-09-03 18:32:05 INFO 357/1199
# 2023-09-03 18:32:05 INFO [357/1199] Shape: (843, 3)
# 2023-09-03 18:32:05 INFO 358/1199
# 2023-09-03 18:32:05 INFO [358/1199] Shape: (842, 3)
# 2023-09-03 18:32:05 INFO 359/1199
# 2023-09-03 18:32:05 INFO [359/1199] Shape: (841, 3)
# 2023-09-03 18:32:05 INFO 360/1199
# 2023-09-03 18:32:05 INFO [360/1199] Shape: (840, 3)
# 2023-09-03 18:32:05 INFO 361/1199
# 2023-09-03 18:32:05 INFO [361/1199] Shape: (839, 3)
# 2023-09-03 18:32:05 INFO 362/1199
# 2023-09-03 18:32:05 INFO [362/1199] Shape: (838, 3)
# 2023-09-03 18:32:05 INFO 363/1199
# 2023-09-03 18:32:05 INFO [363/1199] Shape: (837, 3)
# 2023-09-03 18:32:05 INFO 364/1199
# 2023-09-03 18:32:05 INFO [364/1199] Shape: (836, 3)
# 2023-09-03 18:32:05 INFO 365/1199
# 2023-09-03 18:32:05 INFO [365/1199] Shape: (835, 3)
# 2023-09-03 18:32:05 INFO 366/1199
# 2023-09-03 18:32:05 INFO [366/1199] Shape: (834, 3)
# 2023-09-03 18:32:05 INFO 367/1199
# 2023-09-03 18:32:05 INFO [367/1199] Shape: (833, 3)
# 2023-09-03 18:32:05 INFO 368/1199
# 2023-09-03 18:32:05 INFO [368/1199] Shape: (832, 3)
# 2023-09-03 18:32:05 INFO 369/1199
# 2023-09-03 18:32:05 INFO [369/1199] Shape: (831, 3)
# 2023-09-03 18:32:05 INFO 370/1199
# 2023-09-03 18:32:05 INFO [370/1199] Shape: (830, 3)
# 2023-09-03 18:32:05 INFO 371/1199
# 2023-09-03 18:32:05 INFO [371/1199] Shape: (829, 3)
# 2023-09-03 18:32:05 INFO 372/1199
# 2023-09-03 18:32:05 INFO [372/1199] Shape: (828, 3)
# 2023-09-03 18:32:05 INFO 373/1199
# 2023-09-03 18:32:05 INFO [373/1199] Shape: (827, 3)
# 2023-09-03 18:32:05 INFO 374/1199
# 2023-09-03 18:32:05 INFO [374/1199] Shape: (826, 3)
# 2023-09-03 18:32:05 INFO 375/1199
# 2023-09-03 18:32:05 INFO [375/1199] Shape: (825, 3)
# 2023-09-03 18:32:05 INFO 376/1199
# 2023-09-03 18:32:05 INFO [376/1199] Shape: (824, 3)
# 2023-09-03 18:32:05 INFO 377/1199
# 2023-09-03 18:32:05 INFO [377/1199] Shape: (823, 3)
# 2023-09-03 18:32:05 INFO 378/1199
# 2023-09-03 18:32:05 INFO [378/1199] Shape: (822, 3)
# 2023-09-03 18:32:05 INFO 379/1199
# 2023-09-03 18:32:05 INFO [379/1199] Shape: (821, 3)
# 2023-09-03 18:32:05 INFO 380/1199
# 2023-09-03 18:32:05 INFO [380/1199] Shape: (820, 3)
# 2023-09-03 18:32:05 INFO 381/1199
# 2023-09-03 18:32:05 INFO [381/1199] Shape: (819, 3)
# 2023-09-03 18:32:05 INFO 382/1199
# 2023-09-03 18:32:05 INFO [382/1199] Shape: (818, 3)
# 2023-09-03 18:32:05 INFO 383/1199
# 2023-09-03 18:32:05 INFO [383/1199] Shape: (817, 3)
# 2023-09-03 18:32:05 INFO 384/1199
# 2023-09-03 18:32:05 INFO [384/1199] Shape: (816, 3)
# 2023-09-03 18:32:05 INFO 385/1199
# 2023-09-03 18:32:05 INFO [385/1199] Shape: (815, 3)
# 2023-09-03 18:32:05 INFO 386/1199
# 2023-09-03 18:32:05 INFO [386/1199] Shape: (814, 3)
# 2023-09-03 18:32:05 INFO 387/1199
# 2023-09-03 18:32:05 INFO [387/1199] Shape: (813, 3)
# 2023-09-03 18:32:05 INFO 388/1199
# 2023-09-03 18:32:05 INFO [388/1199] Shape: (812, 3)
# 2023-09-03 18:32:05 INFO 389/1199
# 2023-09-03 18:32:05 INFO [389/1199] Shape: (811, 3)
# 2023-09-03 18:32:05 INFO 390/1199
# 2023-09-03 18:32:05 INFO [390/1199] Shape: (810, 3)
# 2023-09-03 18:32:05 INFO 391/1199
# 2023-09-03 18:32:05 INFO [391/1199] Shape: (809, 3)
# 2023-09-03 18:32:05 INFO 392/1199
# 2023-09-03 18:32:05 INFO [392/1199] Shape: (808, 3)
# 2023-09-03 18:32:05 INFO 393/1199
# 2023-09-03 18:32:05 INFO [393/1199] Shape: (807, 3)
# 2023-09-03 18:32:05 INFO 394/1199
# 2023-09-03 18:32:05 INFO [394/1199] Shape: (806, 3)
# 2023-09-03 18:32:05 INFO 395/1199
# 2023-09-03 18:32:05 INFO [395/1199] Shape: (805, 3)
# 2023-09-03 18:32:05 INFO 396/1199
# 2023-09-03 18:32:05 INFO [396/1199] Shape: (804, 3)
# 2023-09-03 18:32:05 INFO 397/1199
# 2023-09-03 18:32:05 INFO [397/1199] Shape: (803, 3)
# 2023-09-03 18:32:05 INFO 398/1199
# 2023-09-03 18:32:05 INFO [398/1199] Shape: (802, 3)
# 2023-09-03 18:32:05 INFO 399/1199
# 2023-09-03 18:32:05 INFO [399/1199] Shape: (801, 3)
# 2023-09-03 18:32:05 INFO 400/1199
# 2023-09-03 18:32:05 INFO [400/1199] Shape: (800, 3)
# 2023-09-03 18:32:05 INFO 401/1199
# 2023-09-03 18:32:05 INFO [401/1199] Shape: (799, 3)
# 2023-09-03 18:32:05 INFO 402/1199
# 2023-09-03 18:32:05 INFO [402/1199] Shape: (798, 3)
# 2023-09-03 18:32:05 INFO 403/1199
# 2023-09-03 18:32:05 INFO [403/1199] Shape: (797, 3)
# 2023-09-03 18:32:05 INFO 404/1199
# 2023-09-03 18:32:05 INFO [404/1199] Shape: (796, 3)
# 2023-09-03 18:32:05 INFO 405/1199
# 2023-09-03 18:32:05 INFO [405/1199] Shape: (795, 3)
# 2023-09-03 18:32:05 INFO 406/1199
# 2023-09-03 18:32:05 INFO [406/1199] Shape: (794, 3)
# 2023-09-03 18:32:05 INFO 407/1199
# 2023-09-03 18:32:05 INFO [407/1199] Shape: (793, 3)
# 2023-09-03 18:32:05 INFO 408/1199
# 2023-09-03 18:32:05 INFO [408/1199] Shape: (792, 3)
# 2023-09-03 18:32:05 INFO 409/1199
# 2023-09-03 18:32:05 INFO [409/1199] Shape: (791, 3)
# 2023-09-03 18:32:05 INFO 410/1199
# 2023-09-03 18:32:05 INFO [410/1199] Shape: (790, 3)
# 2023-09-03 18:32:05 INFO 411/1199
# 2023-09-03 18:32:05 INFO [411/1199] Shape: (789, 3)
# 2023-09-03 18:32:06 INFO 412/1199
# 2023-09-03 18:32:06 INFO [412/1199] Shape: (788, 3)
# 2023-09-03 18:32:06 INFO 413/1199
# 2023-09-03 18:32:06 INFO [413/1199] Shape: (787, 3)
# 2023-09-03 18:32:06 INFO 414/1199
# 2023-09-03 18:32:06 INFO [414/1199] Shape: (786, 3)
# 2023-09-03 18:32:06 INFO 415/1199
# 2023-09-03 18:32:06 INFO [415/1199] Shape: (785, 3)
# 2023-09-03 18:32:06 INFO 416/1199
# 2023-09-03 18:32:06 INFO [416/1199] Shape: (784, 3)
# 2023-09-03 18:32:06 INFO 417/1199
# 2023-09-03 18:32:06 INFO [417/1199] Shape: (783, 3)
# 2023-09-03 18:32:06 INFO 418/1199
# 2023-09-03 18:32:06 INFO [418/1199] Shape: (782, 3)
# 2023-09-03 18:32:06 INFO 419/1199
# 2023-09-03 18:32:06 INFO [419/1199] Shape: (781, 3)
# 2023-09-03 18:32:06 INFO 420/1199
# 2023-09-03 18:32:06 INFO [420/1199] Shape: (780, 3)
# 2023-09-03 18:32:06 INFO 421/1199
# 2023-09-03 18:32:06 INFO [421/1199] Shape: (779, 3)
# 2023-09-03 18:32:06 INFO 422/1199
# 2023-09-03 18:32:06 INFO [422/1199] Shape: (778, 3)
# 2023-09-03 18:32:06 INFO 423/1199
# 2023-09-03 18:32:06 INFO [423/1199] Shape: (777, 3)
# 2023-09-03 18:32:06 INFO 424/1199
# 2023-09-03 18:32:06 INFO [424/1199] Shape: (776, 3)
# 2023-09-03 18:32:06 INFO 425/1199
# 2023-09-03 18:32:06 INFO [425/1199] Shape: (775, 3)
# 2023-09-03 18:32:06 INFO 426/1199
# 2023-09-03 18:32:06 INFO [426/1199] Shape: (774, 3)
# 2023-09-03 18:32:06 INFO 427/1199
# 2023-09-03 18:32:06 INFO [427/1199] Shape: (773, 3)
# 2023-09-03 18:32:06 INFO 428/1199
# 2023-09-03 18:32:06 INFO [428/1199] Shape: (772, 3)
# 2023-09-03 18:32:06 INFO 429/1199
# 2023-09-03 18:32:06 INFO [429/1199] Shape: (771, 3)
# 2023-09-03 18:32:06 INFO 430/1199
# 2023-09-03 18:32:06 INFO [430/1199] Shape: (770, 3)
# 2023-09-03 18:32:06 INFO 431/1199
# 2023-09-03 18:32:06 INFO [431/1199] Shape: (769, 3)
# 2023-09-03 18:32:06 INFO 432/1199
# 2023-09-03 18:32:06 INFO [432/1199] Shape: (768, 3)
# 2023-09-03 18:32:06 INFO 433/1199
# 2023-09-03 18:32:06 INFO [433/1199] Shape: (767, 3)
# 2023-09-03 18:32:06 INFO 434/1199
# 2023-09-03 18:32:06 INFO [434/1199] Shape: (766, 3)
# 2023-09-03 18:32:06 INFO 435/1199
# 2023-09-03 18:32:06 INFO [435/1199] Shape: (765, 3)
# 2023-09-03 18:32:06 INFO 436/1199
# 2023-09-03 18:32:06 INFO [436/1199] Shape: (764, 3)
# 2023-09-03 18:32:06 INFO 437/1199
# 2023-09-03 18:32:06 INFO [437/1199] Shape: (763, 3)
# 2023-09-03 18:32:06 INFO 438/1199
# 2023-09-03 18:32:06 INFO [438/1199] Shape: (762, 3)
# 2023-09-03 18:32:06 INFO 439/1199
# 2023-09-03 18:32:06 INFO [439/1199] Shape: (761, 3)
# 2023-09-03 18:32:06 INFO 440/1199
# 2023-09-03 18:32:06 INFO [440/1199] Shape: (760, 3)
# 2023-09-03 18:32:06 INFO 441/1199
# 2023-09-03 18:32:06 INFO [441/1199] Shape: (759, 3)
# 2023-09-03 18:32:06 INFO 442/1199
# 2023-09-03 18:32:06 INFO [442/1199] Shape: (758, 3)
# 2023-09-03 18:32:06 INFO 443/1199
# 2023-09-03 18:32:06 INFO [443/1199] Shape: (757, 3)
# 2023-09-03 18:32:06 INFO 444/1199
# 2023-09-03 18:32:06 INFO [444/1199] Shape: (756, 3)
# 2023-09-03 18:32:06 INFO 445/1199
# 2023-09-03 18:32:06 INFO [445/1199] Shape: (755, 3)
# 2023-09-03 18:32:06 INFO 446/1199
# 2023-09-03 18:32:06 INFO [446/1199] Shape: (754, 3)
# 2023-09-03 18:32:06 INFO 447/1199
# 2023-09-03 18:32:06 INFO [447/1199] Shape: (753, 3)
# 2023-09-03 18:32:06 INFO 448/1199
# 2023-09-03 18:32:06 INFO [448/1199] Shape: (752, 3)
# 2023-09-03 18:32:06 INFO 449/1199
# 2023-09-03 18:32:06 INFO [449/1199] Shape: (751, 3)
# 2023-09-03 18:32:06 INFO 450/1199
# 2023-09-03 18:32:06 INFO [450/1199] Shape: (750, 3)
# 2023-09-03 18:32:06 INFO 451/1199
# 2023-09-03 18:32:06 INFO [451/1199] Shape: (749, 3)
# 2023-09-03 18:32:06 INFO 452/1199
# 2023-09-03 18:32:06 INFO [452/1199] Shape: (748, 3)
# 2023-09-03 18:32:06 INFO 453/1199
# 2023-09-03 18:32:06 INFO [453/1199] Shape: (747, 3)
# 2023-09-03 18:32:06 INFO 454/1199
# 2023-09-03 18:32:06 INFO [454/1199] Shape: (746, 3)
# 2023-09-03 18:32:06 INFO 455/1199
# 2023-09-03 18:32:06 INFO [455/1199] Shape: (745, 3)
# 2023-09-03 18:32:06 INFO 456/1199
# 2023-09-03 18:32:06 INFO [456/1199] Shape: (744, 3)
# 2023-09-03 18:32:06 INFO 457/1199
# 2023-09-03 18:32:06 INFO [457/1199] Shape: (743, 3)
# 2023-09-03 18:32:06 INFO 458/1199
# 2023-09-03 18:32:06 INFO [458/1199] Shape: (742, 3)
# 2023-09-03 18:32:06 INFO 459/1199
# 2023-09-03 18:32:06 INFO [459/1199] Shape: (741, 3)
# 2023-09-03 18:32:06 INFO 460/1199
# 2023-09-03 18:32:06 INFO [460/1199] Shape: (740, 3)
# 2023-09-03 18:32:06 INFO 461/1199
# 2023-09-03 18:32:06 INFO [461/1199] Shape: (739, 3)
# 2023-09-03 18:32:06 INFO 462/1199
# 2023-09-03 18:32:06 INFO [462/1199] Shape: (738, 3)
# 2023-09-03 18:32:06 INFO 463/1199
# 2023-09-03 18:32:06 INFO [463/1199] Shape: (737, 3)
# 2023-09-03 18:32:06 INFO 464/1199
# 2023-09-03 18:32:06 INFO [464/1199] Shape: (736, 3)
# 2023-09-03 18:32:06 INFO 465/1199
# 2023-09-03 18:32:06 INFO [465/1199] Shape: (735, 3)
# 2023-09-03 18:32:06 INFO 466/1199
# 2023-09-03 18:32:06 INFO [466/1199] Shape: (734, 3)
# 2023-09-03 18:32:06 INFO 467/1199
# 2023-09-03 18:32:06 INFO [467/1199] Shape: (733, 3)
# 2023-09-03 18:32:06 INFO 468/1199
# 2023-09-03 18:32:06 INFO [468/1199] Shape: (732, 3)
# 2023-09-03 18:32:06 INFO 469/1199
# 2023-09-03 18:32:06 INFO [469/1199] Shape: (731, 3)
# 2023-09-03 18:32:06 INFO 470/1199
# 2023-09-03 18:32:06 INFO [470/1199] Shape: (730, 3)
# 2023-09-03 18:32:06 INFO 471/1199
# 2023-09-03 18:32:06 INFO [471/1199] Shape: (729, 3)
# 2023-09-03 18:32:06 INFO 472/1199
# 2023-09-03 18:32:06 INFO [472/1199] Shape: (728, 3)
# 2023-09-03 18:32:06 INFO 473/1199
# 2023-09-03 18:32:06 INFO [473/1199] Shape: (727, 3)
# 2023-09-03 18:32:06 INFO 474/1199
# 2023-09-03 18:32:06 INFO [474/1199] Shape: (726, 3)
# 2023-09-03 18:32:06 INFO 475/1199
# 2023-09-03 18:32:06 INFO [475/1199] Shape: (725, 3)
# 2023-09-03 18:32:06 INFO 476/1199
# 2023-09-03 18:32:06 INFO [476/1199] Shape: (724, 3)
# 2023-09-03 18:32:06 INFO 477/1199
# 2023-09-03 18:32:06 INFO [477/1199] Shape: (723, 3)
# 2023-09-03 18:32:06 INFO 478/1199
# 2023-09-03 18:32:06 INFO [478/1199] Shape: (722, 3)
# 2023-09-03 18:32:06 INFO 479/1199
# 2023-09-03 18:32:06 INFO [479/1199] Shape: (721, 3)
# 2023-09-03 18:32:06 INFO 480/1199
# 2023-09-03 18:32:06 INFO [480/1199] Shape: (720, 3)
# 2023-09-03 18:32:06 INFO 481/1199
# 2023-09-03 18:32:06 INFO [481/1199] Shape: (719, 3)
# 2023-09-03 18:32:06 INFO 482/1199
# 2023-09-03 18:32:06 INFO [482/1199] Shape: (718, 3)
# 2023-09-03 18:32:06 INFO 483/1199
# 2023-09-03 18:32:06 INFO [483/1199] Shape: (717, 3)
# 2023-09-03 18:32:06 INFO 484/1199
# 2023-09-03 18:32:06 INFO [484/1199] Shape: (716, 3)
# 2023-09-03 18:32:06 INFO 485/1199
# 2023-09-03 18:32:06 INFO [485/1199] Shape: (715, 3)
# 2023-09-03 18:32:06 INFO 486/1199
# 2023-09-03 18:32:06 INFO [486/1199] Shape: (714, 3)
# 2023-09-03 18:32:06 INFO 487/1199
# 2023-09-03 18:32:06 INFO [487/1199] Shape: (713, 3)
# 2023-09-03 18:32:06 INFO 488/1199
# 2023-09-03 18:32:06 INFO [488/1199] Shape: (712, 3)
# 2023-09-03 18:32:06 INFO 489/1199
# 2023-09-03 18:32:06 INFO [489/1199] Shape: (711, 3)
# 2023-09-03 18:32:06 INFO 490/1199
# 2023-09-03 18:32:06 INFO [490/1199] Shape: (710, 3)
# 2023-09-03 18:32:06 INFO 491/1199
# 2023-09-03 18:32:06 INFO [491/1199] Shape: (709, 3)
# 2023-09-03 18:32:06 INFO 492/1199
# 2023-09-03 18:32:06 INFO [492/1199] Shape: (708, 3)
# 2023-09-03 18:32:06 INFO 493/1199
# 2023-09-03 18:32:06 INFO [493/1199] Shape: (707, 3)
# 2023-09-03 18:32:06 INFO 494/1199
# 2023-09-03 18:32:06 INFO [494/1199] Shape: (706, 3)
# 2023-09-03 18:32:06 INFO 495/1199
# 2023-09-03 18:32:06 INFO [495/1199] Shape: (705, 3)
# 2023-09-03 18:32:06 INFO 496/1199
# 2023-09-03 18:32:06 INFO [496/1199] Shape: (704, 3)
# 2023-09-03 18:32:06 INFO 497/1199
# 2023-09-03 18:32:06 INFO [497/1199] Shape: (703, 3)
# 2023-09-03 18:32:06 INFO 498/1199
# 2023-09-03 18:32:06 INFO [498/1199] Shape: (702, 3)
# 2023-09-03 18:32:06 INFO 499/1199
# 2023-09-03 18:32:06 INFO [499/1199] Shape: (701, 3)
# 2023-09-03 18:32:06 INFO 500/1199
# 2023-09-03 18:32:06 INFO [500/1199] Shape: (700, 3)
# 2023-09-03 18:32:06 INFO 501/1199
# 2023-09-03 18:32:06 INFO [501/1199] Shape: (699, 3)
# 2023-09-03 18:32:06 INFO 502/1199
# 2023-09-03 18:32:06 INFO [502/1199] Shape: (698, 3)
# 2023-09-03 18:32:06 INFO 503/1199
# 2023-09-03 18:32:06 INFO [503/1199] Shape: (697, 3)
# 2023-09-03 18:32:06 INFO 504/1199
# 2023-09-03 18:32:06 INFO [504/1199] Shape: (696, 3)
# 2023-09-03 18:32:06 INFO 505/1199
# 2023-09-03 18:32:06 INFO [505/1199] Shape: (695, 3)
# 2023-09-03 18:32:06 INFO 506/1199
# 2023-09-03 18:32:06 INFO [506/1199] Shape: (694, 3)
# 2023-09-03 18:32:06 INFO 507/1199
# 2023-09-03 18:32:06 INFO [507/1199] Shape: (693, 3)
# 2023-09-03 18:32:06 INFO 508/1199
# 2023-09-03 18:32:06 INFO [508/1199] Shape: (692, 3)
# 2023-09-03 18:32:06 INFO 509/1199
# 2023-09-03 18:32:06 INFO [509/1199] Shape: (691, 3)
# 2023-09-03 18:32:06 INFO 510/1199
# 2023-09-03 18:32:06 INFO [510/1199] Shape: (690, 3)
# 2023-09-03 18:32:06 INFO 511/1199
# 2023-09-03 18:32:06 INFO [511/1199] Shape: (689, 3)
# 2023-09-03 18:32:06 INFO 512/1199
# 2023-09-03 18:32:06 INFO [512/1199] Shape: (688, 3)
# 2023-09-03 18:32:06 INFO 513/1199
# 2023-09-03 18:32:06 INFO [513/1199] Shape: (687, 3)
# 2023-09-03 18:32:06 INFO 514/1199
# 2023-09-03 18:32:06 INFO [514/1199] Shape: (686, 3)
# 2023-09-03 18:32:06 INFO 515/1199
# 2023-09-03 18:32:06 INFO [515/1199] Shape: (685, 3)
# 2023-09-03 18:32:06 INFO 516/1199
# 2023-09-03 18:32:06 INFO [516/1199] Shape: (684, 3)
# 2023-09-03 18:32:06 INFO 517/1199
# 2023-09-03 18:32:06 INFO [517/1199] Shape: (683, 3)
# 2023-09-03 18:32:06 INFO 518/1199
# 2023-09-03 18:32:06 INFO [518/1199] Shape: (682, 3)
# 2023-09-03 18:32:06 INFO 519/1199
# 2023-09-03 18:32:06 INFO [519/1199] Shape: (681, 3)
# 2023-09-03 18:32:06 INFO 520/1199
# 2023-09-03 18:32:06 INFO [520/1199] Shape: (680, 3)
# 2023-09-03 18:32:06 INFO 521/1199
# 2023-09-03 18:32:06 INFO [521/1199] Shape: (679, 3)
# 2023-09-03 18:32:06 INFO 522/1199
# 2023-09-03 18:32:06 INFO [522/1199] Shape: (678, 3)
# 2023-09-03 18:32:06 INFO 523/1199
# 2023-09-03 18:32:06 INFO [523/1199] Shape: (677, 3)
# 2023-09-03 18:32:06 INFO 524/1199
# 2023-09-03 18:32:06 INFO [524/1199] Shape: (676, 3)
# 2023-09-03 18:32:06 INFO 525/1199
# 2023-09-03 18:32:06 INFO [525/1199] Shape: (675, 3)
# 2023-09-03 18:32:06 INFO 526/1199
# 2023-09-03 18:32:06 INFO [526/1199] Shape: (674, 3)
# 2023-09-03 18:32:06 INFO 527/1199
# 2023-09-03 18:32:06 INFO [527/1199] Shape: (673, 3)
# 2023-09-03 18:32:06 INFO 528/1199
# 2023-09-03 18:32:06 INFO [528/1199] Shape: (672, 3)
# 2023-09-03 18:32:06 INFO 529/1199
# 2023-09-03 18:32:06 INFO [529/1199] Shape: (671, 3)
# 2023-09-03 18:32:06 INFO 530/1199
# 2023-09-03 18:32:06 INFO [530/1199] Shape: (670, 3)
# 2023-09-03 18:32:06 INFO 531/1199
# 2023-09-03 18:32:06 INFO [531/1199] Shape: (669, 3)
# 2023-09-03 18:32:06 INFO 532/1199
# 2023-09-03 18:32:06 INFO [532/1199] Shape: (668, 3)
# 2023-09-03 18:32:06 INFO 533/1199
# 2023-09-03 18:32:06 INFO [533/1199] Shape: (667, 3)
# 2023-09-03 18:32:06 INFO 534/1199
# 2023-09-03 18:32:06 INFO [534/1199] Shape: (666, 3)
# 2023-09-03 18:32:06 INFO 535/1199
# 2023-09-03 18:32:06 INFO [535/1199] Shape: (665, 3)
# 2023-09-03 18:32:06 INFO 536/1199
# 2023-09-03 18:32:06 INFO [536/1199] Shape: (664, 3)
# 2023-09-03 18:32:06 INFO 537/1199
# 2023-09-03 18:32:06 INFO [537/1199] Shape: (663, 3)
# 2023-09-03 18:32:06 INFO 538/1199
# 2023-09-03 18:32:06 INFO [538/1199] Shape: (662, 3)
# 2023-09-03 18:32:06 INFO 539/1199
# 2023-09-03 18:32:06 INFO [539/1199] Shape: (661, 3)
# 2023-09-03 18:32:06 INFO 540/1199
# 2023-09-03 18:32:06 INFO [540/1199] Shape: (660, 3)
# 2023-09-03 18:32:06 INFO 541/1199
# 2023-09-03 18:32:06 INFO [541/1199] Shape: (659, 3)
# 2023-09-03 18:32:06 INFO 542/1199
# 2023-09-03 18:32:06 INFO [542/1199] Shape: (658, 3)
# 2023-09-03 18:32:06 INFO 543/1199
# 2023-09-03 18:32:06 INFO [543/1199] Shape: (657, 3)
# 2023-09-03 18:32:06 INFO 544/1199
# 2023-09-03 18:32:06 INFO [544/1199] Shape: (656, 3)
# 2023-09-03 18:32:06 INFO 545/1199
# 2023-09-03 18:32:06 INFO [545/1199] Shape: (655, 3)
# 2023-09-03 18:32:06 INFO 546/1199
# 2023-09-03 18:32:06 INFO [546/1199] Shape: (654, 3)
# 2023-09-03 18:32:06 INFO 547/1199
# 2023-09-03 18:32:06 INFO [547/1199] Shape: (653, 3)
# 2023-09-03 18:32:06 INFO 548/1199
# 2023-09-03 18:32:06 INFO [548/1199] Shape: (652, 3)
# 2023-09-03 18:32:06 INFO 549/1199
# 2023-09-03 18:32:06 INFO [549/1199] Shape: (651, 3)
# 2023-09-03 18:32:06 INFO 550/1199
# 2023-09-03 18:32:06 INFO [550/1199] Shape: (650, 3)
# 2023-09-03 18:32:06 INFO 551/1199
# 2023-09-03 18:32:06 INFO [551/1199] Shape: (649, 3)
# 2023-09-03 18:32:06 INFO 552/1199
# ...
# 2023-09-03 18:32:49 INFO 1521/1697
# 2023-09-03 18:32:49 INFO [1521/1697] Shape: (177, 3)
# 2023-09-03 18:32:49 INFO 1522/1697
# 2023-09-03 18:32:49 INFO [1522/1697] Shape: (176, 3)
# 2023-09-03 18:32:49 INFO 1523/1697
# 2023-09-03 18:32:49 INFO [1523/1697] Shape: (175, 3)
# 2023-09-03 18:32:49 INFO 1524/1697
# 2023-09-03 18:32:49 INFO [1524/1697] Shape: (174, 3)
# 2023-09-03 18:32:49 INFO 1525/1697
# 2023-09-03 18:32:49 INFO [1525/1697] Shape: (173, 3)
# 2023-09-03 18:32:49 INFO 1526/1697
# 2023-09-03 18:32:49 INFO [1526/1697] Shape: (172, 3)
# 2023-09-03 18:32:49 INFO 1527/1697
# 2023-09-03 18:32:49 INFO [1527/1697] Shape: (171, 3)
# 2023-09-03 18:32:49 INFO 1528/1697
# 2023-09-03 18:32:49 INFO [1528/1697] Shape: (170, 3)
# 2023-09-03 18:32:49 INFO 1529/1697
# 2023-09-03 18:32:49 INFO [1529/1697] Shape: (169, 3)
# 2023-09-03 18:32:49 INFO 1530/1697
# 2023-09-03 18:32:49 INFO [1530/1697] Shape: (168, 3)
# 2023-09-03 18:32:49 INFO 1531/1697
# 2023-09-03 18:32:49 INFO [1531/1697] Shape: (167, 3)
# 2023-09-03 18:32:49 INFO 1532/1697
# 2023-09-03 18:32:49 INFO [1532/1697] Shape: (166, 3)
# 2023-09-03 18:32:49 INFO 1533/1697
# 2023-09-03 18:32:49 INFO [1533/1697] Shape: (165, 3)
# 2023-09-03 18:32:49 INFO 1534/1697
# 2023-09-03 18:32:49 INFO [1534/1697] Shape: (164, 3)
# 2023-09-03 18:32:49 INFO 1535/1697
# 2023-09-03 18:32:49 INFO [1535/1697] Shape: (163, 3)
# 2023-09-03 18:32:49 INFO 1536/1697
# 2023-09-03 18:32:49 INFO [1536/1697] Shape: (162, 3)
# 2023-09-03 18:32:49 INFO 1537/1697
# 2023-09-03 18:32:49 INFO [1537/1697] Shape: (161, 3)
# 2023-09-03 18:32:49 INFO 1538/1697
# 2023-09-03 18:32:49 INFO [1538/1697] Shape: (160, 3)
# 2023-09-03 18:32:49 INFO 1539/1697
# 2023-09-03 18:32:49 INFO [1539/1697] Shape: (159, 3)
# 2023-09-03 18:32:49 INFO 1540/1697
# 2023-09-03 18:32:49 INFO [1540/1697] Shape: (158, 3)
# 2023-09-03 18:32:49 INFO 1541/1697
# 2023-09-03 18:32:49 INFO [1541/1697] Shape: (157, 3)
# 2023-09-03 18:32:49 INFO 1542/1697
# 2023-09-03 18:32:49 INFO [1542/1697] Shape: (156, 3)
# 2023-09-03 18:32:49 INFO 1543/1697
# 2023-09-03 18:32:49 INFO [1543/1697] Shape: (155, 3)
# 2023-09-03 18:32:49 INFO 1544/1697
# 2023-09-03 18:32:49 INFO [1544/1697] Shape: (154, 3)
# 2023-09-03 18:32:49 INFO 1545/1697
# 2023-09-03 18:32:49 INFO [1545/1697] Shape: (153, 3)
# 2023-09-03 18:32:49 INFO 1546/1697
# 2023-09-03 18:32:49 INFO [1546/1697] Shape: (152, 3)
# 2023-09-03 18:32:49 INFO 1547/1697
# 2023-09-03 18:32:49 INFO [1547/1697] Shape: (151, 3)
# 2023-09-03 18:32:49 INFO 1548/1697
# 2023-09-03 18:32:49 INFO [1548/1697] Shape: (150, 3)
# 2023-09-03 18:32:49 INFO 1549/1697
# 2023-09-03 18:32:49 INFO [1549/1697] Shape: (149, 3)
# 2023-09-03 18:32:49 INFO 1550/1697
# 2023-09-03 18:32:49 INFO [1550/1697] Shape: (148, 3)
# 2023-09-03 18:32:49 INFO 1551/1697
# 2023-09-03 18:32:49 INFO [1551/1697] Shape: (147, 3)
# 2023-09-03 18:32:49 INFO 1552/1697
# 2023-09-03 18:32:49 INFO [1552/1697] Shape: (146, 3)
# 2023-09-03 18:32:49 INFO 1553/1697
# 2023-09-03 18:32:49 INFO [1553/1697] Shape: (145, 3)
# 2023-09-03 18:32:49 INFO 1554/1697
# 2023-09-03 18:32:49 INFO [1554/1697] Shape: (144, 3)
# 2023-09-03 18:32:49 INFO 1555/1697
# 2023-09-03 18:32:49 INFO [1555/1697] Shape: (143, 3)
# 2023-09-03 18:32:49 INFO 1556/1697
# 2023-09-03 18:32:49 INFO [1556/1697] Shape: (142, 3)
# 2023-09-03 18:32:49 INFO 1557/1697
# 2023-09-03 18:32:49 INFO [1557/1697] Shape: (141, 3)
# 2023-09-03 18:32:49 INFO 1558/1697
# 2023-09-03 18:32:49 INFO [1558/1697] Shape: (140, 3)
# 2023-09-03 18:32:49 INFO 1559/1697
# 2023-09-03 18:32:49 INFO [1559/1697] Shape: (139, 3)
# 2023-09-03 18:32:49 INFO 1560/1697
# 2023-09-03 18:32:49 INFO [1560/1697] Shape: (138, 3)
# 2023-09-03 18:32:49 INFO 1561/1697
# 2023-09-03 18:32:49 INFO [1561/1697] Shape: (137, 3)
# 2023-09-03 18:32:49 INFO 1562/1697
# 2023-09-03 18:32:49 INFO [1562/1697] Shape: (136, 3)
# 2023-09-03 18:32:49 INFO 1563/1697
# 2023-09-03 18:32:49 INFO [1563/1697] Shape: (135, 3)
# 2023-09-03 18:32:49 INFO 1564/1697
# 2023-09-03 18:32:49 INFO [1564/1697] Shape: (134, 3)
# 2023-09-03 18:32:49 INFO 1565/1697
# 2023-09-03 18:32:49 INFO [1565/1697] Shape: (133, 3)
# 2023-09-03 18:32:49 INFO 1566/1697
# 2023-09-03 18:32:49 INFO [1566/1697] Shape: (132, 3)
# 2023-09-03 18:32:49 INFO 1567/1697
# 2023-09-03 18:32:49 INFO [1567/1697] Shape: (131, 3)
# 2023-09-03 18:32:49 INFO 1568/1697
# 2023-09-03 18:32:49 INFO [1568/1697] Shape: (130, 3)
# 2023-09-03 18:32:49 INFO 1569/1697
# 2023-09-03 18:32:49 INFO [1569/1697] Shape: (129, 3)
# 2023-09-03 18:32:49 INFO 1570/1697
# 2023-09-03 18:32:49 INFO [1570/1697] Shape: (128, 3)
# 2023-09-03 18:32:49 INFO 1571/1697
# 2023-09-03 18:32:49 INFO [1571/1697] Shape: (127, 3)
# 2023-09-03 18:32:49 INFO 1572/1697
# 2023-09-03 18:32:49 INFO [1572/1697] Shape: (126, 3)
# 2023-09-03 18:32:49 INFO 1573/1697
# 2023-09-03 18:32:49 INFO [1573/1697] Shape: (125, 3)
# 2023-09-03 18:32:49 INFO 1574/1697
# 2023-09-03 18:32:49 INFO [1574/1697] Shape: (124, 3)
# 2023-09-03 18:32:49 INFO 1575/1697
# 2023-09-03 18:32:49 INFO [1575/1697] Shape: (123, 3)
# 2023-09-03 18:32:49 INFO 1576/1697
# 2023-09-03 18:32:49 INFO [1576/1697] Shape: (122, 3)
# 2023-09-03 18:32:49 INFO 1577/1697
# 2023-09-03 18:32:49 INFO [1577/1697] Shape: (121, 3)
# 2023-09-03 18:32:50 INFO 1578/1697
# 2023-09-03 18:32:50 INFO [1578/1697] Shape: (120, 3)
# 2023-09-03 18:32:50 INFO 1579/1697
# 2023-09-03 18:32:50 INFO [1579/1697] Shape: (119, 3)
# 2023-09-03 18:32:50 INFO 1580/1697
# 2023-09-03 18:32:50 INFO [1580/1697] Shape: (118, 3)
# 2023-09-03 18:32:50 INFO 1581/1697
# 2023-09-03 18:32:50 INFO [1581/1697] Shape: (117, 3)
# 2023-09-03 18:32:50 INFO 1582/1697
# 2023-09-03 18:32:50 INFO [1582/1697] Shape: (116, 3)
# 2023-09-03 18:32:50 INFO 1583/1697
# 2023-09-03 18:32:50 INFO [1583/1697] Shape: (115, 3)
# 2023-09-03 18:32:50 INFO 1584/1697
# 2023-09-03 18:32:50 INFO [1584/1697] Shape: (114, 3)
# 2023-09-03 18:32:50 INFO 1585/1697
# 2023-09-03 18:32:50 INFO [1585/1697] Shape: (113, 3)
# 2023-09-03 18:32:50 INFO 1586/1697
# 2023-09-03 18:32:50 INFO [1586/1697] Shape: (112, 3)
# 2023-09-03 18:32:50 INFO 1587/1697
# 2023-09-03 18:32:50 INFO [1587/1697] Shape: (111, 3)
# 2023-09-03 18:32:50 INFO 1588/1697
# 2023-09-03 18:32:50 INFO [1588/1697] Shape: (110, 3)
# 2023-09-03 18:32:50 INFO 1589/1697
# 2023-09-03 18:32:50 INFO [1589/1697] Shape: (109, 3)
# 2023-09-03 18:32:50 INFO 1590/1697
# 2023-09-03 18:32:50 INFO [1590/1697] Shape: (108, 3)
# 2023-09-03 18:32:50 INFO 1591/1697
# 2023-09-03 18:32:50 INFO [1591/1697] Shape: (107, 3)
# 2023-09-03 18:32:50 INFO 1592/1697
# 2023-09-03 18:32:50 INFO [1592/1697] Shape: (106, 3)
# 2023-09-03 18:32:50 INFO 1593/1697
# 2023-09-03 18:32:50 INFO [1593/1697] Shape: (105, 3)
# 2023-09-03 18:32:50 INFO 1594/1697
# 2023-09-03 18:32:50 INFO [1594/1697] Shape: (104, 3)
# 2023-09-03 18:32:50 INFO 1595/1697
# 2023-09-03 18:32:50 INFO [1595/1697] Shape: (103, 3)
# 2023-09-03 18:32:50 INFO 1596/1697
# 2023-09-03 18:32:50 INFO [1596/1697] Shape: (102, 3)
# 2023-09-03 18:32:50 INFO 1597/1697
# 2023-09-03 18:32:50 INFO [1597/1697] Shape: (101, 3)
# 2023-09-03 18:32:50 INFO 1598/1697
# 2023-09-03 18:32:50 INFO [1598/1697] Shape: (100, 3)
# 2023-09-03 18:32:50 INFO 1599/1697
# 2023-09-03 18:32:50 INFO [1599/1697] Shape: (99, 3)
# 2023-09-03 18:32:50 INFO 1600/1697
# 2023-09-03 18:32:50 INFO [1600/1697] Shape: (98, 3)
# 2023-09-03 18:32:50 INFO 1601/1697
# 2023-09-03 18:32:50 INFO [1601/1697] Shape: (97, 3)
# 2023-09-03 18:32:50 INFO 1602/1697
# 2023-09-03 18:32:50 INFO [1602/1697] Shape: (96, 3)
# 2023-09-03 18:32:50 INFO 1603/1697
# 2023-09-03 18:32:50 INFO [1603/1697] Shape: (95, 3)
# 2023-09-03 18:32:50 INFO 1604/1697
# 2023-09-03 18:32:50 INFO [1604/1697] Shape: (94, 3)
# 2023-09-03 18:32:50 INFO 1605/1697
# 2023-09-03 18:32:50 INFO [1605/1697] Shape: (93, 3)
# 2023-09-03 18:32:50 INFO 1606/1697
# 2023-09-03 18:32:50 INFO [1606/1697] Shape: (92, 3)
# 2023-09-03 18:32:50 INFO 1607/1697
# 2023-09-03 18:32:50 INFO [1607/1697] Shape: (91, 3)
# 2023-09-03 18:32:50 INFO 1608/1697
# 2023-09-03 18:32:50 INFO [1608/1697] Shape: (90, 3)
# 2023-09-03 18:32:50 INFO 1609/1697
# 2023-09-03 18:32:50 INFO [1609/1697] Shape: (89, 3)
# 2023-09-03 18:32:50 INFO 1610/1697
# 2023-09-03 18:32:50 INFO [1610/1697] Shape: (88, 3)
# 2023-09-03 18:32:50 INFO 1611/1697
# 2023-09-03 18:32:50 INFO [1611/1697] Shape: (87, 3)
# 2023-09-03 18:32:50 INFO 1612/1697
# 2023-09-03 18:32:50 INFO [1612/1697] Shape: (86, 3)
# 2023-09-03 18:32:50 INFO 1613/1697
# 2023-09-03 18:32:50 INFO [1613/1697] Shape: (85, 3)
# 2023-09-03 18:32:50 INFO 1614/1697
# 2023-09-03 18:32:50 INFO [1614/1697] Shape: (84, 3)
# 2023-09-03 18:32:50 INFO 1615/1697
# 2023-09-03 18:32:50 INFO [1615/1697] Shape: (83, 3)
# 2023-09-03 18:32:50 INFO 1616/1697
# 2023-09-03 18:32:50 INFO [1616/1697] Shape: (82, 3)
# 2023-09-03 18:32:50 INFO 1617/1697
# 2023-09-03 18:32:50 INFO [1617/1697] Shape: (81, 3)
# 2023-09-03 18:32:50 INFO 1618/1697
# 2023-09-03 18:32:50 INFO [1618/1697] Shape: (80, 3)
# 2023-09-03 18:32:50 INFO 1619/1697
# 2023-09-03 18:32:50 INFO [1619/1697] Shape: (79, 3)
# 2023-09-03 18:32:50 INFO 1620/1697
# 2023-09-03 18:32:50 INFO [1620/1697] Shape: (78, 3)
# 2023-09-03 18:32:50 INFO 1621/1697
# 2023-09-03 18:32:50 INFO [1621/1697] Shape: (77, 3)
# 2023-09-03 18:32:50 INFO 1622/1697
# 2023-09-03 18:32:50 INFO [1622/1697] Shape: (76, 3)
# 2023-09-03 18:32:50 INFO 1623/1697
# 2023-09-03 18:32:50 INFO [1623/1697] Shape: (75, 3)
# 2023-09-03 18:32:50 INFO 1624/1697
# 2023-09-03 18:32:50 INFO [1624/1697] Shape: (74, 3)
# 2023-09-03 18:32:50 INFO 1625/1697
# 2023-09-03 18:32:50 INFO [1625/1697] Shape: (73, 3)
# 2023-09-03 18:32:50 INFO 1626/1697
# 2023-09-03 18:32:50 INFO [1626/1697] Shape: (72, 3)
# 2023-09-03 18:32:50 INFO 1627/1697
# 2023-09-03 18:32:50 INFO [1627/1697] Shape: (71, 3)
# 2023-09-03 18:32:50 INFO 1628/1697
# 2023-09-03 18:32:50 INFO [1628/1697] Shape: (70, 3)
# 2023-09-03 18:32:50 INFO 1629/1697
# 2023-09-03 18:32:50 INFO [1629/1697] Shape: (69, 3)
# 2023-09-03 18:32:50 INFO 1630/1697
# 2023-09-03 18:32:50 INFO [1630/1697] Shape: (68, 3)
# 2023-09-03 18:32:50 INFO 1631/1697
# 2023-09-03 18:32:50 INFO [1631/1697] Shape: (67, 3)
# 2023-09-03 18:32:50 INFO 1632/1697
# 2023-09-03 18:32:50 INFO [1632/1697] Shape: (66, 3)
# 2023-09-03 18:32:50 INFO 1633/1697
# 2023-09-03 18:32:50 INFO [1633/1697] Shape: (65, 3)
# 2023-09-03 18:32:50 INFO 1634/1697
# 2023-09-03 18:32:50 INFO [1634/1697] Shape: (64, 3)
# 2023-09-03 18:32:50 INFO 1635/1697
# 2023-09-03 18:32:50 INFO [1635/1697] Shape: (63, 3)
# 2023-09-03 18:32:50 INFO 1636/1697
# 2023-09-03 18:32:50 INFO [1636/1697] Shape: (62, 3)
# 2023-09-03 18:32:50 INFO 1637/1697
# 2023-09-03 18:32:50 INFO [1637/1697] Shape: (61, 3)
# 2023-09-03 18:32:50 INFO 1638/1697
# 2023-09-03 18:32:50 INFO [1638/1697] Shape: (60, 3)
# 2023-09-03 18:32:50 INFO 1639/1697
# 2023-09-03 18:32:50 INFO [1639/1697] Shape: (59, 3)
# 2023-09-03 18:32:50 INFO 1640/1697
# 2023-09-03 18:32:50 INFO [1640/1697] Shape: (58, 3)
# 2023-09-03 18:32:50 INFO 1641/1697
# 2023-09-03 18:32:50 INFO [1641/1697] Shape: (57, 3)
# 2023-09-03 18:32:50 INFO 1642/1697
# 2023-09-03 18:32:50 INFO [1642/1697] Shape: (56, 3)
# 2023-09-03 18:32:50 INFO 1643/1697
# 2023-09-03 18:32:50 INFO [1643/1697] Shape: (55, 3)
# 2023-09-03 18:32:50 INFO 1644/1697
# 2023-09-03 18:32:50 INFO [1644/1697] Shape: (54, 3)
# 2023-09-03 18:32:50 INFO 1645/1697
# 2023-09-03 18:32:50 INFO [1645/1697] Shape: (53, 3)
# 2023-09-03 18:32:50 INFO 1646/1697
# 2023-09-03 18:32:50 INFO [1646/1697] Shape: (52, 3)
# 2023-09-03 18:32:50 INFO 1647/1697
# 2023-09-03 18:32:50 INFO [1647/1697] Shape: (51, 3)
# 2023-09-03 18:32:50 INFO 1648/1697
# 2023-09-03 18:32:50 INFO [1648/1697] Shape: (50, 3)
# 2023-09-03 18:32:50 INFO 1649/1697
# 2023-09-03 18:32:50 INFO [1649/1697] Shape: (49, 3)
# 2023-09-03 18:32:50 INFO 1650/1697
# 2023-09-03 18:32:50 INFO [1650/1697] Shape: (48, 3)
# 2023-09-03 18:32:50 INFO 1651/1697
# 2023-09-03 18:32:50 INFO [1651/1697] Shape: (47, 3)
# 2023-09-03 18:32:50 INFO 1652/1697
# 2023-09-03 18:32:50 INFO [1652/1697] Shape: (46, 3)
# 2023-09-03 18:32:50 INFO 1653/1697
# 2023-09-03 18:32:50 INFO [1653/1697] Shape: (45, 3)
# 2023-09-03 18:32:50 INFO 1654/1697
# 2023-09-03 18:32:50 INFO [1654/1697] Shape: (44, 3)
# 2023-09-03 18:32:50 INFO 1655/1697
# 2023-09-03 18:32:50 INFO [1655/1697] Shape: (43, 3)
# 2023-09-03 18:32:50 INFO 1656/1697
# 2023-09-03 18:32:50 INFO [1656/1697] Shape: (42, 3)
# 2023-09-03 18:32:50 INFO 1657/1697
# 2023-09-03 18:32:50 INFO [1657/1697] Shape: (41, 3)
# 2023-09-03 18:32:50 INFO 1658/1697
# 2023-09-03 18:32:50 INFO [1658/1697] Shape: (40, 3)
# 2023-09-03 18:32:50 INFO 1659/1697
# 2023-09-03 18:32:50 INFO [1659/1697] Shape: (39, 3)
# 2023-09-03 18:32:50 INFO 1660/1697
# 2023-09-03 18:32:50 INFO [1660/1697] Shape: (38, 3)
# 2023-09-03 18:32:50 INFO 1661/1697
# 2023-09-03 18:32:50 INFO [1661/1697] Shape: (37, 3)
# 2023-09-03 18:32:50 INFO 1662/1697
# 2023-09-03 18:32:50 INFO [1662/1697] Shape: (36, 3)
# 2023-09-03 18:32:50 INFO 1663/1697
# 2023-09-03 18:32:50 INFO [1663/1697] Shape: (35, 3)
# 2023-09-03 18:32:50 INFO 1664/1697
# 2023-09-03 18:32:50 INFO [1664/1697] Shape: (34, 3)
# 2023-09-03 18:32:50 INFO 1665/1697
# 2023-09-03 18:32:50 INFO [1665/1697] Shape: (33, 3)
# 2023-09-03 18:32:50 INFO 1666/1697
# 2023-09-03 18:32:50 INFO [1666/1697] Shape: (32, 3)
# 2023-09-03 18:32:50 INFO 1667/1697
# 2023-09-03 18:32:50 INFO [1667/1697] Shape: (31, 3)
# 2023-09-03 18:32:50 INFO 1668/1697
# 2023-09-03 18:32:50 INFO [1668/1697] Shape: (30, 3)
# 2023-09-03 18:32:50 INFO 1669/1697
# 2023-09-03 18:32:50 INFO [1669/1697] Shape: (29, 3)
# 2023-09-03 18:32:50 INFO 1670/1697
# 2023-09-03 18:32:50 INFO [1670/1697] Shape: (28, 3)
# 2023-09-03 18:32:50 INFO 1671/1697
# 2023-09-03 18:32:50 INFO [1671/1697] Shape: (27, 3)
# 2023-09-03 18:32:50 INFO 1672/1697
# 2023-09-03 18:32:50 INFO [1672/1697] Shape: (26, 3)
# 2023-09-03 18:32:50 INFO 1673/1697
# 2023-09-03 18:32:50 INFO [1673/1697] Shape: (25, 3)
# 2023-09-03 18:32:50 INFO 1674/1697
# 2023-09-03 18:32:50 INFO [1674/1697] Shape: (24, 3)
# 2023-09-03 18:32:50 INFO 1675/1697
# 2023-09-03 18:32:50 INFO [1675/1697] Shape: (23, 3)
# 2023-09-03 18:32:50 INFO 1676/1697
# 2023-09-03 18:32:50 INFO [1676/1697] Shape: (22, 3)
# 2023-09-03 18:32:50 INFO 1677/1697
# 2023-09-03 18:32:50 INFO [1677/1697] Shape: (21, 3)
# 2023-09-03 18:32:50 INFO 1678/1697
# 2023-09-03 18:32:50 INFO [1678/1697] Shape: (20, 3)
# 2023-09-03 18:32:50 INFO 1679/1697
# 2023-09-03 18:32:50 INFO [1679/1697] Shape: (19, 3)
# 2023-09-03 18:32:50 INFO 1680/1697
# 2023-09-03 18:32:50 INFO [1680/1697] Shape: (18, 3)
# 2023-09-03 18:32:50 INFO 1681/1697
# 2023-09-03 18:32:50 INFO [1681/1697] Shape: (17, 3)
# 2023-09-03 18:32:50 INFO 1682/1697
# 2023-09-03 18:32:50 INFO [1682/1697] Shape: (16, 3)
# 2023-09-03 18:32:50 INFO 1683/1697
# 2023-09-03 18:32:50 INFO [1683/1697] Shape: (15, 3)
# 2023-09-03 18:32:50 INFO 1684/1697
# 2023-09-03 18:32:50 INFO [1684/1697] Shape: (14, 3)
# 2023-09-03 18:32:50 INFO 1685/1697
# 2023-09-03 18:32:50 INFO [1685/1697] Shape: (13, 3)
# 2023-09-03 18:32:50 INFO 1686/1697
# 2023-09-03 18:32:50 INFO [1686/1697] Shape: (12, 3)
# 2023-09-03 18:32:50 INFO 1687/1697
# 2023-09-03 18:32:50 INFO [1687/1697] Shape: (11, 3)
# 2023-09-03 18:32:50 INFO 1688/1697
# 2023-09-03 18:32:50 INFO [1688/1697] Shape: (10, 3)
# 2023-09-03 18:32:50 INFO 1689/1697
# 2023-09-03 18:32:50 INFO [1689/1697] Shape: (9, 3)
# 2023-09-03 18:32:50 INFO 1690/1697
# 2023-09-03 18:32:50 INFO [1690/1697] Shape: (8, 3)
# 2023-09-03 18:32:50 INFO 1691/1697
# 2023-09-03 18:32:50 INFO [1691/1697] Shape: (7, 3)
# 2023-09-03 18:32:50 INFO 1692/1697
# 2023-09-03 18:32:50 INFO [1692/1697] Shape: (6, 3)
# 2023-09-03 18:32:50 INFO 1693/1697
# 2023-09-03 18:32:50 INFO [1693/1697] Shape: (5, 3)
# 2023-09-03 18:32:50 INFO 1694/1697
# 2023-09-03 18:32:50 INFO [1694/1697] Shape: (4, 3)
# 2023-09-03 18:32:50 INFO 1695/1697
# 2023-09-03 18:32:50 INFO [1695/1697] Shape: (3, 3)
# 2023-09-03 18:32:50 INFO 1696/1697
# 2023-09-03 18:32:50 INFO [1696/1697] Shape: (2, 3)
# 2023-09-03 18:32:50 INFO 1697/1697
# 2023-09-03 18:32:50 INFO [1697/1697] Shape: (1, 3)
# 2023-09-03 18:32:50 INFO [WT_stress] embeddings shape: (1697, 40000)
# [ANXA11] Save to dict
# [ANXA11] UMAP...
# embeddings_marker shape:  (14115, 40000) (14115, 40000)
# !!!!!!!!! TAKING ONLY FIRST 10000 FEATURES since otherwise there for bigger numbers there is an error (cannot assign slice from input of different size) !!!!!!
# [ANXA11] Print X to dict..
# [ANXA11] Init model
# [ANXA11] fit_eval
# X_train shape (11292, 100), X_test shape: (2823, 100), y_train shape: (11292,), y_test shape: (2823,)

# %%
for l in unique_ll[len(unique_ll):]:
    marker = l.split('_')[-1]
    print('---------------------')
    print(f"Marker: {marker}")
    print('---------------------')
    marker_indexes = np.where(np.char.endswith(labels_npy, f'_{marker}'))[0]
    embeddings_marker, labels_marker = embeddings[marker_indexes], labels_npy[marker_indexes]
    
    print(np.unique(labels_marker))
    print(f"[{marker}] embeddings_marker shape: {embeddings_marker.shape}, labels_marker shape: {labels_marker.shape}")
    
    print(f"[{marker}] SM")
    df = synthetic_multiplexing.__embeddings_to_df(embeddings_marker, labels_marker.reshape(-1,), dataset_conf=config_data)
    embeddings_marker, y_marker, unique_groups_marker = synthetic_multiplexing.__get_multiplexed_embeddings(df, random_state=config_data.SEED)

    print(f"[{marker}] Save to dict")
    sm_dict[marker] = {'embeddings': embeddings_marker, 'y': y_marker, 'unique_groups': unique_groups_marker}

    print(f"[{marker}] UMAP...")
    reducer = UMAP(n_components=100, random_state=1)
    X_marker = reducer.fit_transform(embeddings_marker.reshape(embeddings_marker.shape[0], -1))
    
    print(f"[{marker}] Print X to dict..")
    sm_dict[marker]['X'] = X_marker
    
    print(f"[{marker}] Init model")
    mlp = MLPClassifier(hidden_layer_sizes=(20,), activation='relu', random_state=1)
    # rfc = RandomForestClassifier(n_estimators=10, max_depth=3, random_state=1)
    
    print(f"[{marker}] fit_eval")
    fit_eval(mlp, X_marker, y_marker)

# %% [markdown]
# -------------------------

# %% [markdown]
# # Multiplex

# %%
print(embeddings.shape)

# %%
df = synthetic_multiplexing.__embeddings_to_df(embeddings, labels.reshape(-1,), dataset_conf=config_data)
embeddings, y, unique_groups = synthetic_multiplexing.__get_multiplexed_embeddings(df, random_state=config_data.SEED)

# %%
np.save("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b5_vqvec1", embeddings)
np.save("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_labels_b5_vqvec1", y)

# %%
embeddings9 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b9_vqvec1.npy")
y9 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_labels_b9_vqvec1.npy")
embeddings9.shape, y9.shape

# %%
embeddings5 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b5_vqvec1.npy")
y5 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_labels_b5_vqvec1.npy")
embeddings5.shape, y5.shape

# %%
embeddings.shape

# %% [markdown]
# # Dim reduction

# %%
# from sklearn.manifold import MDS
# from umap import UMAP

# reducer = UMAP(n_components=100, random_state=1)#, max_iter=10)
# # reducer.fit(embeddings.reshape(embeddings.shape[0], -1))
# # print(reducer.explained_variance_ratio_)
# reducer.fit(embeddings9.reshape(embeddings9.shape[0], -1))
# X9 = reducer.transform(embeddings9.reshape(embeddings9.shape[0], -1))
# X5 = reducer.transform(embeddings5.reshape(embeddings5.shape[0], -1))

# X9.shape, X5.shape

# %%
# from sklearn.manifold import MDS
# from umap import UMAP

# reducer = UMAP(n_components=100, random_state=1)#, max_iter=10)
# # reducer.fit(embeddings.reshape(embeddings.shape[0], -1))
# # print(reducer.explained_variance_ratio_)
# X = reducer.fit_transform(embeddings.reshape(embeddings.shape[0], -1))
# X.shape

# %% [markdown]
# --------

# %% [markdown]
# #### Save to file

# %%
np.save("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b5_vqvec1_umap100", X)
# np.save("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/mul_label_all_all", label_data)

# %% [markdown]
# #### Load from file

# %%
X9 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b9_new_umap100.npy")
y9 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_labels_b9_new.npy")
X9.shape, y9.shape

# %%
X5 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_embeddings_b5_umap100.npy")
y5 = np.load("/home/labs/hornsteinlab/Collaboration/MOmaps_Sagy/MOmaps/sandbox/sm_labels_b5.npy")
X5.shape, y5.shape

# %% [markdown]
# ### Models

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(20,), activation='relu', random_state=1)
# mlp.fit(X_train, y_train)

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=10, max_depth=3, random_state=1)
# rfc.fit(X_train, y_train)

# %% [markdown]
# ### Eval

# %%
mlp = mlp.fit(X9, y9)

# %%
val_classifier(mlp, X5, y5.reshape(-1,), np.unique(y5.reshape(-1,)))

# %% [markdown]
# ### Fit & Eval

# %% [markdown]
# #### vqvec1

# %%
fit_eval(mlp, X, y)

# %%
fit_eval(mlp, X, y)

# %% [markdown]
# #### vqvec2

# %%
fit_eval(mlp, X, y)

# %%
fit_eval(mlp, X, y)

# %% [markdown]
# #### y shuffled

# %% [markdown]
# ##### vqvec1

# %%
y_shuffled = np.copy(y)
np.random.shuffle(y_shuffled)
fit_eval(rfc, X, y_shuffled)

# %% [markdown]
# ##### vqvec2

# %%
y_shuffled = np.copy(y)
np.random.shuffle(y_shuffled)
fit_eval(mlp, X, y_shuffled)

# %% [markdown]
# ---------------------

# %% [markdown]
# # Old

# %%
# from sklearn.model_selection import StratifiedKFold

# clf = mlp
# unique_labels = np.unique(y)

# skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
# result = fit_and_plot_multiclass_cv_auc_roc_curves(clf, skf, X_train, y_train,
#                                                     n_classes=len(unique_labels),
#                                                     class_names=unique_labels,
#                                                     colors=plt.cm.get_cmap('Set1', len(unique_labels)).colors,
#                                                     title='ROC multi-class one-vs-rest in training')

# print("\n\nTraining dataset (75%): K-Fold Cross Validation score: " + str(model_scorer) + " " + str(
#     result) + " Mean: " + str(result.mean()))

# %%
# clf_trained = clf.fit(X_train, y_train)
# validate_classifier(clf_trained, X_test, y_test, 'roc_auc_ovr_weighted',
#                     unique_labels, sample_weight=None, colors=plt.cm.get_cmap('Set1', len(unique_labels)).colors,
#                     title='Validate classifier', show_plot=True)

# %% [markdown]
# -----------------------

# %% [markdown]
# # Plot

# %%
groups = np.unique(labels_flat)
colors = cm.get_cmap('Set1').colors

for i, g in enumerate(groups):
    ind = np.where(labels_flat == g)
    plt.scatter(x[ind,0], x[ind,1], c=colors[i])
plt.legend(groups)
plt.show()

# %%
groups = np.unique(labels_flat)
colors = cm.get_cmap('Set1').colors

for i, g in enumerate(groups):
    ind = np.where(labels_flat == g)
    plt.scatter(x[ind,0], x[ind,1], c=colors[i])
plt.legend(groups)
plt.show()

# %%
groups = np.unique(labels_flat)
colors = cm.get_cmap('Set1').colors

for i, g in enumerate(groups):
    ind = np.where(labels_flat == g)
    plt.scatter(x[ind,0], x[ind,1], c=colors[i])
plt.legend(groups)
plt.show()

# %%
# 50 umaps
groups = np.unique(labels_flat)
colors = cm.get_cmap('Set1').colors

for i, g in enumerate(groups):
    ind = np.where(labels_flat == g)
    plt.scatter(x[ind,0], x[ind,1], c=colors[i])
plt.legend(groups)
plt.show()

# %%
# 50 umaps multi
groups = np.unique(label_data.reshape(-1,))
colors = cm.get_cmap('Set1').colors

for i, g in enumerate(groups):
    ind = np.where(label_data.reshape(-1,) == g)
    plt.scatter(x[ind,0], x[ind,1], c=colors[i])
plt.legend(groups)
plt.show()

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split
labels_flat = label_data.reshape(-1,)
X_train, X_test, y_train, y_test = train_test_split(x, labels_flat, test_size=.2, stratify=labels_flat, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', random_state=1)
mlp.fit(X_train, y_train)

# %%
mlp.n_layers_

# %%
# for i in range(5):
#     print(mlp.predict(X_test[[i]]), y_test[i])

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=20, max_depth=3, random_state=1)
rfc.fit(X_train, y_train)

# %% [markdown]
# ### Plots

# %%
    # for i, l in enumerate(unique_labels):
    #     print(l)
    #     disp = ConfusionMatrixDisplay(conf_matrix[i])
    #     disp.plot()
    #     plt.show()

# %%
plot_conf_matrix(rfc, 'true')

# %%
plot_conf_matrix(rfc, 'true')

# %%
plot_conf_matrix(mlp, 'true')

# %%
plot_conf_matrix(rfc, 'true')

# %%
plot_conf_matrix(mlp, 'true')

# %% [markdown]
# ### Utils

# %% [markdown]
# ### Reports

# %%
def cv_report(get_clf, x, labels_flat):
    from sklearn.metrics import classification_report
    from sklearn.model_selection import StratifiedKFold

    skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
    for i, (train_index, test_index) in enumerate(skf.split(x, labels_flat)):
        print(i)
        print(train_index[:2], test_index[:2])
        x_train, y_train = x[train_index], labels_flat[train_index]
        x_test, y_test = x[test_index], labels_flat[test_index]

        print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

        clf = get_clf() #MLPClassifier(hidden_layer_sizes=(50,), activation='relu', random_state=1)
        clf.fit(x_train, y_train)

        predictions = clf.predict(x_test)
        print(classification_report(y_test, predictions))

# %%
from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
fit_and_plot_multiclass_cv_auc_roc_curves(mlp, skf, x, labels_flat)

# %%
cv_report(lambda : MLPClassifier(hidden_layer_sizes=(50,), activation='relu', random_state=1), x, labels_flat)

# %%
# from sklearn.metrics import classification_report
# from sklearn.model_selection import StratifiedKFold

# skf = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
# for i, (train_index, test_index) in enumerate(skf.split(x, labels_flat)):
#     print(i)
#     print(train_index[:2], test_index[:2])
#     x_train, y_train = x[train_index], labels_flat[train_index]
#     x_test, y_test = x[test_index], labels_flat[test_index]

#     print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

#     mlp = MLPClassifier(hidden_layer_sizes=(50,), activation='relu', random_state=1)
#     mlp.fit(x_train, y_train)

#     predictions = mlp.predict(x_test)
#     print(classification_report(y_test, predictions))

# %% [markdown]
# ### 2 UMAPS

# %%
plot_conf_matrix(mlp)

# %%
plot_conf_matrix(rfc)

# %% [markdown]
# ### 100 UMAPS

# %%
plot_conf_matrix(mlp)

# %%
plot_conf_matrix(rfc)

# %% [markdown]
# # PLOTS old

# %%
plot_conf_matrix(rfc)

# %%
plot_conf_matrix(mlp)

# %%
plot_conf_matrix(rfc)

# %%
plot_conf_matrix(mlp)

# %%
plot_conf_matrix(rfc)

# %%
# def plot_conf_matrix(clf):
#     from sklearn.metrics import ConfusionMatrixDisplay, multilabel_confusion_matrix, confusion_matrix

#     unique_labels = np.unique(mlp.classes_)

#     predictions = clf.predict(X_test)
#     conf_matrix = confusion_matrix(y_test, predictions, labels=unique_labels)

#     import seaborn as sns

#     sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
#     plt.show()
#     # for i, l in enumerate(unique_labels):
#     #     print(l)
#     #     disp = ConfusionMatrixDisplay(conf_matrix[i])
#     #     disp.plot()
#     #     plt.show()
    
# # plot_conf_matrix(rfc)

# %%
#50 umaps
def plot_conf_matrix(clf):
    from sklearn.metrics import ConfusionMatrixDisplay, multilabel_confusion_matrix, confusion_matrix

    unique_labels = np.unique(mlp.classes_)

    predictions = clf.predict(X_test)
    conf_matrix = confusion_matrix(y_test, predictions, labels=unique_labels)

    import seaborn as sns

    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
    plt.show()
    # for i, l in enumerate(unique_labels):
    #     print(l)
    #     disp = ConfusionMatrixDisplay(conf_matrix[i])
    #     disp.plot()
    #     plt.show()
    
plot_conf_matrix(rfc)

# %%
#Multiplex

def plot_conf_matrix(clf):
    from sklearn.metrics import ConfusionMatrixDisplay, multilabel_confusion_matrix, confusion_matrix

    unique_labels = np.unique(mlp.classes_)

    predictions = clf.predict(X_test)
    conf_matrix = confusion_matrix(y_test, predictions, labels=unique_labels)

    import seaborn as sns

    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=unique_labels, yticklabels=unique_labels)
    plt.show()
    # for i, l in enumerate(unique_labels):
    #     print(l)
    #     disp = ConfusionMatrixDisplay(conf_matrix[i])
    #     disp.plot()
    #     plt.show()
    
plot_conf_matrix(rfc)

# %%
#multi 50umaps
plot_conf_matrix(mlp)

# %%
plot_conf_matrix(mlp)

# %%
#50umaps
plot_conf_matrix(mlp)

# %%
from xgboost import XGBClassifier

# create model instance
bst = XGBClassifier(n_estimators=20, max_depth=4, learning_rate=0.1, objective='multi:softmax')
# fit model
bst.fit(X_train, y_train)
# # make predictions
# preds = bst.predict(X_test)
