# %% [markdown]
# # <font color="red"> CellProfiler: profiling of P-Bodies (DCP1A, LSM14A) Sorbitol Experiment across all batches </font>
#
# JIRA task: NN-151

# %% [markdown]
# Why Linear Mixed-Effects Models (LMMs)?
# Your experimental structure involves:
#
# - Two groups: dNLS_Untreated vs dNLS_DOX
#
# - 5 batches per group
#
# - Measurements per site image (the dependent variable), 50–250 site images per batch (i.e., image-level measurements)
#
#
# - Random variation across batches random intercept per batch (i.e., variation across batches)
#
# This design includes both fixed effects (groups) and random effects (batches)
# Estimate how dNLS_DOX affects each CellProfiler feature vs dNLS_Untreated, accounting for batch effects (inter-batch variation).

# %%
from pathlib import Path
import glob
import sys
import os


os.environ['NOVA_HOME'] = '/home/projects/hornsteinlab/Collaboration/NOVA/'
os.environ['NOVA_DATA_HOME'] = f"{os.environ['NOVA_HOME']}/input"
print('NOVA_HOME is at', os.getenv('NOVA_HOME'))
sys.path.insert(1, os.getenv('NOVA_HOME'))


import numpy as np
import pandas as pd
import seaborn as sns
from markdown import markdown
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

from cell_profiler.code.cp_effect_size_utils import CP_OUTPUTS_FOLDER, validate_cp_files, extract_path_parts, merge_on_group, collect_cp_results_by_cell_line, load_cp_results, get_features_per_image, get_aggregated_features_per_image, collect_all_features, run_analysis_generate_report, print_mixedlm_conclusions, plot_cp_feature_grouped_by_gene, measures_to_plot
from manuscript.plot_config import PlotConfig

# %load_ext autoreload    
# %autoreload 2
# Out:
# NOVA_HOME is at /home/projects/hornsteinlab/Collaboration/NOVA/

# %% [markdown]
# # New Sorbitol Experiment dataset - DCP1A

# %%
ANALYSIS_TYPE = 'PB_profiling/Sorbitol_DCP1A'

BATCHES = ['batch1', 'batch2', 'batch3']

# Save figures here
save_path = '/home/projects/hornsteinlab/Collaboration/NOVA/outputs/vit_models/finetunedModel_MLPHead_acrossBatches_B56789_80pct_frozen/figures/Sorbitol/cell_profiler/PB_profiling/Sorbitol_DCP1A'

_color_mapping = {'WT_Untreated':{'alias':'Wild-Type', 'color':'#37AFD7'},
                'WT_stress':{'alias':'Stress', 'color':'#11AFD7'}}

# %%
group_by_columns = ['ImageNumber', 'batch', 'rep', 'cell_line', 'condition']
REQUIRED_FILES = ['Image.csv', 'Pbodies.csv', 'Cytoplasm.csv']

# %%
# Test CP outputs (number of images)
if True:
    pattern = os.path.join(CP_OUTPUTS_FOLDER, ANALYSIS_TYPE, '*', '*', '*', '*', '*', '*')
    # store marker folders by cell line
    for marker_path in glob.glob(pattern):
        if os.path.isdir(marker_path):
            try:
                image_df = pd.read_csv(marker_path +'/Image.csv')
                #print(marker_path, image_df.shape)
                #print(image_df[['Count_Pbodies', 'Count_nucleus']].head(10))
                
                # DEBUG CODE: to recognise problems in CP wiriting to the wrong folder
                # parts_df = image_df['PathName_nucleus'].apply(extract_path_parts)
                parts_df = image_df['PathName_DAPI'].apply(extract_path_parts)
                
                print(marker_path, parts_df['batch'].unique(), parts_df['cell_line'].unique(), parts_df['condition'].unique(), parts_df['rep'].unique(), )
                # DEBUG CODE

                marker = os.path.basename(marker_path)    
                cell_line = Path(marker_path).resolve().parents[3].name
            except FileNotFoundError as e:
                print("!!!!")
                print(e)
        else:
            print(f"Not a marker folder directory:{marker_path}")
# Out:
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/stress/rep3/DCP1A ['batch3'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/stress/rep4/DCP1A ['batch3'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/stress/rep1/DCP1A ['batch3'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/stress/rep2/DCP1A ['batch3'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/Untreated/rep3/DCP1A ['batch3'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/Untreated/rep4/DCP1A ['batch3'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/Untreated/rep1/DCP1A ['batch3'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch3/WT/panelA/Untreated/rep2/DCP1A ['batch3'] ['WT'] ['Untreated'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/stress/rep3/DCP1A ['batch2'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/stress/rep4/DCP1A ['batch2'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/stress/rep1/DCP1A ['batch2'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/stress/rep2/DCP1A ['batch2'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/Untreated/rep3/DCP1A ['batch2'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/Untreated/rep4/DCP1A ['batch2'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/Untreated/rep1/DCP1A ['batch2'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch2/WT/panelA/Untreated/rep2/DCP1A ['batch2'] ['WT'] ['Untreated'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/stress/rep3/DCP1A ['batch1'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/stress/rep4/DCP1A ['batch1'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/stress/rep1/DCP1A ['batch1'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/stress/rep2/DCP1A ['batch1'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/Untreated/rep3/DCP1A ['batch1'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/Untreated/rep4/DCP1A ['batch1'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/Untreated/rep1/DCP1A ['batch1'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/batch1/WT/panelA/Untreated/rep2/DCP1A ['batch1'] ['WT'] ['Untreated'] ['rep2']

# %% [markdown]
# ## Collect CP files by "cell_line+condition" and Load CP data

# %%
# Collect paths of CP output files
paths_by_cell_line = collect_cp_results_by_cell_line(ANALYSIS_TYPE, include_condition=True)

# %%
# Load CP data
cp_data = load_cp_results(paths_by_cell_line, REQUIRED_FILES)
# Out:
# number of subjects from cell line WT_stress: 12
# number of subjects from cell line WT_Untreated: 12

# %%
# Get the calculated features from all CP output files
cp_measurements = collect_all_features(cp_data, group_by_columns)
# Out:
# WT_stress (2674, 6) (2674, 32) (2674, 18)
# (2674, 33)
# (2674, 46)
# WT_Untreated (2823, 6) (2823, 32) (2823, 18)
# (2823, 33)
# (2823, 46)
# Shape after merging is: (5497, 46)

# %%
cp_measurements
# Out:
#       ImageNumber   batch   rep cell_line  condition     num_pb  \
# 0               1  batch1  rep1        WT     stress  10.282051
# 1               1  batch1  rep2        WT     stress  17.275862
# 2               1  batch1  rep3        WT     stress  12.117647
# 3               1  batch1  rep4        WT     stress  14.466667
# 4               1  batch2  rep1        WT     stress  14.593750
# ...           ...     ...   ...       ...        ...        ...
# 5492          246  batch2  rep4        WT  Untreated   8.545455
# 5493          247  batch2  rep2        WT  Untreated  10.511628
# 5494          247  batch2  rep4        WT  Untreated  11.441176
# 5495          248  batch2  rep2        WT  Untreated   8.490909
# 5496          249  batch2  rep2        WT  Untreated   7.283582
#
#       mean_AreaShape_Area  mean_AreaShape_Compactness  \
# 0               25.271820                    0.792330
# 1               23.950100                    0.795016
# 2               23.347087                    0.772651
# 3               25.951613                    0.818639
# 4               24.182013                    0.792462
# ...                   ...                         ...
# 5492            24.319149                    0.763612
# 5493            24.796460                    0.782070
# 5494            26.406170                    0.799506
# 5495            23.231263                    0.761080
# 5496            24.483607                    0.764627
#
#       mean_AreaShape_Eccentricity  mean_AreaShape_EquivalentDiameter  ...  \
# 0                        0.564398                           5.464352  ...
# 1                        0.568774                           5.295376  ...
# 2                        0.539623                           5.230422  ...
# 3                        0.582715                           5.526321  ...
# 4                        0.561082                           5.336245  ...
# ...                           ...                                ...  ...
# 5492                     0.488463                           5.355413  ...
# 5493                     0.539933                           5.379492  ...
# 5494                     0.518545                           5.593704  ...
# 5495                     0.481098                           5.257826  ...
# 5496                     0.473272                           5.379942  ...
#
#       mean_Math_Texture_Contrast_DCP1A_pb_only_5  \
# 0                                     135.814722
# 1                                      65.387192
# 2                                     134.867132
# 3                                      72.692730
# 4                                     131.725029
# ...                                          ...
# 5492                                   91.299167
# 5493                                   91.603439
# 5494                                  111.579842
# 5495                                   61.734043
# 5496                                   88.541483
#
#       mean_Math_Texture_Contrast_DCP1A_pb_only_9  \
# 0                                      29.119141
# 1                                      34.717262
# 2                                      26.421741
# 3                                      48.756461
# 4                                      21.158761
# ...                                          ...
# 5492                                   10.135525
# 5493                                   24.110549
# 5494                                   19.583811
# 5495                                   16.734490
# 5496                                   13.205186
#
#       mean_Math_Texture_Entropy_DCP1A_pb_only_15  \
# 0                                       0.100133
# 1                                       0.332918
# 2                                       0.090862
# 3                                       0.141244
# 4                                       0.192388
# ...                                          ...
# 5492                                    0.029112
# 5493                                    0.082067
# 5494                                    0.117775
# 5495                                    0.031328
# 5496                                    0.044839
#
#       mean_Math_Texture_Entropy_DCP1A_pb_only_3  \
# 0                                      0.836307
# 1                                      0.827373
# 2                                      0.798397
# 3                                      0.926325
# 4                                      0.937440
# ...                                         ...
# 5492                                   0.731760
# 5493                                   0.761978
# 5494                                   0.839603
# 5495                                   0.747191
# 5496                                   0.726538
#
#       mean_Math_Texture_Entropy_DCP1A_pb_only_5  \
# 0                                      0.599088
# 1                                      0.645985
# 2                                      0.491850
# 3                                      0.709060
# 4                                      0.692591
# ...                                         ...
# 5492                                   0.422588
# 5493                                   0.584771
# 5494                                   0.566913
# 5495                                   0.362847
# 5496                                   0.351832
#
#       mean_Math_Texture_Entropy_DCP1A_pb_only_9  \
# 0                                      0.281511
# 1                                      0.449233
# 2                                      0.249366
# 3                                      0.468966
# 4                                      0.346618
# ...                                         ...
# 5492                                   0.093660
# 5493                                   0.197595
# 5494                                   0.229708
# 5495                                   0.143436
# 5496                                   0.060646
#
#       mean_Math_Texture_Homogeneity_DCP1A_pb_only_15  \
# 0                                           0.026699
# 1                                           0.141234
# 2                                           0.011753
# 3                                           0.054369
# 4                                           0.044577
# ...                                              ...
# 5492                                        0.032886
# 5493                                        0.063270
# 5494                                        0.044934
# 5495                                        0.018134
# 5496                                        0.010616
#
#       mean_Math_Texture_Homogeneity_DCP1A_pb_only_3  \
# 0                                          0.169592
# 1                                          0.187459
# 2                                          0.171916
# 3                                          0.167290
# 4                                          0.158811
# ...                                             ...
# 5492                                       0.150635
# 5493                                       0.221922
# 5494                                       0.153180
# 5495                                       0.117651
# 5496                                       0.085415
#
#       mean_Math_Texture_Homogeneity_DCP1A_pb_only_5  \
# 0                                          0.093890
# 1                                          0.123284
# 2                                          0.091922
# 3                                          0.167158
# 4                                          0.094750
# ...                                             ...
# 5492                                       0.100497
# 5493                                       0.147233
# 5494                                       0.093709
# 5495                                       0.087549
# 5496                                       0.047413
#
#       mean_Math_Texture_Homogeneity_DCP1A_pb_only_9
# 0                                          0.063550
# 1                                          0.097678
# 2                                          0.065669
# 3                                          0.112909
# 4                                          0.079037
# ...                                             ...
# 5492                                       0.024060
# 5493                                       0.055116
# 5494                                       0.185583
# 5495                                       0.078532
# 5496                                       0.009756
#
# [5497 rows x 46 columns]

# %%
cp_measurements.groupby('batch')['ImageNumber'].unique().apply(len)
# Out:
# batch
# batch1    241
# batch2    249
# batch3    245
# Name: ImageNumber, dtype: int64

# %% [markdown]
# # Add new variable "group"

# %%
# Add group
cp_measurements['group'] = cp_measurements['cell_line']+"_"+cp_measurements['condition']

# Fiilter by lines
lines_to_include = ["WT_Untreated", "WT_stress"]
cp_measurements = cp_measurements[cp_measurements['group'].isin(lines_to_include)]
print(cp_measurements.shape)

# Important to put the reference group first in order for mixedlm() - has to be Categorical!
cp_measurements["group"] = pd.Categorical(
    cp_measurements["group"],
    categories=lines_to_include,
    ordered=True
)
# Out:
# (5497, 47)

# %%
cp_measurements[['rep', 'group']].value_counts()
# Out:
# rep   group
# rep4  WT_stress       726
# rep2  WT_Untreated    720
# rep3  WT_Untreated    707
# rep1  WT_Untreated    706
# rep4  WT_Untreated    690
# rep1  WT_stress       667
# rep3  WT_stress       644
# rep2  WT_stress       637
# Name: count, dtype: int64

# %%
cp_measurements[['batch']].value_counts()
# Out:
# batch
# batch2    1848
# batch1    1846
# batch3    1803
# Name: count, dtype: int64

# %%
cp_measurements[['group']].value_counts()
# Out:
# group
# WT_Untreated    2823
# WT_stress       2674
# Name: count, dtype: int64

# %% [markdown]
# # Effect size modeling
#
# The terms in the formula:
# - measurement: The CellProfiler feature (e.g., mean number of p-bodies).
# - gene_group: A fixed effect to test differences between WT, C9, +sALS, -sALS.
# - rep: Random intercept for each patient, accounting for intra-patient correlation across site images.
#
# What This Model Gives You:
# - Estimates of group differences: WT vs other groups, with significance testing.
#
# - Within-patient variability: Captures how consistent measurements are across images for a given patient.
#
# - Between-patient variability: Tests whether observed effects are reproducible across patients.
#
# - P-values or confidence intervals: For significance of gene group effects.

# %%
cp_measurements[['group', 'batch', 'num_pb']].groupby(['group', 'batch'], observed=False).describe()
#cp_measurements[['gene_group', 'num_pb']].groupby('gene_group', observed=False).describe()
# Out:
#                     num_pb                                            \
#                      count       mean       std       min        25%
# group        batch
# WT_Untreated batch1  901.0  12.038027  4.007868  6.569444   9.469388
#              batch2  985.0  10.302657  2.694218  6.493671   8.490909
#              batch3  937.0  11.489772  4.377915  6.477273   8.734694
# WT_stress    batch1  945.0  13.486353  4.870420  7.250000  10.333333
#              batch2  863.0  12.693563  5.090366  7.059701  10.091614
#              batch3  866.0  13.995236  6.979262  7.363636  10.245427
#
#
#                            50%        75%      max
# group        batch
# WT_Untreated batch1  10.916667  13.156250   43.500
#              batch2   9.666667  11.225806   28.600
#              batch3  10.217391  12.628571   45.000
# WT_stress    batch1  12.117647  14.960000   44.375
#              batch2  11.585366  13.983871  109.000
#              batch3  12.075047  15.905956  120.250

# %%
# get the CellProfiler features you want to calculate effect for 
cp_features_columns = [col for col in cp_measurements.columns if col not in group_by_columns + ['batch', 'group']]

results_df_DCP1A = run_analysis_generate_report(
                                df=cp_measurements,
                                feature_columns=cp_features_columns,
                                group_col="group",
                                batch_col="batch",
                                output_dir=os.path.join(CP_OUTPUTS_FOLDER, ANALYSIS_TYPE, 'mixed_effect_report')
)
# Out:
# Analysing CP feature: num_pb
# ⚠️ Warning during model fit for feature num_pb: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature num_pb: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature num_pb: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature num_pb: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature num_pb: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: num_pb
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     119.2
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           8.46e-75
# Time:                        18:05:06   Log-Likelihood:                -16424.
# No. Observations:                5497   AIC:                         3.286e+04
# Df Residuals:                    5493   BIC:                         3.288e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                11.6986      0.130     89.977      0.000      11.444      11.953
# C(group)[T.WT_stress]     2.1115      0.130     16.280      0.000       1.857       2.366
# C(batch)[T.batch2]       -1.2654      0.158     -8.001      0.000      -1.575      -0.955
# C(batch)[T.batch3]       -0.0195      0.159     -0.123      0.902      -0.331       0.292
# ==============================================================================
# Omnibus:                     6351.139   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1633936.303
# Skew:                           5.662   Prob(JB):                         0.00
# Kurtosis:                      86.699   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 11.70
# - WT_stress: +2.11146 units vs Ctrl (p = 0.00000, 95% CI: [1.85720, 2.36572]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_Area
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_Area
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     659.1
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                -10878.
# No. Observations:                5497   AIC:                         2.176e+04
# Df Residuals:                    5493   BIC:                         2.179e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                26.0724      0.047    549.959      0.000      25.979      26.165
# C(group)[T.WT_stress]    -1.9803      0.047    -41.874      0.000      -2.073      -1.888
# C(batch)[T.batch2]       -0.9453      0.058    -16.393      0.000      -1.058      -0.832
# C(batch)[T.batch3]       -0.4046      0.058     -6.975      0.000      -0.518      -0.291
# ==============================================================================
# Omnibus:                      738.961   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1187.104
# Skew:                           0.929   Prob(JB):                    1.67e-258
# Kurtosis:                       4.316   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 26.07
# - WT_stress: -1.98033 units vs Ctrl (p = 0.00000, 95% CI: [-2.07304, -1.88762]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_Compactness
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_Compactness
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     171.7
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          2.12e-106
# Time:                        18:05:06   Log-Likelihood:                 12369.
# No. Observations:                5497   AIC:                        -2.473e+04
# Df Residuals:                    5493   BIC:                        -2.470e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.7972      0.001   1154.394      0.000       0.796       0.799
# C(group)[T.WT_stress]    -0.0118      0.001    -17.152      0.000      -0.013      -0.010
# C(batch)[T.batch2]       -0.0129      0.001    -15.356      0.000      -0.015      -0.011
# C(batch)[T.batch3]       -0.0051      0.001     -6.070      0.000      -0.007      -0.003
# ==============================================================================
# Omnibus:                     1626.621   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4889.360
# Skew:                           1.531   Prob(JB):                         0.00
# Kurtosis:                       6.460   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.80
# - WT_stress: -0.01182 units vs Ctrl (p = 0.00000, 95% CI: [-0.01317, -0.01046]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_Eccentricity
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_Eccentricity
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.168
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     368.6
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          4.07e-218
# Time:                        18:05:06   Log-Likelihood:                 10672.
# No. Observations:                5497   AIC:                        -2.134e+04
# Df Residuals:                    5493   BIC:                        -2.131e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.5226      0.001    555.838      0.000       0.521       0.524
# C(group)[T.WT_stress]     0.0275      0.001     29.349      0.000       0.026       0.029
# C(batch)[T.batch2]       -0.0165      0.001    -14.431      0.000      -0.019      -0.014
# C(batch)[T.batch3]       -0.0061      0.001     -5.334      0.000      -0.008      -0.004
# ==============================================================================
# Omnibus:                      705.555   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1062.409
# Skew:                           0.931   Prob(JB):                    2.00e-231
# Kurtosis:                       4.082   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.52
# - WT_stress: +0.02753 units vs Ctrl (p = 0.00000, 95% CI: [0.02569, 0.02937]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_EquivalentDiameter
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_EquivalentDiameter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.308
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     813.4
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                 1868.0
# No. Observations:                5497   AIC:                            -3728.
# Df Residuals:                    5493   BIC:                            -3702.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 5.5371      0.005   1186.992      0.000       5.528       5.546
# C(group)[T.WT_stress]    -0.2195      0.005    -47.162      0.000      -0.229      -0.210
# C(batch)[T.batch2]       -0.0930      0.006    -16.388      0.000      -0.104      -0.082
# C(batch)[T.batch3]       -0.0434      0.006     -7.604      0.000      -0.055      -0.032
# ==============================================================================
# Omnibus:                      547.706   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              771.628
# Skew:                           0.786   Prob(JB):                    2.77e-168
# Kurtosis:                       3.948   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 5.54
# - WT_stress: -0.21947 units vs Ctrl (p = 0.00000, 95% CI: [-0.22859, -0.21034]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_FormFactor
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_FormFactor
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.128
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     267.7
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          3.55e-162
# Time:                        18:05:06   Log-Likelihood:                 10871.
# No. Observations:                5497   AIC:                        -2.173e+04
# Df Residuals:                    5493   BIC:                        -2.171e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.2943      0.001   1427.292      0.000       1.292       1.296
# C(group)[T.WT_stress]     0.0218      0.001     24.113      0.000       0.020       0.024
# C(batch)[T.batch2]        0.0173      0.001     15.724      0.000       0.015       0.020
# C(batch)[T.batch3]        0.0078      0.001      7.008      0.000       0.006       0.010
# ==============================================================================
# Omnibus:                     1134.568   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2405.259
# Skew:                          -1.202   Prob(JB):                         0.00
# Kurtosis:                       5.174   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.29
# - WT_stress: +0.02181 units vs Ctrl (p = 0.00000, 95% CI: [0.02004, 0.02359]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_0
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     85.73
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           3.32e-54
# Time:                        18:05:06   Log-Likelihood:                 24313.
# No. Observations:                5497   AIC:                        -4.862e+04
# Df Residuals:                    5493   BIC:                        -4.859e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.1643   7.86e-05   2089.116      0.000       0.164       0.164
# C(group)[T.WT_stress]     0.0006   7.84e-05      7.935      0.000       0.000       0.001
# C(batch)[T.batch2]       -0.0013   9.56e-05    -13.306      0.000      -0.001      -0.001
# C(batch)[T.batch3]       -0.0004   9.62e-05     -3.950      0.000      -0.001      -0.000
# ==============================================================================
# Omnibus:                     1621.848   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4632.913
# Skew:                           1.551   Prob(JB):                         0.00
# Kurtosis:                       6.257   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.16
# - WT_stress: +0.00062 units vs Ctrl (p = 0.00000, 95% CI: [0.00047, 0.00078]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_1
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     130.8
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           7.96e-82
# Time:                        18:05:06   Log-Likelihood:                 32293.
# No. Observations:                5497   AIC:                        -6.458e+04
# Df Residuals:                    5493   BIC:                        -6.455e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0020   1.84e-05    108.775      0.000       0.002       0.002
# C(group)[T.WT_stress]     0.0003   1.84e-05     14.774      0.000       0.000       0.000
# C(batch)[T.batch2]       -0.0003   2.24e-05    -12.190      0.000      -0.000      -0.000
# C(batch)[T.batch3]    -6.745e-05   2.25e-05     -2.995      0.003      -0.000   -2.33e-05
# ==============================================================================
# Omnibus:                     1607.747   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4636.775
# Skew:                           1.532   Prob(JB):                         0.00
# Kurtosis:                       6.296   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00027 units vs Ctrl (p = 0.00000, 95% CI: [0.00024, 0.00031]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_2
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     94.96
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           6.48e-60
# Time:                        18:05:06   Log-Likelihood:                 43546.
# No. Observations:                5497   AIC:                        -8.708e+04
# Df Residuals:                    5493   BIC:                        -8.706e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0003   2.38e-06    125.487      0.000       0.000       0.000
# C(group)[T.WT_stress]   2.57e-05   2.37e-06     10.837      0.000     2.1e-05    3.03e-05
# C(batch)[T.batch2]     -3.46e-05   2.89e-06    -11.968      0.000   -4.03e-05   -2.89e-05
# C(batch)[T.batch3]    -7.545e-06   2.91e-06     -2.594      0.009   -1.32e-05   -1.84e-06
# ==============================================================================
# Omnibus:                     2069.999   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9131.557
# Skew:                           1.805   Prob(JB):                         0.00
# Kurtosis:                       8.180   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00003 units vs Ctrl (p = 0.00000, 95% CI: [0.00002, 0.00003]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_3
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     42.10
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           6.90e-27
# Time:                        18:05:06   Log-Likelihood:                 54367.
# No. Observations:                5497   AIC:                        -1.087e+05
# Df Residuals:                    5493   BIC:                        -1.087e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              1.839e-05   3.32e-07     55.385      0.000    1.77e-05     1.9e-05
# C(group)[T.WT_stress]  9.732e-07   3.31e-07      2.939      0.003    3.24e-07    1.62e-06
# C(batch)[T.batch2]    -4.106e-06   4.04e-07    -10.169      0.000    -4.9e-06   -3.31e-06
# C(batch)[T.batch3]    -8.312e-07   4.06e-07     -2.046      0.041   -1.63e-06   -3.49e-08
# ==============================================================================
# Omnibus:                     7637.389   Durbin-Watson:                   1.980
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          8233119.462
# Skew:                           7.486   Prob(JB):                         0.00
# Kurtosis:                     192.002   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.00331, 95% CI: [0.00000, 0.00000]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_4
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.057
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):              0.366
# Time:                        18:05:06   Log-Likelihood:                 70910.
# No. Observations:                5497   AIC:                        -1.418e+05
# Df Residuals:                    5493   BIC:                        -1.418e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              1.815e-08   1.64e-08      1.109      0.268   -1.39e-08    5.02e-08
# C(group)[T.WT_stress]  1.359e-08   1.63e-08      0.832      0.405   -1.84e-08    4.56e-08
# C(batch)[T.batch2]    -9.226e-09   1.99e-08     -0.463      0.643   -4.83e-08    2.98e-08
# C(batch)[T.batch3]     2.148e-08      2e-08      1.072      0.284   -1.78e-08    6.07e-08
# ==============================================================================
# Omnibus:                    19730.903   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6463612393.768
# Skew:                          72.308   Prob(JB):                         0.00
# Kurtosis:                    5313.304   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.40520, 95% CI: [-0.00000, 0.00000]) → ✖️ Not significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_5
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     8.091
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           2.24e-05
# Time:                        18:05:06   Log-Likelihood:                 62942.
# No. Observations:                5497   AIC:                        -1.259e+05
# Df Residuals:                    5493   BIC:                        -1.258e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              1.191e-06   6.98e-08     17.067      0.000    1.05e-06    1.33e-06
# C(group)[T.WT_stress]  4.254e-08   6.96e-08      0.611      0.541   -9.39e-08    1.79e-07
# C(batch)[T.batch2]     -3.57e-07   8.49e-08     -4.207      0.000   -5.23e-07   -1.91e-07
# C(batch)[T.batch3]     2.931e-09   8.54e-08      0.034      0.973   -1.64e-07     1.7e-07
# ==============================================================================
# Omnibus:                    16537.006   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       1568855690.863
# Skew:                          43.479   Prob(JB):                         0.00
# Kurtosis:                    2618.739   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.54103, 95% CI: [-0.00000, 0.00000]) → ✖️ Not significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_6
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.7101
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):              0.546
# Time:                        18:05:06   Log-Likelihood:                 90288.
# No. Observations:                5497   AIC:                        -1.806e+05
# Df Residuals:                    5493   BIC:                        -1.805e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              5.499e-10   4.82e-10      1.141      0.254   -3.95e-10    1.49e-09
# C(group)[T.WT_stress] -3.907e-10   4.81e-10     -0.813      0.417   -1.33e-09    5.52e-10
# C(batch)[T.batch2]    -6.786e-10   5.86e-10     -1.157      0.247   -1.83e-09    4.71e-10
# C(batch)[T.batch3]    -5.705e-10    5.9e-10     -0.967      0.333   -1.73e-09    5.86e-10
# ==============================================================================
# Omnibus:                     8814.165   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        119103837.938
# Skew:                          -9.166   Prob(JB):                         0.00
# Kurtosis:                     723.884   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: -0.00000 units vs Ctrl (p = 0.41653, 95% CI: [-0.00000, 0.00000]) → ✖️ Not significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_MeanRadius
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_MeanRadius
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     1743.
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                 14614.
# No. Observations:                5497   AIC:                        -2.922e+04
# Df Residuals:                    5493   BIC:                        -2.919e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3607      0.000   2964.259      0.000       1.360       1.362
# C(group)[T.WT_stress]    -0.0327      0.000    -71.379      0.000      -0.034      -0.032
# C(batch)[T.batch2]       -0.0080      0.001    -14.257      0.000      -0.009      -0.007
# C(batch)[T.batch3]       -0.0044      0.001     -7.898      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                      178.957   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              198.870
# Skew:                           0.435   Prob(JB):                     6.55e-44
# Kurtosis:                       3.333   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.36
# - WT_stress: -0.03268 units vs Ctrl (p = 0.00000, 95% CI: [-0.03358, -0.03179]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_MedianRadius
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_MedianRadius
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     886.3
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:05:06   Log-Likelihood:                 14520.
# No. Observations:                5497   AIC:                        -2.903e+04
# Df Residuals:                    5493   BIC:                        -2.901e+04
# ...
# Time:                        18:05:08   Log-Likelihood:                 2988.5
# No. Observations:                5497   AIC:                            -5969.
# Df Residuals:                    5493   BIC:                            -5943.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.2654      0.004     69.754      0.000       0.258       0.273
# C(group)[T.WT_stress]     0.0520      0.004     13.710      0.000       0.045       0.059
# C(batch)[T.batch2]       -0.0659      0.005    -14.234      0.000      -0.075      -0.057
# C(batch)[T.batch3]       -0.0240      0.005     -5.163      0.000      -0.033      -0.015
# ==============================================================================
# Omnibus:                     1054.537   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1949.248
# Skew:                           1.194   Prob(JB):                         0.00
# Kurtosis:                       4.676   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.27
# - WT_stress: +0.05204 units vs Ctrl (p = 0.00000, 95% CI: [0.04459, 0.05948]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_15
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_15: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_15: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_15: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_15: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_15: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_15
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     27.51
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           1.19e-17
# Time:                        18:05:08   Log-Likelihood:                 9521.1
# No. Observations:                5497   AIC:                        -1.903e+04
# Df Residuals:                    5493   BIC:                        -1.901e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0478      0.001     41.229      0.000       0.046       0.050
# C(group)[T.WT_stress]    -0.0028      0.001     -2.403      0.016      -0.005      -0.001
# C(batch)[T.batch2]       -0.0120      0.001     -8.513      0.000      -0.015      -0.009
# C(batch)[T.batch3]       -0.0031      0.001     -2.184      0.029      -0.006      -0.000
# ==============================================================================
# Omnibus:                     2664.271   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18293.851
# Skew:                           2.229   Prob(JB):                         0.00
# Kurtosis:                      10.745   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.05
# - WT_stress: -0.00278 units vs Ctrl (p = 0.01628, 95% CI: [-0.00505, -0.00051]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_3
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_3: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_3: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_3: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     41.97
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           8.31e-27
# Time:                        18:05:08   Log-Likelihood:                 10167.
# No. Observations:                5497   AIC:                        -2.033e+04
# Df Residuals:                    5493   BIC:                        -2.030e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.1477      0.001    143.332      0.000       0.146       0.150
# C(group)[T.WT_stress]    -0.0078      0.001     -7.538      0.000      -0.010      -0.006
# C(batch)[T.batch2]       -0.0068      0.001     -5.423      0.000      -0.009      -0.004
# C(batch)[T.batch3]        0.0037      0.001      2.906      0.004       0.001       0.006
# ==============================================================================
# Omnibus:                      924.026   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1816.449
# Skew:                           1.024   Prob(JB):                         0.00
# Kurtosis:                       4.932   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.15
# - WT_stress: -0.00775 units vs Ctrl (p = 0.00000, 95% CI: [-0.00977, -0.00574]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_5
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_5: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_5: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_5: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     57.65
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           1.09e-36
# Time:                        18:05:08   Log-Likelihood:                 10675.
# No. Observations:                5497   AIC:                        -2.134e+04
# Df Residuals:                    5493   BIC:                        -2.132e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0987      0.001    105.034      0.000       0.097       0.101
# C(group)[T.WT_stress]    -0.0104      0.001    -11.069      0.000      -0.012      -0.009
# C(batch)[T.batch2]       -0.0059      0.001     -5.181      0.000      -0.008      -0.004
# C(batch)[T.batch3]        0.0022      0.001      1.899      0.058   -7.01e-05       0.004
# ==============================================================================
# Omnibus:                      982.008   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2034.998
# Skew:                           1.059   Prob(JB):                         0.00
# Kurtosis:                       5.097   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.10
# - WT_stress: -0.01038 units vs Ctrl (p = 0.00000, 95% CI: [-0.01221, -0.00854]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_9
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_9: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_9: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_9: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_9: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_DCP1A_pb_only_9: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_DCP1A_pb_only_9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     40.47
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           7.33e-26
# Time:                        18:05:08   Log-Likelihood:                 9293.0
# No. Observations:                5497   AIC:                        -1.858e+04
# Df Residuals:                    5493   BIC:                        -1.855e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0737      0.001     60.998      0.000       0.071       0.076
# C(group)[T.WT_stress]    -0.0055      0.001     -4.576      0.000      -0.008      -0.003
# C(batch)[T.batch2]       -0.0132      0.001     -8.997      0.000      -0.016      -0.010
# C(batch)[T.batch3]       -0.0006      0.001     -0.400      0.689      -0.003       0.002
# ==============================================================================
# Omnibus:                     1522.552   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4368.977
# Skew:                           1.448   Prob(JB):                         0.00
# Kurtosis:                       6.269   Cond. No.                         4.21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.07
# - WT_stress: -0.00552 units vs Ctrl (p = 0.00000, 95% CI: [-0.00788, -0.00315]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
# Saving all results to: /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_DCP1A/mixed_effect_report/mixedlm_results.csv

# %%
def plot_cp_feature_grouped_by_gene(cp_measurements, cp_feature_col, group_col="gene_group", patient_col="patient_id", color_mapping=None, model_results_df=None, pdf_file=None):
    
    df = cp_measurements.copy()

    # Define fixed color and label mapping for both group_col and patient_col
    _palette = {}
    groups = df[group_col].astype(str).unique().tolist() + df[patient_col].astype(str).unique().tolist()
    for g in groups:
        if g in color_mapping: _palette[color_mapping[g]['alias']] = color_mapping[g]['color']
    if patient_col=='batch':
        for b in df[patient_col].astype(str).unique().tolist():
            _palette[b]='gray'

    
    # Rename groups to aliases
    label_mapping = {k: v["alias"] for k, v in color_mapping.items() if k in groups}
    df[group_col] = df[group_col].cat.rename_categories(label_mapping)
    df[patient_col] = df[patient_col].astype("category").cat.rename_categories(label_mapping)
    
    # Get x-axis positions for each group
    x_pos_map = {label: i for i, label in enumerate(sorted(df[group_col].unique()))}

    
    sns.set(style="white", font_scale=1.0)
    fig, ax = plt.subplots(figsize=(3, 4))
    line_width=1.5
    # Boxplot with custom order
    sns.boxplot(
        data=df,
        x=group_col,
        hue=group_col,  # or patient_col if needed
        y=cp_feature_col,
        palette=_palette,
        width=0.3,
        linewidth=line_width,
        showfliers=False,
        showmeans=True,
        meanline=True,
        meanprops={
        "linestyle": "-",
        "color": "black",
        "linewidth": line_width * 2
        },
        boxprops=dict(facecolor='white', edgecolor='black', linewidth=line_width),
        whiskerprops=dict(linewidth=line_width, color='black'),
        capprops=dict(linewidth=line_width, color='black'),
        medianprops=dict(visible=False),        
        order=list(x_pos_map.keys())  
    )

    # ============================
    # Full distribution: raw cell-level/image-level points
    # ============================
    sns.stripplot(
        data=df,
        x=group_col,
        y=cp_feature_col,
        order=list(x_pos_map.keys()),
        color="lightgray",
        size=2.5,
        jitter=0.25,
        alpha=0.4,
        dodge=False,
        zorder=1
    )
    # Then move legend
    ax = plt.gca()
    handles, labels = ax.get_legend_handles_labels()
    unique = dict(zip(labels, handles))
    plt.legend(
        unique.values(),
        unique.keys(),
        title=patient_col,
        bbox_to_anchor=(1.02, 1),
        loc="upper left"
    )
    
    # ============================
    # Overlay per-batch means
    # ============================
    batch_means = df.groupby([group_col, patient_col], observed=True)[cp_feature_col].mean().reset_index()
    
    for _, row in batch_means.iterrows():
        group = row[group_col]
        batch = row[patient_col]
        x = x_pos_map[group]
        y = row[cp_feature_col]
        # Jitter x slightly (mean = x, small std deviation)
        jittered_x = np.random.normal(loc=x, scale=0.05)  # adjust scale if needed
        
        ax.scatter(
            x=jittered_x,
            y=y,
            color=_palette.get(group, 'black'),
            edgecolor=None,
            s=20,
            zorder=3,
            label=batch  # will be deduplicated in legend
        )


    # Ensure tick marks are shown on both axes
    ax.tick_params(
        axis='both',
        which='both',
        direction='out',   # or 'in' or 'inout'
        length=4,          # length of the tick marks
        width=1,           # thickness of the ticks
        bottom=True, top=False,    # x-axis ticks
        left=True, right=False     # y-axis ticks
    )
    # ============================
    # p-value annotation LMM
    # ============================
    stat = model_results_df[(model_results_df['comparison'] == 'WT_stress') & (model_results_df['feature'] == cp_feature_col)]
    p = float(stat['pval'].iloc[0])

    #ci_low = float(stat['ci_lower'].values[0])
    #ci_high = float(stat['ci_upper'].values[0])
    #txt = f"(p = {p:.3f}, 95% CI: [{ci_low:.2f}, {ci_high:.2f}])"

    # Format p display
    if p < 0.001:
        p_text = "***"
    elif p < 0.01:
        p_text = "**"
    elif p < 0.05:
        p_text = "*"
    else:
        p_text = f"n.s. (p = {p:.2f})"

    # Use actual plot limits to place annotation
    ymin, ymax = ax.get_ylim()

    y_range = ymax - ymin
    line_y = ymax - 0.1 * y_range
    text_y = line_y 

    # Bridge line
    x1, x2 = 0, 1
    ax.plot([x1, x1, x2, x2],
            [line_y, line_y + 0.01*y_range, line_y + 0.01*y_range, line_y],
            lw=1.5, c='black')

    # Annotation text
    ax.text((x1 + x2) / 2, text_y, p_text, ha='center', va='bottom')
    
    # Format
    plt.ylabel(cp_feature_col)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.subplots_adjust(top=0.88)  # add top space if needed
    
    # Save the plot
    if pdf_file is not None:
        pdf_file.savefig(fig, bbox_inches='tight')
        
        plt.close(fig)
    else:
        plt.show()

# %%
with PdfPages(f"{save_path}/cell_profiler_Sorbitol_p_bodies_DCP1A.pdf") as pdf:
    for cp_feature_col in measures_to_plot:
        if cp_feature_col in cp_measurements.columns:
            plot_cp_feature_grouped_by_gene(cp_measurements, 
                                              cp_feature_col=cp_feature_col,
                                              group_col='group', 
                                              patient_col="batch",
                                              color_mapping=_color_mapping, 
                                              model_results_df=results_df_DCP1A,
                                              pdf_file=pdf
                                           )

# %% [markdown]
# # New Sorbitol  dataset - LSM14A

# %%
ANALYSIS_TYPE = 'PB_profiling/Sorbitol_LSM14A'
BATCHES = ['batch1', 'batch2', 'batch3']

save_path = '/home/projects/hornsteinlab/Collaboration/NOVA/outputs/vit_models/finetunedModel_MLPHead_acrossBatches_B56789_80pct_frozen/figures/Sorbitol/cell_profiler/PB_profiling/Sorbitol_LSM14A'

# %%
# Test CP outputs (number of images)
if True:
    pattern = os.path.join(CP_OUTPUTS_FOLDER, ANALYSIS_TYPE, '*', '*', '*', '*', '*', '*')
    # store marker folders by cell line
    for marker_path in glob.glob(pattern):
        if os.path.isdir(marker_path):
            try:
                image_df = pd.read_csv(marker_path +'/Image.csv')
                #print(marker_path, image_df.shape)
                #print(image_df[['Count_Pbodies', 'Count_nucleus']].head(10))
                
                # DEBUG CODE: to recognise problems in CP wiriting to the wrong folder
                # parts_df = image_df['PathName_nucleus'].apply(extract_path_parts)
                parts_df = image_df['PathName_DAPI'].apply(extract_path_parts)
                
                print(marker_path, parts_df['batch'].unique(), parts_df['cell_line'].unique(), parts_df['condition'].unique(), parts_df['rep'].unique(), )
                # DEBUG CODE

                marker = os.path.basename(marker_path)    
                cell_line = Path(marker_path).resolve().parents[3].name
            except FileNotFoundError as e:
                print("!!!!")
                print(e)
        else:
            print(f"Not a marker folder directory:{marker_path}")
# Out:
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/stress/rep3/LSM14A ['batch3'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/stress/rep4/LSM14A ['batch3'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/stress/rep1/LSM14A ['batch3'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/stress/rep2/LSM14A ['batch3'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/Untreated/rep3/LSM14A ['batch3'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/Untreated/rep4/LSM14A ['batch3'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/Untreated/rep1/LSM14A ['batch3'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch3/WT/panelB/Untreated/rep2/LSM14A ['batch3'] ['WT'] ['Untreated'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/stress/rep3/LSM14A ['batch2'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/stress/rep4/LSM14A ['batch2'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/stress/rep1/LSM14A ['batch2'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/stress/rep2/LSM14A ['batch2'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/Untreated/rep3/LSM14A ['batch2'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/Untreated/rep4/LSM14A ['batch2'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/Untreated/rep1/LSM14A ['batch2'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch2/WT/panelB/Untreated/rep2/LSM14A ['batch2'] ['WT'] ['Untreated'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/stress/rep3/LSM14A ['batch1'] ['WT'] ['stress'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/stress/rep4/LSM14A ['batch1'] ['WT'] ['stress'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/stress/rep1/LSM14A ['batch1'] ['WT'] ['stress'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/stress/rep2/LSM14A ['batch1'] ['WT'] ['stress'] ['rep2']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/Untreated/rep3/LSM14A ['batch1'] ['WT'] ['Untreated'] ['rep3']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/Untreated/rep4/LSM14A ['batch1'] ['WT'] ['Untreated'] ['rep4']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/Untreated/rep1/LSM14A ['batch1'] ['WT'] ['Untreated'] ['rep1']
# /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/batch1/WT/panelB/Untreated/rep2/LSM14A ['batch1'] ['WT'] ['Untreated'] ['rep2']

# %% [markdown]
# ## Collect CP files by "cell_line+condition" and Load CP data

# %%
# Collect paths of CP output files
paths_by_cell_line = collect_cp_results_by_cell_line(ANALYSIS_TYPE, include_condition=True)#, validate=False)

# %%
# Load CP data
cp_data = load_cp_results(paths_by_cell_line, REQUIRED_FILES)
# Out:
# number of subjects from cell line WT_stress: 12
# number of subjects from cell line WT_Untreated: 12

# %%
# Get the calculated features from all CP output files

LSM14A_PB_in_cyto_measures = [
    "Math_LSM14A_PB_over_cyto", 
    "Math_Texture_Contrast_LSM14A_pb_only_15", 
    "Math_Texture_Contrast_LSM14A_pb_only_3", 
    "Math_Texture_Contrast_LSM14A_pb_only_5",
    "Math_Texture_Contrast_LSM14A_pb_only_9",
    "Math_Texture_Entropy_LSM14A_pb_only_15",
    "Math_Texture_Entropy_LSM14A_pb_only_3",
    "Math_Texture_Entropy_LSM14A_pb_only_5",
    "Math_Texture_Entropy_LSM14A_pb_only_9",
    "Math_Texture_Homogeneity_LSM14A_pb_only_15",
    "Math_Texture_Homogeneity_LSM14A_pb_only_3",
    "Math_Texture_Homogeneity_LSM14A_pb_only_5",
    "Math_Texture_Homogeneity_LSM14A_pb_only_9",

    
]

cp_measurements = collect_all_features(cp_data, group_by_columns, PB_in_cyto_measures=LSM14A_PB_in_cyto_measures)
# Out:
# WT_stress (2591, 6) (2591, 32) (2591, 18)
# (2591, 33)
# (2591, 46)
# WT_Untreated (2727, 6) (2727, 32) (2727, 18)
# (2727, 33)
# (2727, 46)
# Shape after merging is: (5318, 46)

# %% [markdown]
# # add new variable "group"

# %%
# Add group
cp_measurements['group'] = cp_measurements['cell_line']+"_"+cp_measurements['condition']

# Fiilter by lines
lines_to_include = ["WT_Untreated", "WT_stress"]
cp_measurements = cp_measurements[cp_measurements['group'].isin(lines_to_include)]
print(cp_measurements.shape)

# Important to put the reference group first in order for mixedlm() - has to be Categorical!
cp_measurements["group"] = pd.Categorical(
    cp_measurements["group"],
    categories=lines_to_include,
    ordered=True
)
# Out:
# (5318, 47)

# %%
cp_measurements[['rep', 'group']].value_counts()
# Out:
# rep   group
# rep1  WT_Untreated    694
# rep4  WT_Untreated    684
# rep3  WT_Untreated    679
# rep4  WT_stress       678
# rep2  WT_Untreated    670
# rep1  WT_stress       640
# rep2  WT_stress       640
# rep3  WT_stress       633
# Name: count, dtype: int64

# %%
cp_measurements[['batch']].value_counts()
# Out:
# batch
# batch1    1826
# batch3    1756
# batch2    1736
# Name: count, dtype: int64

# %%
cp_measurements[['group']].value_counts()
# Out:
# group
# WT_Untreated    2727
# WT_stress       2591
# Name: count, dtype: int64

# %% [markdown]
# # Effect size modeling
#
# The terms in the formula:
# - measurement: The CellProfiler feature (e.g., mean number of p-bodies).
# - gene_group: A fixed effect to test differences between WT, C9, +sALS, -sALS.
# - rep: Random intercept for each patient, accounting for intra-patient correlation across site images.
#
# What This Model Gives You:
# - Estimates of group differences: WT vs other groups, with significance testing.
#
# - Within-patient variability: Captures how consistent measurements are across images for a given patient.
#
# - Between-patient variability: Tests whether observed effects are reproducible across patients.
#
# - P-values or confidence intervals: For significance of gene group effects.

# %%
cp_measurements[['group', 'batch', 'num_pb']].groupby(['group', 'batch'], observed=False).describe()
#cp_measurements[['gene_group', 'num_pb']].groupby('gene_group', observed=False).describe()
# Out:
#                     num_pb                                                    \
#                      count      mean       std       min       25%       50%
# group        batch
# WT_Untreated batch1  900.0  8.613726  1.457981  5.392857  7.550978  8.473611
#              batch2  891.0  8.135650  1.332103  5.557377  7.228524  7.895833
#              batch3  936.0  7.919097  1.454472  5.166667  6.974107  7.670290
# WT_stress    batch1  926.0  9.907762  2.743192  5.298507  8.102572  9.363698
#              batch2  845.0  9.161898  2.419958  5.637681  7.609756  8.636364
#              batch3  820.0  9.152514  2.809151  5.088889  7.473684  8.506757
#
#
#                            75%        max
# group        batch
# WT_Untreated batch1   9.439236  15.000000
#              batch2   8.850713  15.166667
#              batch3   8.503788  20.000000
# WT_stress    batch1  10.938416  41.750000
#              batch2  10.060606  30.125000
#              batch3  10.000000  34.200000

# %%
# get the CellProfiler features you want to calculate effect for 
cp_features_columns = [col for col in cp_measurements.columns if col not in group_by_columns + ['batch', 'group']]

results_df_LSM14A = run_analysis_generate_report(
                                df=cp_measurements,
                                feature_columns=cp_features_columns,
                                group_col="group",
                                batch_col="batch",
                                output_dir=os.path.join(CP_OUTPUTS_FOLDER, ANALYSIS_TYPE, 'mixed_effect_report')
)
# Out:
# Analysing CP feature: num_pb
# ⚠️ Warning during model fit for feature num_pb: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature num_pb: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature num_pb: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature num_pb: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature num_pb: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: num_pb
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     184.3
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          1.05e-113
# Time:                        18:07:18   Log-Likelihood:                -11536.
# No. Observations:                5318   AIC:                         2.308e+04
# Df Residuals:                    5314   BIC:                         2.311e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 8.6682      0.058    150.261      0.000       8.555       8.781
# C(group)[T.WT_stress]     1.1866      0.058     20.404      0.000       1.073       1.301
# C(batch)[T.batch2]       -0.6106      0.071     -8.597      0.000      -0.750      -0.471
# C(batch)[T.batch3]       -0.7273      0.071    -10.265      0.000      -0.866      -0.588
# ==============================================================================
# Omnibus:                     3865.908   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           135979.907
# Skew:                           3.072   Prob(JB):                         0.00
# Kurtosis:                      26.999   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 8.67
# - WT_stress: +1.18657 units vs Ctrl (p = 0.00000, 95% CI: [1.07256, 1.30057]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_Area
# ⚠️ Warning during model fit for feature mean_AreaShape_Area: UserWarning: Random effects covariance is singular
#               Mixed Linear Model Regression Results
# =================================================================
# Model:              MixedLM   Dependent Variable:   feature_value
# No. Observations:   5318      Method:               ML
# No. Groups:         3         Scale:                11.2540
# Min. group size:    1736      Log-Likelihood:       -13987.9636
# Max. group size:    1826      Converged:            Yes
# Mean group size:    1772.7
# -----------------------------------------------------------------
#                       Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------
# Intercept             31.259    0.276 113.307 0.000 30.718 31.800
# C(group)[T.WT_stress]  1.650    0.092  17.916 0.000  1.469  1.830
# Group Var              0.216    0.054
# =================================================================
#
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 31.26
# - WT_stress: +1.64974 units vs Ctrl (p = 0.00000, 95% CI: [1.46926, 1.83022]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - Estimated variance across batches: 0.21594
# - ✅ Indicates batch-level variability was successfully modeled.
#
#
#
# Analysing CP feature: mean_AreaShape_Compactness
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Compactness: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_Compactness
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     293.9
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          1.52e-176
# Time:                        18:07:18   Log-Likelihood:                 11550.
# No. Observations:                5318   AIC:                        -2.309e+04
# Df Residuals:                    5314   BIC:                        -2.307e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.7959      0.001   1059.525      0.000       0.794       0.797
# C(group)[T.WT_stress]     0.0205      0.001     27.059      0.000       0.019       0.022
# C(batch)[T.batch2]       -0.0107      0.001    -11.591      0.000      -0.013      -0.009
# C(batch)[T.batch3]       -0.0063      0.001     -6.860      0.000      -0.008      -0.005
# ==============================================================================
# Omnibus:                     1726.009   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7767.603
# Skew:                           1.518   Prob(JB):                         0.00
# Kurtosis:                       8.083   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.80
# - WT_stress: +0.02049 units vs Ctrl (p = 0.00000, 95% CI: [0.01901, 0.02197]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_Eccentricity
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_Eccentricity: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_Eccentricity
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     2211.
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:07:18   Log-Likelihood:                 11847.
# No. Observations:                5318   AIC:                        -2.369e+04
# Df Residuals:                    5314   BIC:                        -2.366e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.4767      0.001    671.056      0.000       0.475       0.478
# C(group)[T.WT_stress]     0.0570      0.001     79.605      0.000       0.056       0.058
# C(batch)[T.batch2]       -0.0118      0.001    -13.462      0.000      -0.013      -0.010
# C(batch)[T.batch3]       -0.0107      0.001    -12.239      0.000      -0.012      -0.009
# ==============================================================================
# Omnibus:                      815.725   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1586.056
# Skew:                           0.948   Prob(JB):                         0.00
# Kurtosis:                       4.887   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.48
# - WT_stress: +0.05701 units vs Ctrl (p = 0.00000, 95% CI: [0.05560, 0.05841]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_EquivalentDiameter
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_EquivalentDiameter: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM  Dependent Variable:  feature_value
# No. Observations:    5318     Method:              ML
# No. Groups:          3        Scale:               0.0880
# Min. group size:     1736     Log-Likelihood:      -1087.5002
# Max. group size:     1826     Converged:           Yes
# Mean group size:     1772.7
# ----------------------------------------------------------------
#                       Coef. Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept             5.964    0.024 248.076 0.000  5.917  6.011
# C(group)[T.WT_stress] 0.100    0.008  12.250 0.000  0.084  0.116
# Group Var             0.002    0.005
# ================================================================
#
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 5.96
# - WT_stress: +0.09972 units vs Ctrl (p = 0.00000, 95% CI: [0.08377, 0.11568]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - Estimated variance across batches: 0.00164
# - ✅ Indicates batch-level variability was successfully modeled.
#
#
#
# Analysing CP feature: mean_AreaShape_FormFactor
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_FormFactor: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_FormFactor
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     90.58
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           3.67e-57
# Time:                        18:07:18   Log-Likelihood:                 9001.5
# No. Observations:                5318   AIC:                        -1.800e+04
# Df Residuals:                    5314   BIC:                        -1.797e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.3385      0.001   1103.477      0.000       1.336       1.341
# C(group)[T.WT_stress]    -0.0156      0.001    -12.741      0.000      -0.018      -0.013
# C(batch)[T.batch2]        0.0151      0.001     10.126      0.000       0.012       0.018
# C(batch)[T.batch3]        0.0089      0.001      6.002      0.000       0.006       0.012
# ==============================================================================
# Omnibus:                      645.735   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1243.660
# Skew:                          -0.779   Prob(JB):                    8.76e-271
# Kurtosis:                       4.785   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.34
# - WT_stress: -0.01558 units vs Ctrl (p = 0.00000, 95% CI: [-0.01798, -0.01318]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_0
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_0: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_0
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.384
# Model:                            OLS   Adj. R-squared:                  0.383
# Method:                 Least Squares   F-statistic:                     1103.
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:07:18   Log-Likelihood:                 25392.
# No. Observations:                5318   AIC:                        -5.078e+04
# Df Residuals:                    5314   BIC:                        -5.075e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.1616   5.56e-05   2905.407      0.000       0.162       0.162
# C(group)[T.WT_stress]     0.0031   5.61e-05     55.738      0.000       0.003       0.003
# C(batch)[T.batch2]       -0.0008   6.85e-05    -12.217      0.000      -0.001      -0.001
# C(batch)[T.batch3]       -0.0006   6.83e-05     -9.327      0.000      -0.001      -0.001
# ==============================================================================
# Omnibus:                     2189.551   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13704.128
# Skew:                           1.855   Prob(JB):                         0.00
# Kurtosis:                       9.934   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.16
# - WT_stress: +0.00313 units vs Ctrl (p = 0.00000, 95% CI: [0.00302, 0.00324]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_1
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_1: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_1
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     1603.
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:07:18   Log-Likelihood:                 33324.
# No. Observations:                5318   AIC:                        -6.664e+04
# Df Residuals:                    5314   BIC:                        -6.661e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0016   1.25e-05    126.055      0.000       0.002       0.002
# C(group)[T.WT_stress]     0.0009   1.26e-05     67.902      0.000       0.001       0.001
# C(batch)[T.batch2]       -0.0002   1.54e-05    -11.325      0.000      -0.000      -0.000
# C(batch)[T.batch3]       -0.0001   1.54e-05     -9.475      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                     2253.171   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15948.523
# Skew:                           1.874   Prob(JB):                         0.00
# Kurtosis:                      10.611   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00086 units vs Ctrl (p = 0.00000, 95% CI: [0.00083, 0.00088]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_2
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_2: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.390
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     1133.
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):               0.00
# Time:                        18:07:18   Log-Likelihood:                 44646.
# No. Observations:                5318   AIC:                        -8.928e+04
# Df Residuals:                    5314   BIC:                        -8.926e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0002   1.49e-06    156.813      0.000       0.000       0.000
# C(group)[T.WT_stress]  8.569e-05    1.5e-06     57.084      0.000    8.27e-05    8.86e-05
# C(batch)[T.batch2]    -1.828e-05   1.83e-06     -9.969      0.000   -2.19e-05   -1.47e-05
# C(batch)[T.batch3]    -1.382e-05   1.83e-06     -7.555      0.000   -1.74e-05   -1.02e-05
# ==============================================================================
# Omnibus:                     2313.569   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16841.551
# Skew:                           1.925   Prob(JB):                         0.00
# Kurtosis:                      10.822   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00009 units vs Ctrl (p = 0.00000, 95% CI: [0.00008, 0.00009]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_3
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_3: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     532.0
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          2.48e-302
# Time:                        18:07:18   Log-Likelihood:                 54126.
# No. Observations:                5318   AIC:                        -1.082e+05
# Df Residuals:                    5314   BIC:                        -1.082e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              1.319e-05    2.5e-07     52.680      0.000    1.27e-05    1.37e-05
# C(group)[T.WT_stress]  9.778e-06   2.52e-07     38.725      0.000    9.28e-06    1.03e-05
# C(batch)[T.batch2]     -2.56e-06   3.08e-07     -8.301      0.000   -3.16e-06   -1.96e-06
# C(batch)[T.batch3]    -2.035e-06   3.08e-07     -6.614      0.000   -2.64e-06   -1.43e-06
# ==============================================================================
# Omnibus:                     3485.501   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63065.472
# Skew:                           2.868   Prob(JB):                         0.00
# Kurtosis:                      18.866   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00001 units vs Ctrl (p = 0.00000, 95% CI: [0.00001, 0.00001]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_4
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_4: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_4
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     20.75
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           2.32e-13
# Time:                        18:07:19   Log-Likelihood:                 78908.
# No. Observations:                5318   AIC:                        -1.578e+05
# Df Residuals:                    5314   BIC:                        -1.578e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              2.181e-08   2.37e-09      9.197      0.000    1.72e-08    2.65e-08
# C(group)[T.WT_stress]  1.714e-08   2.39e-09      7.170      0.000    1.25e-08    2.18e-08
# C(batch)[T.batch2]     -7.16e-09   2.92e-09     -2.453      0.014   -1.29e-08   -1.44e-09
# C(batch)[T.batch3]    -8.188e-09   2.91e-09     -2.812      0.005   -1.39e-08   -2.48e-09
# ==============================================================================
# Omnibus:                    11061.457   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         48863258.683
# Skew:                          17.552   Prob(JB):                         0.00
# Kurtosis:                     471.280   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.00000, 95% CI: [0.00000, 0.00000]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_5
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_5: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_5
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     119.9
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           4.00e-75
# Time:                        18:07:19   Log-Likelihood:                 62680.
# No. Observations:                5318   AIC:                        -1.254e+05
# Df Residuals:                    5314   BIC:                        -1.253e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               1.07e-06   5.01e-08     21.342      0.000    9.72e-07    1.17e-06
# C(group)[T.WT_stress]  9.207e-07   5.06e-08     18.213      0.000    8.22e-07    1.02e-06
# C(batch)[T.batch2]    -2.665e-07   6.17e-08     -4.316      0.000   -3.88e-07   -1.45e-07
# C(batch)[T.batch3]    -2.396e-07   6.16e-08     -3.890      0.000    -3.6e-07   -1.19e-07
# ==============================================================================
# Omnibus:                     6700.953   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1471917.149
# Skew:                           6.768   Prob(JB):                         0.00
# Kurtosis:                      83.371   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.00000, 95% CI: [0.00000, 0.00000]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_HuMoment_6
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_HuMoment_6: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_HuMoment_6
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8703
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):              0.456
# Time:                        18:07:19   Log-Likelihood:                 88099.
# No. Observations:                5318   AIC:                        -1.762e+05
# Df Residuals:                    5314   BIC:                        -1.762e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              4.959e-12   4.21e-10      0.012      0.991    -8.2e-10     8.3e-10
# C(group)[T.WT_stress]  6.733e-10   4.24e-10      1.586      0.113   -1.59e-10    1.51e-09
# C(batch)[T.batch2]     8.135e-11   5.18e-10      0.157      0.875   -9.35e-10     1.1e-09
# C(batch)[T.batch3]    -6.558e-11   5.17e-10     -0.127      0.899   -1.08e-09    9.48e-10
# ==============================================================================
# Omnibus:                     7839.930   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         43117409.153
# Skew:                           7.858   Prob(JB):                         0.00
# Kurtosis:                     443.841   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.00
# - WT_stress: +0.00000 units vs Ctrl (p = 0.11273, 95% CI: [-0.00000, 0.00000]) → ✖️ Not significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_MeanRadius
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MeanRadius: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_MeanRadius
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     26.16
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           8.63e-17
# Time:                        18:07:19   Log-Likelihood:                 10411.
# No. Observations:                5318   AIC:                        -2.081e+04
# Df Residuals:                    5314   BIC:                        -2.079e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.4391      0.001   1546.415      0.000       1.437       1.441
# C(group)[T.WT_stress] -2.111e-05      0.001     -0.023      0.982      -0.002       0.002
# C(batch)[T.batch2]       -0.0098      0.001     -8.581      0.000      -0.012      -0.008
# C(batch)[T.batch3]       -0.0026      0.001     -2.278      0.023      -0.005      -0.000
# ==============================================================================
# Omnibus:                      321.909   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              392.112
# Skew:                           0.604   Prob(JB):                     7.14e-86
# Kurtosis:                       3.556   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.44
# - WT_stress: -0.00002 units vs Ctrl (p = 0.98204, 95% CI: [-0.00186, 0.00182]) → ✖️ Not significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_MedianRadius
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_MedianRadius: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_MedianRadius
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     60.40
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           2.16e-38
# Time:                        18:07:19   Log-Likelihood:                 10226.
# No. Observations:                5318   AIC:                        -2.044e+04
# Df Residuals:                    5314   BIC:                        -2.042e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.2113      0.001   1257.252      0.000       1.209       1.213
# C(group)[T.WT_stress]     0.0093      0.001      9.624      0.000       0.007       0.011
# C(batch)[T.batch2]       -0.0107      0.001     -9.006      0.000      -0.013      -0.008
# C(batch)[T.batch3]       -0.0027      0.001     -2.307      0.021      -0.005      -0.000
# ==============================================================================
# Omnibus:                      360.339   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              442.094
# Skew:                           0.657   Prob(JB):                     1.00e-96
# Kurtosis:                       3.519   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.21
# - WT_stress: +0.00935 units vs Ctrl (p = 0.00000, 95% CI: [0.00744, 0.01125]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_AreaShape_NormalizedMoment_0_2
# ⚠️ Warning during model fit for feature mean_AreaShape_NormalizedMoment_0_2: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_AreaShape_NormalizedMoment_0_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_NormalizedMoment_0_2: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_AreaShape_NormalizedMoment_0_2: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_AreaShape_NormalizedMoment_0_2: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_AreaShape_NormalizedMoment_0_2
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.245
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     575.2
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):          9.88e-324
# Time:                        18:07:19   Log-Likelihood:                 27113.
# No. Observations:                5318   AIC:                        -5.422e+04
# Df Residuals:                    5314   BIC:                        -5.419e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.0000   4.66e-16   2.15e+15      0.000       1.000       1.000
# C(group)[T.WT_stress] -3.376e-14    4.7e-16    -71.837      0.000   -3.47e-14   -3.28e-14
# C(batch)[T.batch2]    -3.088e-16   5.74e-16     -0.538      0.591   -1.43e-15    8.16e-16
# C(batch)[T.batch3]     7.365e-16   5.73e-16      1.286      0.198   -3.86e-16    1.86e-15
# ==============================================================================
# Omnibus:                    18508.922   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              884.587
# Skew:                           0.051   Prob(JB):                    8.21e-193
# Kurtosis:                       1.005   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 1.00
# - WT_stress: -0.00000 units vs Ctrl (p = 0.00000, 95% CI: [-0.00000, -0.00000]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_15
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_15: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_15: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_15: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_15: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_15: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_15
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     53.77
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           3.12e-34
# Time:                        18:07:20   Log-Likelihood:                 10650.
# No. Observations:                5318   AIC:                        -2.129e+04
# Df Residuals:                    5314   BIC:                        -2.126e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0140      0.001     15.749      0.000       0.012       0.016
# C(group)[T.WT_stress]     0.0110      0.001     12.290      0.000       0.009       0.013
# C(batch)[T.batch2]       -0.0032      0.001     -2.949      0.003      -0.005      -0.001
# C(batch)[T.batch3]       -0.0007      0.001     -0.641      0.522      -0.003       0.001
# ==============================================================================
# Omnibus:                    15058.624   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        931152424.688
# Skew:                          36.871   Prob(JB):                         0.00
# Kurtosis:                    2051.617   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.01
# - WT_stress: +0.01102 units vs Ctrl (p = 0.00000, 95% CI: [0.00926, 0.01278]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_3
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_3: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_3: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_3: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_3: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     113.3
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           4.34e-71
# Time:                        18:07:20   Log-Likelihood:                 10731.
# No. Observations:                5318   AIC:                        -2.145e+04
# Df Residuals:                    5314   BIC:                        -2.143e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0801      0.001     91.439      0.000       0.078       0.082
# C(group)[T.WT_stress]     0.0158      0.001     17.859      0.000       0.014       0.018
# C(batch)[T.batch2]       -0.0043      0.001     -4.028      0.000      -0.006      -0.002
# C(batch)[T.batch3]       -0.0003      0.001     -0.263      0.793      -0.002       0.002
# ==============================================================================
# Omnibus:                     9183.350   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         31832540.772
# Skew:                          11.408   Prob(JB):                         0.00
# Kurtosis:                     381.337   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.08
# - WT_stress: +0.01577 units vs Ctrl (p = 0.00000, 95% CI: [0.01404, 0.01751]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_5
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_5: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_5: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_5: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_5: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_5
# /home/projects/hornsteinlab/Collaboration/NOVA/envs/nova/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     83.75
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           6.10e-53
# Time:                        18:07:20   Log-Likelihood:                 12529.
# No. Observations:                5318   AIC:                        -2.505e+04
# Df Residuals:                    5314   BIC:                        -2.502e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0474      0.001     75.817      0.000       0.046       0.049
# C(group)[T.WT_stress]     0.0092      0.001     14.652      0.000       0.008       0.010
# C(batch)[T.batch2]       -0.0043      0.001     -5.645      0.000      -0.006      -0.003
# C(batch)[T.batch3]       -0.0028      0.001     -3.588      0.000      -0.004      -0.001
# ==============================================================================
# Omnibus:                     8742.395   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         22617525.296
# Skew:                          10.329   Prob(JB):                         0.00
# Kurtosis:                     321.819   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.05
# - WT_stress: +0.00923 units vs Ctrl (p = 0.00000, 95% CI: [0.00799, 0.01046]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
#
# Analysing CP feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_9
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_9: UserWarning: Random effects covariance is singular
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_9: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_9: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_9: UserWarning: The random effects covariance matrix is singular.
# ⚠️ Warning during model fit for feature mean_Math_Texture_Homogeneity_LSM14A_pb_only_9: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
# ❌ Random effect variance is near zero. — Unable to fit random intercept (e.g., low variance or convergence issue)
# ⚠️ Fallback to fixed-effects model for feature: mean_Math_Texture_Homogeneity_LSM14A_pb_only_9
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          feature_value   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     131.7
# Date:                Tue, 30 Sep 2025   Prob (F-statistic):           2.89e-82
# Time:                        18:07:20   Log-Likelihood:                 12234.
# No. Observations:                5318   AIC:                        -2.446e+04
# Df Residuals:                    5314   BIC:                        -2.443e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0300      0.001     45.387      0.000       0.029       0.031
# C(group)[T.WT_stress]     0.0125      0.001     18.718      0.000       0.011       0.014
# C(batch)[T.batch2]       -0.0051      0.001     -6.211      0.000      -0.007      -0.003
# C(batch)[T.batch3]       -0.0031      0.001     -3.815      0.000      -0.005      -0.002
# ==============================================================================
# Omnibus:                     5994.756   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1972544.587
# Skew:                           5.302   Prob(JB):                         0.00
# Kurtosis:                      96.753   Cond. No.                         4.17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ### Fixed Effects: Gene Group Differences from Ctrl
# - Ctrl: estimated average = 0.03
# - WT_stress: +0.01246 units vs Ctrl (p = 0.00000, 95% CI: [0.01116, 0.01377]) → ✔️ Significant
#
# ### Random Effects (Batch-level / Intra-patient variability)
# - ℹ️ Model did not include random effects (fixed-effects fallback used).
#
#
# Saving all results to: /home/projects/hornsteinlab/Collaboration/NOVA/cell_profiler/outputs/cell_profiler_RUNS/Final_cp_analysis/PB_profiling/Sorbitol_LSM14A/mixed_effect_report/mixedlm_results.csv

# %%
with PdfPages(f"{save_path}/cell_profiler_Sorbitol_p_bodies_LSM14A.pdf") as pdf:
    for cp_feature_col in measures_to_plot:
        if cp_feature_col in cp_measurements.columns:
            plot_cp_feature_grouped_by_gene(cp_measurements, 
                                              cp_feature_col=cp_feature_col,
                                              group_col='group', 
                                              patient_col="batch",
                                              color_mapping=_color_mapping, 
                                              model_results_df=results_df_LSM14A,
                                              pdf_file=pdf
                                           )

# %%
print("Done!")
# Out:
# Done!
