# %%
def create_run_command(figure_config, plot_config):
    return (
        f"$NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot "
        f"-m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model "
        f"./manuscript/manuscript_figures_data_config/{figure_config} "
        f"./manuscript/manuscript_plot_config/{plot_config} -q short"
    )

def generate_run_commands(figure_configs, plot_configs):
    commands = [
        create_run_command(figure_config, plot_config)
        for figure_config in figure_configs
        for plot_config in plot_configs
    ]
    print("\n".join(commands))

# %%
figure_configs = [
    f"Funova_Batch{batch}_{cell_line.replace('TDP-43', 'TDP--43')}_Config"
    for batch in range(1, 5)
    for cell_line in [
        "Control_1001733", "Control_1017118", "Control_1025045", "Control_1048087",
        "C9orf72_HRE_1008566", "C9orf72_HRE_981344", "TDP_43_G348V_1057052", "TDP_43_N390D_1005373"
    ]
]

plot_configs = [
     "UMAP0StressPlotConfig",
    "UMAP0RepsAsLabelsPlotConfig"
]

# %%
generate_run_commands(figure_configs, plot_configs)
# Out:
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1001733_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1017118_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1025045_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Control_1048087_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_C9orf72_HRE_1008566_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_C9orf72_HRE_981344_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_TDP_43_G348V_1057052_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_TDP_43_N390D_1005373_Config ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfig -q short

# %%
figure_configs = ["Funova_Batch1_Config", "Funova_Batch2_Config", "Funova_Batch3_Config", "Funova_Batch4_Config"]
plot_configs = ["UMAP0ALSPlotConfigFunova", "UMAP0ALSConditionsPlotConfigFunova"]
# "UMAP0StressPlotConfig", 
generate_run_commands(figure_configs, plot_configs)
# Out:
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Config ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch1_Config ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Config ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch2_Config ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Config ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch3_Config ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Config ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_Batch4_Config ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short

# %%
figure_configs = ['Funova_controls_tdp_untreated', 'Funova_controls_tdp_stress', 'Funova_controls_c9_untreated',
                 'Funova_controls_c9_stress','Funova_stress','Funova_untreated']
plot_configs = ["UMAP0ALSPlotConfigFunova"]
generate_run_commands(figure_configs, plot_configs)
# Out:
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_tdp_untreated ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_tdp_stress ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_c9_untreated ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_c9_stress ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_stress ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_untreated ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short

# %%
figure_configs = ['Funova_controls_untreated_si', 'Funova_controls_stress_si', 'Funova_tdp_untreated_si', 'Funova_tdp_stress_si',
                 'Funova_control_untreated_tdp', 'Funova_control_stress_tdp']
plot_configs = ["UMAP0ALSPlotConfigFunova"]
generate_run_commands(figure_configs, plot_configs)
# Out:
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_untreated_si ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_controls_stress_si ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_tdp_untreated_si ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_tdp_stress_si ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_control_untreated_tdp ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config/Funova_control_stress_tdp ./manuscript/manuscript_plot_config/UMAP0ALSPlotConfigFunova -q short

# %%
class NeuronsUMAP0StressFunovaFigureConfig(FigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP0 of single markers - WT untreated vs stress
        """        
        self.EXPERIMENT_TYPE = 'funova'    
        self.MARKERS_TO_EXCLUDE = []
        self.SHOW_ARI = True
        self.ARI_LABELS_FUNC = MapLabelsFunction.CONDITIONS.name

class FunovaUMAP0CellLinesFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP0 of single markers - Cell lines 
        """        
        # self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, f) for f in 
        #                 ["Batch1",]]
        self.ADD_LINE_TO_LABEL = True
        self.MARKERS_TO_EXCLUDE = []
        self.ADD_REP_TO_LABEL=False   
        self.SHOW_ARI = True    
        self.ARI_LABELS_FUNC = MapLabelsFunction.CELL_LINES_CONDITIONS.name
        # self.CONDITIONS = ['stress'] 

class FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP0 of single markers - Cell lines + stress
        """        
        self.ARI_LABELS_FUNC = MapLabelsFunction.CELL_LINES.name
        self.CONDITIONS = ['stress'] 

class FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP0 of single markers - Cell lines - stress
        """        
        self.ARI_LABELS_FUNC = MapLabelsFunction.CELL_LINES.name
        self.CONDITIONS = ['Untreated'] 

class NeuronsUMAP1B9FunovaFigureConfig(FigureConfig):
    def __init__(self):
        super().__init__()
        
        """UMAP1 of WT untreated
        """        
        self.EXPERIMENT_TYPE = 'funova'  
        self.CONDITIONS = ['Untreated']
        self.MARKERS_TO_EXCLUDE = []
        self.SHOW_ARI = True
        self.ARI_LABELS_FUNC = MapLabelsFunction.MARKERS.name

class NeuronsUMAP1B9FunovaFigureConfigNoDAPI(FigureConfig):
    def __init__(self):
        super().__init__()
        
        """UMAP1 of WT untreated
        """        
        self.EXPERIMENT_TYPE = 'funova'  
        self.CONDITIONS = ['Untreated']
        self.MARKERS_TO_EXCLUDE = ['DAPI']
        self.SHOW_ARI = True
        self.ARI_LABELS_FUNC = MapLabelsFunction.MARKERS.name

class NeuronsUMAP1B9FunovaFigureConfigStress(FigureConfig):
    def __init__(self):
        super().__init__()
        
        """UMAP1 of WT untreated
        """        
        self.EXPERIMENT_TYPE = 'funova'  
        self.CONDITIONS = ['Untreated']
        self.MARKERS_TO_EXCLUDE = ['DAPI']
        self.SHOW_ARI = True
        self.ARI_LABELS_FUNC = MapLabelsFunction.MARKERS.name        

class FunovaUMAP2FigureConfig(FigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP2 multiplex of WT untreated vs stress
        """
        self.EXPERIMENT_TYPE = 'funova'    
        # self.CELL_LINES = []
        self.MARKERS_TO_EXCLUDE = []
        # self.MARKERS = ['DAPI']
        self.SHOW_ARI = False
        self.ADD_REP_TO_LABEL=False
        self.ADD_LINE_TO_LABEL = True
        self.ADD_CONDITION_TO_LABEL = True
        # self.CELL_LINES = ["C9orf72-HRE-1008566"] + control_cell_lines
        # self.CONDITIONS = ['Untreated']
        self.ARI_LABELS_FUNC = MapLabelsFunction.CELL_LINES_CONDITIONS.name

class FunovaUMAP2ALSD18B2FigureConfig(FigureConfig):
    def __init__(self):
        super().__init__()
        """UMAP2 multiplex of WT untreated vs cell lines
        """
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, f) for f in 
                        ["Batch4",]]
        self.EXPERIMENT_TYPE = 'funova'   
        self.MARKERS_TO_EXCLUDE = [] 
        self.CONDITIONS = ['Untreated']
        self.SHOW_ARI = True
        self.ADD_REP_TO_LABEL=False
        self.ARI_LABELS_FUNC = MapLabelsFunction.CELL_LINES.name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 class NeuronsUMAP0StressFunovaFigureConfig(FigureConfig):
#       2     def __init__(self):
#       3         super().__init__()
#
# NameError: name 'FigureConfig' is not defined

# %%
class Funova_Batch1_Config(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]

class Funova_Batch2_Config(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]

class Funova_Batch3_Config(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]

class Funova_Batch4_Config(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        
class Funova_Batch1_Control_1001733_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["Control-1001733"]

class Funova_Batch1_Control_1017118_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["Control-1017118"]

class Funova_Batch1_Control_1025045_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["Control-1025045"]

class Funova_Batch1_Control_1048087_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["Control-1048087"]

class Funova_Batch1_C9orf72_HRE_1008566_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["C9orf72-HRE-1008566"]

class Funova_Batch1_C9orf72_HRE_981344_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["C9orf72-HRE-981344"]

class Funova_Batch1_TDP_43_G348V_1057052_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["TDP--43-G348V-1057052"]

class Funova_Batch1_TDP_43_N390D_1005373_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
        self.CELL_LINES = ["TDP--43-N390D-1005373"]

class Funova_Batch2_Control_1001733_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["Control-1001733"]

class Funova_Batch2_Control_1017118_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["Control-1017118"]

class Funova_Batch2_Control_1025045_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["Control-1025045"]

class Funova_Batch2_Control_1048087_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["Control-1048087"]

class Funova_Batch2_C9orf72_HRE_1008566_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["C9orf72-HRE-1008566"]

class Funova_Batch2_C9orf72_HRE_981344_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["C9orf72-HRE-981344"]

class Funova_Batch2_TDP_43_G348V_1057052_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["TDP--43-G348V-1057052"]

class Funova_Batch2_TDP_43_N390D_1005373_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
        self.CELL_LINES = ["TDP--43-N390D-1005373"]

class Funova_Batch3_Control_1001733_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["Control-1001733"]

class Funova_Batch3_Control_1017118_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["Control-1017118"]

class Funova_Batch3_Control_1025045_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["Control-1025045"]

class Funova_Batch3_Control_1048087_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["Control-1048087"]

class Funova_Batch3_C9orf72_HRE_1008566_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["C9orf72-HRE-1008566"]

class Funova_Batch3_C9orf72_HRE_981344_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["C9orf72-HRE-981344"]

class Funova_Batch3_TDP_43_G348V_1057052_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["TDP--43-G348V-1057052"]

class Funova_Batch3_TDP_43_N390D_1005373_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
        self.CELL_LINES = ["TDP--43-N390D-1005373"]


class Funova_Batch4_Control_1001733_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["Control-1001733"]

class Funova_Batch4_Control_1017118_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["Control-1017118"]

class Funova_Batch4_Control_1025045_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["Control-1025045"]

class Funova_Batch4_Control_1048087_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["Control-1048087"]

class Funova_Batch4_C9orf72_HRE_1008566_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["C9orf72-HRE-1008566"]

class Funova_Batch4_C9orf72_HRE_981344_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["C9orf72-HRE-981344"]

class Funova_Batch4_TDP_43_G348V_1057052_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["TDP--43-G348V-1057052"]

class Funova_Batch4_TDP_43_N390D_1005373_Config(FigureConfigToUse):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
        self.CELL_LINES = ["TDP--43-N390D-1005373"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class Funova_Batch1_Config(FunovaUMAP0CellLinesFigureConfig):
#       2     def __init__(self):
#       3         super().__init__()
#
# NameError: name 'FunovaUMAP0CellLinesFigureConfig' is not defined

# %%
class Funova_controls_tdp_untreated(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines + tdp43_cell_lines
        self.CONDITIONS = ['Untreated']

class Funova_controls_tdp_stress(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines + tdp43_cell_lines
        self.CONDITIONS = ['stress']

class Funova_controls_c9_untreated(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines + c9orf72_cell_lines
        self.CONDITIONS = ['Untreated']

class Funova_controls_c9_stress(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines + c9orf72_cell_lines
        self.CONDITIONS = ['stress']

class Funova_stress(Funova_Batch3_Config):
    def __init__(self):
        super().__init__()
        self.CONDITIONS = ['stress']
class Funova_untreated(Funova_Batch3_Config):
    def __init__(self):
        super().__init__()
        self.CONDITIONS = ['Untreated']

class Funova_controls_untreated_si(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines 
        self.CONDITIONS = ['Untreated']
        self.MARKERS = ['Stress-initiation']

class Funova_controls_stress_si(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines
        self.CONDITIONS = ['stress'] 
        self.MARKERS = ['Stress-initiation']

class Funova_tdp_untreated_si(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = tdp43_cell_lines 
        self.CONDITIONS = ['Untreated']
        self.MARKERS = ['Stress-initiation']

class Funova_tdp_stress_si(Funova_Batch4_Config):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = tdp43_cell_lines
        self.CONDITIONS = ['stress'] 
        self.MARKERS = ['Stress-initiation']

class Funova_control_untreated_tdp(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines
        self.CONDITIONS = ['Untreated']
        self.MARKERS = ['TDP-43']
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, f) for f in 
                        ["Batch1","Batch2","Batch3","Batch4",]]
        
class Funova_control_stress_tdp(FunovaUMAP0CellLinesFigureConfig):
    def __init__(self):
        super().__init__()
        self.CELL_LINES = control_cell_lines
        self.CONDITIONS = ['stress']
        self.MARKERS = ['TDP-43']
        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, f) for f in 
                        ["Batch1","Batch2","Batch3","Batch4",]]
        
class FunovaUMAP2FigureConfigPROTEOSTASIS_MARKERS(FunovaUMAP2FigureConfig):
    def __init__(self):
        super().__init__()
        self.MARKERS = PROTEOSTASIS_MARKERS

class FunovaUMAP2FigureConfigNEURONAL_CELL_DEATH_SENESCENCE_MARKERS(FunovaUMAP2FigureConfig):
    def __init__(self):
        super().__init__()
        self.MARKERS = NEURONAL_CELL_DEATH_SENESCENCE_MARKERS

class FunovaUMAP2FigureConfigSYNAPTIC_NEURONAL_FUNCTION_MARKERS(FunovaUMAP2FigureConfig):
    def __init__(self):
        super().__init__()
        self.MARKERS = SYNAPTIC_NEURONAL_FUNCTION_MARKERS

class FunovaUMAP2FigureConfigDNA_RNA_DEFECTS_MARKERS(FunovaUMAP2FigureConfig):
    def __init__(self):
        super().__init__()
        self.MARKERS = DNA_RNA_DEFECTS_MARKERS

# %%
# Define base UMAP configurations to inherit from
umap_classes = [
    "NeuronsUMAP0StressFunovaFigureConfig",
    "FunovaUMAP0CellLinesFigureConfig",
    "FunovaUMAP0CellLinesStressFigureConfig",
    "FunovaUMAP0CellLinesUntreatedFigureConfig",
    "NeuronsUMAP1B9FunovaFigureConfig",
    "NeuronsUMAP1B9FunovaFigureConfigNoDAPI",
    "NeuronsUMAP1B9FunovaFigureConfigStress",
    "FunovaUMAP2FigureConfig",
    "FunovaUMAP2ALSD18B2FigureConfig",
]

# Define batches
batches = ["Batch1", "Batch2", "Batch3", "Batch4"]

# Define cell lines
cell_lines = [
    "Control-1001733",
    "Control-1017118",
    "Control-1025045",
    "Control-1048087",
    "C9orf72-HRE-1008566",
    "C9orf72-HRE-981344",
    "TDP-43-G348V-1057052",
    "TDP-43-N390D-1005373"
]

# Generate class definitions
for umap_class in umap_classes:
    for batch in batches:
        class_name = f"Funova_{batch}_Config_{umap_class}"
        print(f"class {class_name}({umap_class}):")
        print("    def __init__(self):")
        print("        super().__init__()")
        print(f"        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, \"{batch}\")]")
        print("\n")

        for cell_line in cell_lines:
            class_name = f"Funova_{batch}_{cell_line.replace('-', '_')}_Config_{umap_class}"
            print(f"class {class_name}({umap_class}):")
            print("    def __init__(self):")
            print("        super().__init__()")
            print(f"        self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, \"{batch}\")]")
            print(f"        self.CELL_LINES = [\"{cell_line}\"]")
            print("\n")
# Out:
# class Funova_Batch1_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_NeuronsUMAP0StressFunovaFigureConfig(NeuronsUMAP0StressFunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch1_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesFigureConfig(FunovaUMAP0CellLinesFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch1_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesStressFigureConfig(FunovaUMAP0CellLinesStressFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch1_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_FunovaUMAP0CellLinesUntreatedFigureConfig(FunovaUMAP0CellLinesUntreatedFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_NeuronsUMAP1B9FunovaFigureConfig(NeuronsUMAP1B9FunovaFigureConfig):
# ...
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_FunovaUMAP2FigureConfig(FunovaUMAP2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch1_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#
#
# class Funova_Batch1_Control_1001733_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch1_Control_1017118_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch1_Control_1025045_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch1_Control_1048087_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch1_C9orf72_HRE_1008566_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch1_C9orf72_HRE_981344_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch1_TDP_43_G348V_1057052_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch1_TDP_43_N390D_1005373_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch1")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch2_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#
#
# class Funova_Batch2_Control_1001733_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch2_Control_1017118_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch2_Control_1025045_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch2_Control_1048087_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch2_C9orf72_HRE_1008566_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch2_C9orf72_HRE_981344_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch2_TDP_43_G348V_1057052_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch2_TDP_43_N390D_1005373_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch2")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch3_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#
#
# class Funova_Batch3_Control_1001733_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch3_Control_1017118_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch3_Control_1025045_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch3_Control_1048087_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch3_C9orf72_HRE_1008566_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch3_C9orf72_HRE_981344_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch3_TDP_43_G348V_1057052_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch3_TDP_43_N390D_1005373_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch3")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]
#
#
# class Funova_Batch4_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#
#
# class Funova_Batch4_Control_1001733_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1001733"]
#
#
# class Funova_Batch4_Control_1017118_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1017118"]
#
#
# class Funova_Batch4_Control_1025045_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1025045"]
#
#
# class Funova_Batch4_Control_1048087_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["Control-1048087"]
#
#
# class Funova_Batch4_C9orf72_HRE_1008566_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-1008566"]
#
#
# class Funova_Batch4_C9orf72_HRE_981344_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["C9orf72-HRE-981344"]
#
#
# class Funova_Batch4_TDP_43_G348V_1057052_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-G348V-1057052"]
#
#
# class Funova_Batch4_TDP_43_N390D_1005373_Config_FunovaUMAP2ALSD18B2FigureConfig(FunovaUMAP2ALSD18B2FigureConfig):
#     def __init__(self):
#         super().__init__()
#         self.INPUT_FOLDERS = [os.path.join(self.PROCESSED_FOLDER_ROOT, "Batch4")]
#         self.CELL_LINES = ["TDP-43-N390D-1005373"]

# %%
figure_configs = [
    "NeuronsUMAP0StressFunovaFigureConfig",
    "FunovaUMAP0CellLinesFigureConfig",
    "FunovaUMAP0CellLinesStressFigureConfig",
    "FunovaUMAP0CellLinesUntreatedFigureConfig",
    "NeuronsUMAP1B9FunovaFigureConfig",
    "NeuronsUMAP1B9FunovaFigureConfigStress",
    "FunovaUMAP2FigureConfig",
    "FunovaUMAP2ALSD18B2FigureConfig",
    "Funova_control_untreated_tdp",
    "Funova_control_stress_tdp",
    "FunovaUMAP2FigureConfigPROTEOSTASIS_MARKERS",
    "FunovaUMAP2FigureConfigNEURONAL_CELL_DEATH_SENESCENCE_MARKERS",
    "FunovaUMAP2FigureConfigSYNAPTIC_NEURONAL_FUNCTION_MARKERS",
    "FunovaUMAP2FigureConfigDNA_RNA_DEFECTS_MARKERS",
    "Funova_Batch1_Config_NeuronsUMAP0StressFunovaFigureConfig",
    "Funova_Batch1_Config_FunovaUMAP0CellLinesFigureConfig",
    "Funova_Batch1_Config_FunovaUMAP0CellLinesStressFigureConfig",
    "Funova_Batch1_Config_FunovaUMAP0CellLinesUntreatedFigureConfig",
    "Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfig",
    "Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI",
    "Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigStress",
    "Funova_Batch1_Config_FunovaUMAP2FigureConfig",
    "Funova_Batch1_Config_FunovaUMAP2ALSD18B2FigureConfig",
    "Funova_Batch2_Config_NeuronsUMAP0StressFunovaFigureConfig",
    "Funova_Batch2_Config_FunovaUMAP0CellLinesFigureConfig",
    "Funova_Batch2_Config_FunovaUMAP0CellLinesStressFigureConfig",
    "Funova_Batch2_Config_FunovaUMAP0CellLinesUntreatedFigureConfig",
    "Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfig",
    "Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI",
    "Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigStress",
    "Funova_Batch2_Config_FunovaUMAP2FigureConfig",
    "Funova_Batch2_Config_FunovaUMAP2ALSD18B2FigureConfig",
    "Funova_Batch3_Config_NeuronsUMAP0StressFunovaFigureConfig",
    "Funova_Batch3_Config_FunovaUMAP0CellLinesFigureConfig",
    "Funova_Batch3_Config_FunovaUMAP0CellLinesStressFigureConfig",
    "Funova_Batch3_Config_FunovaUMAP0CellLinesUntreatedFigureConfig",
    "Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfig",
    "Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI",
    "Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigStress",
    "Funova_Batch3_Config_FunovaUMAP2FigureConfig",
    "Funova_Batch3_Config_FunovaUMAP2ALSD18B2FigureConfig",
    "Funova_Batch4_Config_NeuronsUMAP0StressFunovaFigureConfig",
    "Funova_Batch4_Config_FunovaUMAP0CellLinesFigureConfig",
    "Funova_Batch4_Config_FunovaUMAP0CellLinesStressFigureConfig",
    "Funova_Batch4_Config_FunovaUMAP0CellLinesUntreatedFigureConfig",
    "Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfig",
    "Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI",
    "Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigStress",
    "Funova_Batch4_Config_FunovaUMAP2FigureConfig",
    "Funova_Batch4_Config_FunovaUMAP2ALSD18B2FigureConfig"
]

plot_configs = [
     "UMAP0StressPlotConfig",
    "UMAP0RepsAsLabelsPlotConfig"
    "UMAP0ALSPlotConfigFunova", "UMAP0ALSConditionsPlotConfigFunova"
]

# %%
def create_run_command(figure_config, plot_config):
    return (
        f"$NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot "
        f"-m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model "
        f"./manuscript/manuscript_figures_data_config_funova/{figure_config} "
        f"./manuscript/manuscript_plot_config/{plot_config} -q short"
    )

def generate_run_commands(figure_configs, plot_configs):
    commands = [
        create_run_command(figure_config, plot_config)
        for figure_config in figure_configs
        for plot_config in plot_configs
    ]
    print("\n".join(commands))

generate_run_commands(figure_configs, plot_configs)
# Out:
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_untreated_tdp ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_untreated_tdp ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_untreated_tdp ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_stress_tdp ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_stress_tdp ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_control_stress_tdp ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigPROTEOSTASIS_MARKERS ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigPROTEOSTASIS_MARKERS ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigPROTEOSTASIS_MARKERS ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigNEURONAL_CELL_DEATH_SENESCENCE_MARKERS ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigNEURONAL_CELL_DEATH_SENESCENCE_MARKERS ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigNEURONAL_CELL_DEATH_SENESCENCE_MARKERS ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigSYNAPTIC_NEURONAL_FUNCTION_MARKERS ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigSYNAPTIC_NEURONAL_FUNCTION_MARKERS ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigSYNAPTIC_NEURONAL_FUNCTION_MARKERS ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigDNA_RNA_DEFECTS_MARKERS ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigDNA_RNA_DEFECTS_MARKERS ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/FunovaUMAP2FigureConfigDNA_RNA_DEFECTS_MARKERS ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch1_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch2_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch3_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP0StressFunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesStressFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP0CellLinesUntreatedFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigNoDAPI ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_NeuronsUMAP1B9FunovaFigureConfigStress ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0StressPlotConfig -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0RepsAsLabelsPlotConfigUMAP0ALSPlotConfigFunova -q short
# $NOVA_HOME/runnables/run.sh $NOVA_HOME/runnables/generate_umaps_and_plot -m 10000 -a /home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model ./manuscript/manuscript_figures_data_config_funova/Funova_Batch4_Config_FunovaUMAP2ALSD18B2FigureConfig ./manuscript/manuscript_plot_config/UMAP0ALSConditionsPlotConfigFunova -q short

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/labs/hornsteinlab/Collaboration/MOmaps/outputs/vit_models/finetuned_model/figures/funova/distances/Batch1_Batch2_Batch3_Batch4_all_reps_Control-1001733_Control-1017118_Control-1025045_Control-1048087_C9orf72-HRE-1008566_C9orf72-HRE-981344_TDP--43-G348V-1057052_TDP--43-N390D-1005373_Untreated_all_markers/metrics_score_Control-1025045_Untreated.csv")

# %%
df.loc[(df.marker == 'DAPI')]
# Out:
#                                       repA                            repB  \
# 128                             rep1_part1                      rep2_part1
# 129                             rep1_part1                      rep2_part2
# 130                             rep1_part2                      rep2_part1
# 131                             rep1_part2                      rep2_part2
# 132     rep1_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# ...                                    ...                             ...
# 2649  rep2_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 2650  rep1_TDP--43-N390D-1005373_Untreated  rep1_Control-1025045_Untreated
# 2651  rep1_TDP--43-N390D-1005373_Untreated  rep2_Control-1025045_Untreated
# 2652  rep2_TDP--43-N390D-1005373_Untreated  rep1_Control-1025045_Untreated
# 2653  rep2_TDP--43-N390D-1005373_Untreated  rep2_Control-1025045_Untreated
#
#       ARI_KMeansConstrained                        condition marker   batch
# 128                  -0.000        Control-1025045_Untreated   DAPI  Batch1
# 129                  -0.000        Control-1025045_Untreated   DAPI  Batch1
# 130                  -0.000        Control-1025045_Untreated   DAPI  Batch1
# 131                  -0.000        Control-1025045_Untreated   DAPI  Batch1
# 132                   0.477    C9orf72-HRE-1008566_Untreated   DAPI  Batch1
# ...                     ...                              ...    ...     ...
# 2649                  0.081  TDP--43-G348V-1057052_Untreated   DAPI  Batch4
# 2650                  0.000  TDP--43-N390D-1005373_Untreated   DAPI  Batch4
# 2651                  0.001  TDP--43-N390D-1005373_Untreated   DAPI  Batch4
# 2652                 -0.002  TDP--43-N390D-1005373_Untreated   DAPI  Batch4
# 2653                 -0.002  TDP--43-N390D-1005373_Untreated   DAPI  Batch4
#
# [128 rows x 6 columns]

# %%
df.loc[(df.marker == 'DAPI')&(df.condition=='C9orf72-HRE-1008566_Untreated')]
# Out:
#                                     repA                            repB  \
# 132   rep1_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 133   rep1_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 134   rep2_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 135   rep2_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 964   rep1_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 965   rep1_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 966   rep2_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 967   rep2_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 1794  rep1_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 1795  rep1_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 1796  rep2_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 1797  rep2_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 2626  rep1_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 2627  rep1_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
# 2628  rep2_C9orf72-HRE-1008566_Untreated  rep1_Control-1025045_Untreated
# 2629  rep2_C9orf72-HRE-1008566_Untreated  rep2_Control-1025045_Untreated
#
#       ARI_KMeansConstrained                      condition marker   batch
# 132                   0.477  C9orf72-HRE-1008566_Untreated   DAPI  Batch1
# 133                   0.487  C9orf72-HRE-1008566_Untreated   DAPI  Batch1
# 134                   0.439  C9orf72-HRE-1008566_Untreated   DAPI  Batch1
# 135                   0.447  C9orf72-HRE-1008566_Untreated   DAPI  Batch1
# 964                   0.281  C9orf72-HRE-1008566_Untreated   DAPI  Batch2
# 965                   0.267  C9orf72-HRE-1008566_Untreated   DAPI  Batch2
# 966                   0.239  C9orf72-HRE-1008566_Untreated   DAPI  Batch2
# 967                   0.226  C9orf72-HRE-1008566_Untreated   DAPI  Batch2
# 1794                  0.085  C9orf72-HRE-1008566_Untreated   DAPI  Batch3
# 1795                  0.120  C9orf72-HRE-1008566_Untreated   DAPI  Batch3
# 1796                  0.079  C9orf72-HRE-1008566_Untreated   DAPI  Batch3
# 1797                  0.114  C9orf72-HRE-1008566_Untreated   DAPI  Batch3
# 2626                  0.149  C9orf72-HRE-1008566_Untreated   DAPI  Batch4
# 2627                  0.129  C9orf72-HRE-1008566_Untreated   DAPI  Batch4
# 2628                  0.173  C9orf72-HRE-1008566_Untreated   DAPI  Batch4
# 2629                  0.151  C9orf72-HRE-1008566_Untreated   DAPI  Batch4

# %%
df.loc[(df.marker == 'DAPI')&(df.condition=='Control-1025045_Untreated')]
# Out:
#             repA        repB  ARI_KMeansConstrained  \
# 128   rep1_part1  rep2_part1                   -0.0
# 129   rep1_part1  rep2_part2                   -0.0
# 130   rep1_part2  rep2_part1                   -0.0
# 131   rep1_part2  rep2_part2                   -0.0
# 960   rep1_part1  rep2_part1                   -0.0
# 961   rep1_part1  rep2_part2                   -0.0
# 962   rep1_part2  rep2_part1                   -0.0
# 963   rep1_part2  rep2_part2                   -0.0
# 1790  rep1_part1  rep2_part1                    0.0
# 1791  rep1_part1  rep2_part2                   -0.0
# 1792  rep1_part2  rep2_part1                   -0.0
# 1793  rep1_part2  rep2_part2                   -0.0
# 2622  rep1_part1  rep2_part1                   -0.0
# 2623  rep1_part1  rep2_part2                    0.0
# 2624  rep1_part2  rep2_part1                   -0.0
# 2625  rep1_part2  rep2_part2                   -0.0
#
#                       condition marker   batch
# 128   Control-1025045_Untreated   DAPI  Batch1
# 129   Control-1025045_Untreated   DAPI  Batch1
# 130   Control-1025045_Untreated   DAPI  Batch1
# 131   Control-1025045_Untreated   DAPI  Batch1
# 960   Control-1025045_Untreated   DAPI  Batch2
# 961   Control-1025045_Untreated   DAPI  Batch2
# 962   Control-1025045_Untreated   DAPI  Batch2
# 963   Control-1025045_Untreated   DAPI  Batch2
# 1790  Control-1025045_Untreated   DAPI  Batch3
# 1791  Control-1025045_Untreated   DAPI  Batch3
# 1792  Control-1025045_Untreated   DAPI  Batch3
# 1793  Control-1025045_Untreated   DAPI  Batch3
# 2622  Control-1025045_Untreated   DAPI  Batch4
# 2623  Control-1025045_Untreated   DAPI  Batch4
# 2624  Control-1025045_Untreated   DAPI  Batch4
# 2625  Control-1025045_Untreated   DAPI  Batch4

# %%
df.loc[(df.marker == 'Parthanatos-early')&(df.condition=='TDP--43-G348V-1057052_Untreated')]
# Out:
#                                       repA                            repB  \
# 440   rep1_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 441   rep1_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 442   rep2_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 443   rep2_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 1272  rep1_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 1273  rep1_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 2102  rep1_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 2103  rep1_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 2104  rep2_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 2105  rep2_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 2934  rep1_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 2935  rep1_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
# 2936  rep2_TDP--43-G348V-1057052_Untreated  rep1_Control-1025045_Untreated
# 2937  rep2_TDP--43-G348V-1057052_Untreated  rep2_Control-1025045_Untreated
#
#       ARI_KMeansConstrained                        condition  \
# 440                  -0.078  TDP--43-G348V-1057052_Untreated
# 441                  -0.070  TDP--43-G348V-1057052_Untreated
# 442                  -0.034  TDP--43-G348V-1057052_Untreated
# 443                  -0.007  TDP--43-G348V-1057052_Untreated
# 1272                  0.240  TDP--43-G348V-1057052_Untreated
# 1273                 -0.070  TDP--43-G348V-1057052_Untreated
# 2102                 -0.030  TDP--43-G348V-1057052_Untreated
# 2103                 -0.022  TDP--43-G348V-1057052_Untreated
# 2104                 -0.026  TDP--43-G348V-1057052_Untreated
# 2105                 -0.043  TDP--43-G348V-1057052_Untreated
# 2934                  0.499  TDP--43-G348V-1057052_Untreated
# 2935                  0.039  TDP--43-G348V-1057052_Untreated
# 2936                  0.459  TDP--43-G348V-1057052_Untreated
# 2937                  0.028  TDP--43-G348V-1057052_Untreated
#
#                  marker   batch
# 440   Parthanatos-early  Batch1
# 441   Parthanatos-early  Batch1
# 442   Parthanatos-early  Batch1
# 443   Parthanatos-early  Batch1
# 1272  Parthanatos-early  Batch2
# 1273  Parthanatos-early  Batch2
# 2102  Parthanatos-early  Batch3
# 2103  Parthanatos-early  Batch3
# 2104  Parthanatos-early  Batch3
# 2105  Parthanatos-early  Batch3
# 2934  Parthanatos-early  Batch4
# 2935  Parthanatos-early  Batch4
# 2936  Parthanatos-early  Batch4
# 2937  Parthanatos-early  Batch4

# %%
df.loc[(df.marker == 'Parthanatos-early')&(df.condition=='Control-1025045_Untreated')].ARI_KMeansConstrained
# Out:
# 416    -0.001
# 417     0.001
# 418    -0.000
# 419    -0.001
# 1248    0.030
# 1249    0.021
# 1250    0.029
# 1251    0.023
# 2078    0.034
# 2079    0.024
# 2080    0.061
# 2081    0.042
# 2910    0.146
# 2911    0.201
# 2912    0.152
# 2913    0.178
# Name: ARI_KMeansConstrained, dtype: float64
