# %% [markdown]
# # <font color='purple'>CoyneLab_iPSC_patients_TDP43_PB Preprocessing QC statistics </font>
# ### July 2025

# %%
import os
NOVA_HOME = '/home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps'
NOVA_DATA_HOME = '/home/projects/hornsteinlab/Collaboration/NOVA'

LOGS_PATH = os.path.join(NOVA_DATA_HOME, "outputs/preprocessing/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/logs/")
# PLOT_PATH = os.path.join(NOVA_DATA_HOME, "outputs/preprocessing/AlyssaCoyne/logs/preprocessing_CoyneLab_iPSC_patients_TDP43_PB_7tiles/plots")

os.chdir(NOVA_HOME)

import pandas as pd
import contextlib
import io
from IPython.display import display, Javascript
import seaborn as sns
from tools.preprocessing_tools.qc_reports.qc_utils import log_files_qc, run_validate_folder_structure, display_diff, sample_and_calc_variance, \
                                                show_site_survival_dapi_brenner, show_site_survival_dapi_cellpose, \
                                                show_site_survival_dapi_tiling, show_site_survival_target_brenner, \
                                                calc_total_sums, plot_filtering_heatmap, show_total_sum_tables, \
                                                plot_cell_count, plot_catplot, plot_hm_combine_batches, \
                                                run_calc_hist_new,plot_hm_of_mean_cell_count_per_tile
                                                
from tools.preprocessing_tools.qc_reports.qc_config import AC_panels_new, AC_markers_new, AC_marker_info_new, AC_cell_lines_new, AC_cell_lines_to_cond_new,\
                                    AC_cell_lines_for_disp_new, AC_reps_new, AC_line_colors_new, AC_lines_order_new, AC_custom_palette_new,\
                                    AC_expected_dapi_raw_new
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = log_files_qc(LOGS_PATH)
df_dapi = df[df.marker=='DAPI']
df_target = df[df.marker!='DAPI']
# Out:
# reading logs of batch1
#
# Total of 1 files were read.
# Before dup handeling  (3894, 21)
# After duplication removal #1: (3894, 22)
# After duplication removal #2: (3894, 22)
#
# PAY ATTENTION!!!! df.site_num: s28, can be defined using filename_split & site_location

# %%
# choose batches
batches = ['batch1']
batches
# Out:
# ['batch1']

# %% [markdown]
# ## Actual Files Validation

# %% [markdown]
# ### Raw Files Validation

# %% [markdown]
# 1. How many site **tiff** files do we have in each folder?
# 2. Are all existing files valid? (tif, at least 2049kB, not corrupetd)

# %%
root_directory_raw = os.path.join(NOVA_DATA_HOME, 'input', 'images', 'raw', 'AlyssaCoyne_new_sorted')


raws = run_validate_folder_structure(root_directory_raw, False, AC_panels_new, AC_markers_new.copy(),None, AC_marker_info_new,
                                    AC_cell_lines_to_cond_new, AC_reps_new, AC_cell_lines_for_disp_new, AC_expected_dapi_raw_new,
                                     batches=batches, fig_width=8,expected_count=5, check_antibody=False)
# Out:
# batch1
# Folder structure is valid.
# No bad files are found.
# Total Sites:  5286
# ========
# ====================

# %% [markdown]
# ### Processed Files Validation

# %% [markdown]
# 1. How many site **npy** files do we have in each folder? -> How many sites survived the pre-processing?
# 2. Are all existing files valid? (at least 100kB, npy not corrupted)

# %%
root_directory_proc = os.path.join(NOVA_DATA_HOME, 'input', 'images', 'processed', 'ManuscriptFinalData_80pct','AlyssaCoyne_new')
procs = run_validate_folder_structure(root_directory_proc, True, AC_panels_new, AC_markers_new,None, AC_marker_info_new,
                                    AC_cell_lines_to_cond_new, AC_reps_new, AC_cell_lines_for_disp_new, AC_expected_dapi_raw_new,
                                     batches=batches, fig_width=5,expected_count=8, check_antibody=False)
# Out:
# batch1
# Folder structure is invalid. Missing 53 paths:
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS2YNL/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS8RFT/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS8RFT/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS8RFT/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi029/Untreated/NEMO
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi029/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi029/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/ANXA11
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/Calnexin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/CLTC
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/GM130
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0ANK/Untreated/NONO
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/ANXA11
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/Calnexin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/NEMO
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS6ZU8/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/DCP1A
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/Calnexin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/CLTC
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/hnRNPA2B1
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS4ZCD/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS7VCZ/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS7VCZ/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/C9-CS7VCZ/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi022/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi022/Untreated/DCP1A
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi022/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi022/Untreated/GM130
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi037/Untreated/ANXA11
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi037/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi037/Untreated/NEMO
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/Ctrl-EDi037/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/ANXA11
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/LaminB1
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/Nup153
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/POM121
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/Calnexin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/NEMO
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/GM130
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSNegative-CS0JPP/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS2FN3/Untreated/Phalloidin
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS7TN6/Untreated/CD41
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS7TN6/Untreated/hnRNPA1
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS7TN6/Untreated/Nup62
# /home/projects/hornsteinlab/Collaboration/NOVA/input/images/processed/ManuscriptFinalData_80pct/AlyssaCoyne_new/batch1/SALSPositive-CS7TN6/Untreated/NONO
# No bad files are found.
# Total Sites:  3894
# ========
# ====================

# %% [markdown]
# ### Difference between Raw and Processed

# %%
display_diff(batches, raws, procs, None, fig_width=8)
# Out:
# batch1
# ========

# %% [markdown]
# ### Variance in each batch (of processed files)

# %%
for batch in batches:
    with contextlib.redirect_stdout(io.StringIO()):
        var = sample_and_calc_variance(root_directory_proc, batch, 
                                       sample_size_per_markers=200, cond_count=1, rep_count=len(AC_reps_new), 
                                       num_markers=len(AC_markers_new))
    print(f'{batch} var: ',var)
# Out:
# batch1 var:  0.020814432144532883

# %% [markdown]
# ## Preprocessing Filtering qc
# By order of filtering

# %% [markdown]
# ### 1. % site survival after Brenner on DAPI channel
# Percentage out of the total sites

# %%
dapi_filter_by_brenner = show_site_survival_dapi_brenner(df_dapi,batches, AC_line_colors_new, AC_panels_new,
                                                        figsize=(6,3), reps=AC_reps_new, vmax=5)

# %% [markdown]
# ### 2. % Site survival after Cellpose
# Percentage out of the sites that passed the previous filter. In parenthesis are absolute values.
#
# **A site will be filtered out if Cellpose found 0 cells in it.**

# %%
dapi_filter_by_cellpose = show_site_survival_dapi_cellpose(df_dapi, batches, dapi_filter_by_brenner, 
                                                           AC_line_colors_new, AC_panels_new, figsize=(10,5), reps=AC_reps_new)

# %% [markdown]
# ### 3. % Site survival by tiling
# Percentage out of the sites that passed the previous filter. In parenthesis are absolute values.
#
# **A site will be filtered out if after tiling, no tile is containing at least 85% of a cell that Cellpose detected.**

# %%
dapi_filter_by_tiling=show_site_survival_dapi_tiling(df_dapi, batches, dapi_filter_by_cellpose, 
                                                     AC_line_colors_new, AC_panels_new,figsize=(10,5), reps=AC_reps_new)

# %% [markdown]
# ### 4. % Site survival after Brenner on target channel
# Percentage out of the sites that passed the previous filter. In parenthesis are absolute values (if different than the percentages).

# %%
show_site_survival_target_brenner(df_dapi, df_target, dapi_filter_by_tiling,
                                 figsize=(10,8), markers=AC_markers_new)

# %% [markdown]
# ## Statistics About the Processed Files

# %%
names = ['Total number of tiles', 'Total number of whole cells']
stats = ['n_valid_tiles','site_whole_cells_counts_sum','site_cell_count','site_cell_count_sum']
total_sum = calc_total_sums(df_target, df_dapi, stats, AC_markers_new)

# %% [markdown]
# ### Total tiles

# %%
total_sum.n_valid_tiles.sum()
# Out:
# 52114

# %% [markdown]
# ### Total whole nuclei in tiles

# %%
total_sum[total_sum.marker =='DAPI'].site_whole_cells_counts_sum.sum()
# Out:
# 11523.0

# %% [markdown]
# ### Total nuclei in sites

# %%
total_sum[total_sum.marker =='DAPI'].site_cell_count.sum()
# Out:
# 54859.0

# %%
show_total_sum_tables(total_sum)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>n_valid_tiles</th>
#       <th>% valid tiles</th>
#       <th>site_whole_cells_counts_sum</th>
#       <th>site_cell_count</th>
#     </tr>
#     <tr>
#       <th>batch1</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>915.000000</td>
#       <td>915.000000</td>
#       <td>915.000000</td>
#       <td>915.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>56.955191</td>
#       <td>0.569552</td>
#       <td>35.637158</td>
#       <td>171.818579</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>21.092927</td>
#       <td>0.210929</td>
#       <td>15.263532</td>
#       <td>67.599751</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>5.000000</td>
#       <td>0.050000</td>
#       <td>2.000000</td>
#       <td>11.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>45.000000</td>
#       <td>0.450000</td>
#       <td>25.000000</td>
#       <td>127.500000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>60.000000</td>
#       <td>0.600000</td>
#       <td>37.000000</td>
#       <td>178.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>72.000000</td>
#       <td>0.720000</td>
#       <td>47.000000</td>
#       <td>219.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>105.000000</td>
#       <td>1.050000</td>
#       <td>86.000000</td>
#       <td>343.000000</td>
#     </tr>
#     <tr>
#       <th>sum</th>
#       <td>52114.000000</td>
#       <td>NaN</td>
#       <td>32608.000000</td>
#       <td>157214.000000</td>
#     </tr>
#     <tr>
#       <th>expected_count</th>
#       <td>450.000000</td>
#       <td>450.000000</td>
#       <td>450.000000</td>
#       <td>450.000000</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>n valid tiles</th>
#       <th>% valid tiles</th>
#       <th>site_whole_cells_counts_sum</th>
#       <th>site_cell_count</th>
#     </tr>
#     <tr>
#       <th>All batches</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>915.000000</td>
#       <td>915.000000</td>
#       <td>915.000000</td>
#       <td>915.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>56.955191</td>
#       <td>0.569552</td>
#       <td>35.637158</td>
#       <td>171.818579</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>21.092927</td>
#       <td>0.210929</td>
#       <td>15.263532</td>
#       <td>67.599751</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>5.000000</td>
#       <td>0.050000</td>
#       <td>2.000000</td>
#       <td>11.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>45.000000</td>
#       <td>0.450000</td>
#       <td>25.000000</td>
#       <td>127.500000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>60.000000</td>
#       <td>0.600000</td>
#       <td>37.000000</td>
#       <td>178.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>72.000000</td>
#       <td>0.720000</td>
#       <td>47.000000</td>
#       <td>219.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>105.000000</td>
#       <td>1.050000</td>
#       <td>86.000000</td>
#       <td>343.000000</td>
#     </tr>
#     <tr>
#       <th>sum</th>
#       <td>52114.000000</td>
#       <td>NaN</td>
#       <td>32608.000000</td>
#       <td>157214.000000</td>
#     </tr>
#     <tr>
#       <th>expected_count</th>
#       <td>450.000000</td>
#       <td>450.000000</td>
#       <td>450.000000</td>
#       <td>450.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Show Total Tile Counts
# For each batch, cell line, replicate and markerTotal number of tiles

# %%
to_heatmap = total_sum.rename(columns={'n_valid_tiles':'index'})
plot_filtering_heatmap(to_heatmap, extra_index='marker', vmin=None, vmax=None,
                      xlabel = 'Total number of tiles', show_sum=True, figsize=(8,8))
# Out:
# /home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps/tools/preprocessing_tools/qc_reports/qc_utils.py:388: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for batch in batches:
# /home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps/tools/preprocessing_tools/qc_reports/qc_utils.py:388: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for batch in batches:

# %% [markdown]
# ### Show Total Whole Cell Counts
# For each batch, cell line, replicate and markerTotal number of tiles

# %%
to_heatmap = total_sum.rename(columns={'site_whole_cells_counts_sum':'index'})
plot_filtering_heatmap(to_heatmap, extra_index='marker', vmin=None, vmax=None,
                      xlabel = 'Total number of whole cells', show_sum=True, figsize=(8,8))
# Out:
# /home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps/tools/preprocessing_tools/qc_reports/qc_utils.py:388: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for batch in batches:
# /home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps/tools/preprocessing_tools/qc_reports/qc_utils.py:388: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   for batch in batches:

# %% [markdown]
# ### Show **Cell Count** Statistics per Batch

# %%
df_no_empty_sites = df_dapi[df_dapi.n_valid_tiles !=0]
plot_cell_count(df_no_empty_sites, AC_lines_order_new, AC_custom_palette_new, y='site_cell_count_sum', 
                title='Cell Count Average per Site (from tiles)', figsize=(9,4))

plot_cell_count(df_no_empty_sites, AC_lines_order_new, AC_custom_palette_new, y='site_whole_cells_counts_sum',
                title='Whole Cell Count Average per Site',figsize=(9,4))

plot_cell_count(df_no_empty_sites, AC_lines_order_new, AC_custom_palette_new, y='site_cell_count',
               title='Cellpose Cell Count Average per Site',figsize=(9,4))

# %% [markdown]
# ### Show **Tiles** per Site Statistics

# %%
df_dapi.groupby(['cell_line_cond']).n_valid_tiles.mean()
# Out:
# cell_line_cond
# C9-CS2YNL              14.819672
# C9-CS7VCZ              13.760684
# C9-CS8RFT              14.470588
# Ctrl-EDi022            14.141667
# Ctrl-EDi029            12.216667
# Ctrl-EDi037            10.461538
# SALSNegative-CS0ANK    12.899160
# SALSNegative-CS0JPP     9.364407
# SALSNegative-CS6ZU8    11.610169
# SALSPositive-CS2FN3    14.241667
# SALSPositive-CS4ZCD    11.200000
# SALSPositive-CS7TN6    15.941667
# Name: n_valid_tiles, dtype: float64

# %%
plot_catplot(df_dapi, sns.color_palette('colorblind'), reps=AC_reps_new,x='cell_line', y_title='Valid Tiles Count', x_title='Cell Line', 
             y='n_valid_tiles', hue='rep',
             height=5, aspect=5)
# Out:
# /home/projects/hornsteinlab/Collaboration/MOmaps_Noam/MOmaps/tools/preprocessing_tools/qc_reports/qc_utils.py:1068: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   cbar=False, ax=axs[0], vmin=vmin, vmax=vmax,annot_kws={"fontsize": 12})

# %% [markdown]
# ### Show Mean of cell count in valid tiles

# %%
plot_hm_of_mean_cell_count_per_tile(df_dapi, split_by=None,rows='cell_line', columns='rep')

# %% [markdown]
# # Assessing Staining Reproducibility and Outliers

# %%
# for batch in batches:
#     print(batch)
#     run_calc_hist_new(batch,AC_cell_lines_for_disp, AC_markers, root_directory_raw, root_directory_proc,
#                            hist_sample=10,sample_size_per_markers=10, ncols=4, nrows=1, figsize=(6,2))
#     print("="*30)

# %%
# save notebook as HTML ( the HTML will be saved in the same folder the original script is)
display(Javascript('IPython.notebook.save_checkpoint();'))
os.system(f'jupyter nbconvert --to html tools/preprocessing_tools/qc_reports/qc_report_CoyneLab_NEW.ipynb --output {NOVA_HOME}/manuscript/preprocessing_qc_reports/qc_report_CoyneLab_iPSC_patients_NEW.html')
