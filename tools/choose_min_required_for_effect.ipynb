# %%
import os
import sys
import pandas as pd
import numpy as np

os.environ['NOVA_HOME'] = '/home/projects/hornsteinlab/Collaboration/NOVA/'
os.environ['NOVA_DATA_HOME'] = '/home/projects/hornsteinlab/Collaboration/NOVA/input'

sys.path.insert(1, os.getenv("NOVA_HOME"))
print(f"NOVA_HOME: {os.getenv('NOVA_HOME')}")

from manuscript.effects_config import NeuronsEffectWTBaselineConfig
from src.datasets.dataset_config import DatasetConfig
from src.embeddings.embeddings_utils import load_embeddings
# Out:
# NOVA_HOME: /home/projects/hornsteinlab/Collaboration/NOVA/

# %%
class NeuronsDay8NEWConfig(DatasetConfig):
    def __init__(self):
        super().__init__()

        self.INPUT_FOLDERS = ["batch1", 'batch2', 'batch3', 'batch7', 'batch8', 'batch9']
        self.EXPERIMENT_TYPE = 'neuronsDay8_new'

        self.CELL_LINES = ['WT', 'OPTN', 'TBK1', 'FUSHomozygous', 'FUSHeterozygous', 'FUSRevertant', 'TDP43']
        self.CONDITIONS = ['Untreated']

class dNLSConfig(DatasetConfig):
    def __init__(self):
        super().__init__()
        self.INPUT_FOLDERS = ["batch1", 'batch2', 'batch4', 'batch5', 'batch6']
        self.EXPERIMENT_TYPE = 'dNLS'

        self.CELL_LINES = ['dNLS']

# %%
def prepare_embeddings_df(embeddings: np.ndarray[float], 
                           labels: np.ndarray[str], paths) -> pd.DataFrame:
        """
        Create a DataFrame with embeddings and metadata parsed from sample labels.
        Parses labels of the form "marker_cellline_condition_batch_rep" into separate columns.

        Args:
            embeddings (np.ndarray[float]):     Embeddings array of shape (n_samples, n_features).
            labels (np.ndarray[str]):           Array of label strings matching embedding rows.

        Returns:
            pd.DataFrame: DataFrame containing embedding columns plus columns:
                ['marker', 'cell_line', 'condition', 'batch', 'rep'].

        Raises:
            ValueError: If any label string does not contain exactly 5 underscore-separated parts.
        """
        df = pd.DataFrame(embeddings)
        df['label'] = labels
        df['site'] = [p.split(os.sep)[-2] for p in paths]
        df['tile_number'] = [int(p.split(os.sep)[-1]) for p in paths]

        # Split and validate
        split_labels = df['label'].str.split('_', expand=True)

        # Check that all labels have 5 parts
        if split_labels.shape[1] != 5:
            invalid_labels = df['label'][split_labels.isnull().any(axis=1)].tolist()
            raise ValueError(
                f"Some label strings are invalid (expected 5 parts separated by '_').\n"
                f"Example invalid labels: {invalid_labels[:5]}"
            )
        df[['marker', 'cell_line', 'condition', 'batch', 'rep']] = split_labels
        return df

def count_sites_all(df: pd.DataFrame) -> pd.DataFrame:
    """
    Count unique sites for each (marker, cell_line, condition, batch).

    Args:
        df: DataFrame with columns ['marker', 'cell_line', 'condition', 'batch', 'site']

    Returns:
        DataFrame with columns ['marker', 'cell_line', 'condition', 'batch', 'n_sites']
    """
    result = (
        df.groupby(["marker", "cell_line", "condition", "batch"])["site"]
          .nunique()
          .reset_index(name="n_sites").sort_values(by=["marker", "batch"])
    )
    return result

def show_filtered_out(df: pd.DataFrame, min_sites_count:int):
    filtered = df[df["n_sites"] < min_sites_count]
    if not filtered.empty:
        print(f"Filtered out samples with less than {min_sites_count} sites:")
        print(filtered)
    else:
        print(f"All samples meet the minimum site count of {min_sites_count}.")

def get_counts_sites(config_data):
    output_folder_path = f"/home/projects/hornsteinlab/Collaboration/NOVA/outputs/vit_models/finetunedModel_MLPHead_acrossBatches_B56789_80pct_frozen"

    embeddings, labels, paths = load_embeddings(output_folder_path, config_data)
    print(f"Loaded embeddings: {embeddings.shape}, labels: {labels.shape}")

    embeddings_df = prepare_embeddings_df(embeddings, labels, paths)
    print(f"Prepared embeddings DataFrame: {embeddings_df.shape}")

    return count_sites_all(embeddings_df)

# %%
pd.set_option("display.max_rows", None)

# %%
dNLS_counts = get_counts_sites(dNLSConfig())
dNLS_counts
# Out:
# Loaded embeddings: (1134025, 192), labels: (1134025,)
# Prepared embeddings DataFrame: (1134025, 200)
#            marker cell_line  condition   batch  n_sites
# 0          ANXA11      dNLS        DOX  batch1      627
# 5          ANXA11      dNLS  Untreated  batch1      652
# 1          ANXA11      dNLS        DOX  batch2      331
# 6          ANXA11      dNLS  Untreated  batch2      260
# 2          ANXA11      dNLS        DOX  batch4      712
# 7          ANXA11      dNLS  Untreated  batch4      683
# 3          ANXA11      dNLS        DOX  batch5      749
# 8          ANXA11      dNLS  Untreated  batch5      745
# 4          ANXA11      dNLS        DOX  batch6      397
# 9          ANXA11      dNLS  Untreated  batch6      233
# 10           CLTC      dNLS        DOX  batch1      253
# 15           CLTC      dNLS  Untreated  batch1      326
# 11           CLTC      dNLS        DOX  batch2      481
# 16           CLTC      dNLS  Untreated  batch2      224
# 12           CLTC      dNLS        DOX  batch4      615
# 17           CLTC      dNLS  Untreated  batch4      578
# 13           CLTC      dNLS        DOX  batch5      690
# 18           CLTC      dNLS  Untreated  batch5      680
# 14           CLTC      dNLS        DOX  batch6      215
# 19           CLTC      dNLS  Untreated  batch6      271
# 20   Calreticulin      dNLS        DOX  batch1      485
# 25   Calreticulin      dNLS  Untreated  batch1      157
# 21   Calreticulin      dNLS        DOX  batch2      465
# 26   Calreticulin      dNLS  Untreated  batch2      244
# 22   Calreticulin      dNLS        DOX  batch4      721
# 27   Calreticulin      dNLS  Untreated  batch4      668
# 23   Calreticulin      dNLS        DOX  batch5      749
# 28   Calreticulin      dNLS  Untreated  batch5      750
# 24   Calreticulin      dNLS        DOX  batch6      249
# 29   Calreticulin      dNLS  Untreated  batch6      124
# 30           DAPI      dNLS        DOX  batch1     4597
# 35           DAPI      dNLS  Untreated  batch1     3430
# 31           DAPI      dNLS        DOX  batch2     4680
# 36           DAPI      dNLS  Untreated  batch2     3419
# 32           DAPI      dNLS        DOX  batch4     7550
# 37           DAPI      dNLS  Untreated  batch4     6553
# 33           DAPI      dNLS        DOX  batch5     8025
# 38           DAPI      dNLS  Untreated  batch5     8373
# 34           DAPI      dNLS        DOX  batch6     3708
# 39           DAPI      dNLS  Untreated  batch6     2453
# 40          DCP1A      dNLS        DOX  batch1      106
# 45          DCP1A      dNLS  Untreated  batch1       20
# 41          DCP1A      dNLS        DOX  batch2      195
# 46          DCP1A      dNLS  Untreated  batch2      203
# 42          DCP1A      dNLS        DOX  batch4      445
# 47          DCP1A      dNLS  Untreated  batch4      442
# 43          DCP1A      dNLS        DOX  batch5      473
# 48          DCP1A      dNLS  Untreated  batch5      730
# 44          DCP1A      dNLS        DOX  batch6       91
# 49          DCP1A      dNLS  Untreated  batch6       40
# 50           FMRP      dNLS        DOX  batch1      240
# 55           FMRP      dNLS  Untreated  batch1      173
# 51           FMRP      dNLS        DOX  batch2      264
# 56           FMRP      dNLS  Untreated  batch2      283
# 52           FMRP      dNLS        DOX  batch4      628
# 57           FMRP      dNLS  Untreated  batch4      400
# 53           FMRP      dNLS        DOX  batch5      639
# 58           FMRP      dNLS  Untreated  batch5      599
# 54           FMRP      dNLS        DOX  batch6      233
# 59           FMRP      dNLS  Untreated  batch6      174
# 60            FUS      dNLS        DOX  batch1      633
# 65            FUS      dNLS  Untreated  batch1      439
# 61            FUS      dNLS        DOX  batch2      579
# 66            FUS      dNLS  Untreated  batch2      379
# 62            FUS      dNLS        DOX  batch4      741
# 67            FUS      dNLS  Untreated  batch4      669
# 63            FUS      dNLS        DOX  batch5      740
# 68            FUS      dNLS  Untreated  batch5      746
# 64            FUS      dNLS        DOX  batch6      615
# 69            FUS      dNLS  Untreated  batch6      327
# 70          G3BP1      dNLS        DOX  batch1      247
# 75          G3BP1      dNLS  Untreated  batch1      178
# 71          G3BP1      dNLS        DOX  batch2      265
# 76          G3BP1      dNLS  Untreated  batch2      286
# 72          G3BP1      dNLS        DOX  batch4      648
# 77          G3BP1      dNLS  Untreated  batch4      408
# 73          G3BP1      dNLS        DOX  batch5      643
# 78          G3BP1      dNLS  Untreated  batch5      608
# 74          G3BP1      dNLS        DOX  batch6      237
# 79          G3BP1      dNLS  Untreated  batch6      176
# 80          GM130      dNLS        DOX  batch1      483
# 85          GM130      dNLS  Untreated  batch1      159
# 81          GM130      dNLS        DOX  batch2      461
# 86          GM130      dNLS  Untreated  batch2      241
# 82          GM130      dNLS        DOX  batch4      721
# 87          GM130      dNLS  Untreated  batch4      667
# 83          GM130      dNLS        DOX  batch5      749
# 88          GM130      dNLS  Untreated  batch5      747
# 84          GM130      dNLS        DOX  batch6      248
# 89          GM130      dNLS  Untreated  batch6      124
# 90        HNRNPA1      dNLS        DOX  batch1      271
# 95        HNRNPA1      dNLS  Untreated  batch1       84
# 91        HNRNPA1      dNLS        DOX  batch2      255
# 96        HNRNPA1      dNLS  Untreated  batch2      242
# 92        HNRNPA1      dNLS        DOX  batch4      430
# 97        HNRNPA1      dNLS  Untreated  batch4      353
# 93        HNRNPA1      dNLS        DOX  batch5      573
# 98        HNRNPA1      dNLS  Untreated  batch5      663
# 94        HNRNPA1      dNLS        DOX  batch6       92
# 99        HNRNPA1      dNLS  Untreated  batch6      104
# 100         KIF5A      dNLS        DOX  batch1      666
# 105         KIF5A      dNLS  Untreated  batch1      475
# 101         KIF5A      dNLS        DOX  batch2      676
# 106         KIF5A      dNLS  Untreated  batch2      446
# 102         KIF5A      dNLS        DOX  batch4      729
# 107         KIF5A      dNLS  Untreated  batch4      519
# 103         KIF5A      dNLS        DOX  batch5      725
# 108         KIF5A      dNLS  Untreated  batch5      729
# 104         KIF5A      dNLS        DOX  batch6      724
# 109         KIF5A      dNLS  Untreated  batch6      561
# 110         LAMP1      dNLS        DOX  batch1      514
# 115         LAMP1      dNLS  Untreated  batch1      559
# 111         LAMP1      dNLS        DOX  batch2      305
# 116         LAMP1      dNLS  Untreated  batch2      250
# 112         LAMP1      dNLS        DOX  batch4      620
# 117         LAMP1      dNLS  Untreated  batch4      587
# 113         LAMP1      dNLS        DOX  batch5      667
# 118         LAMP1      dNLS  Untreated  batch5      673
# 114         LAMP1      dNLS        DOX  batch6      375
# 119         LAMP1      dNLS  Untreated  batch6      203
# 120        LSM14A      dNLS        DOX  batch1      271
# 125        LSM14A      dNLS  Untreated  batch1       84
# 121        LSM14A      dNLS        DOX  batch2      255
# 126        LSM14A      dNLS  Untreated  batch2      240
# 122        LSM14A      dNLS        DOX  batch4      430
# 127        LSM14A      dNLS  Untreated  batch4      353
# 123        LSM14A      dNLS        DOX  batch5      573
# 128        LSM14A      dNLS  Untreated  batch5      663
# 124        LSM14A      dNLS        DOX  batch6       92
# 129        LSM14A      dNLS  Untreated  batch6      104
# 130           NCL      dNLS        DOX  batch1      632
# 135           NCL      dNLS  Untreated  batch1      439
# 131           NCL      dNLS        DOX  batch2      579
# 136           NCL      dNLS  Untreated  batch2      379
# 132           NCL      dNLS        DOX  batch4      741
# 137           NCL      dNLS  Untreated  batch4      669
# 133           NCL      dNLS        DOX  batch5      740
# 138           NCL      dNLS  Untreated  batch5      746
# 134           NCL      dNLS        DOX  batch6      615
# 139           NCL      dNLS  Untreated  batch6      327
# 140          NEMO      dNLS        DOX  batch1      106
# 145          NEMO      dNLS  Untreated  batch1       20
# 141          NEMO      dNLS        DOX  batch2      194
# 146          NEMO      dNLS  Untreated  batch2      203
# 142          NEMO      dNLS        DOX  batch4      442
# 147          NEMO      dNLS  Untreated  batch4      442
# 143          NEMO      dNLS        DOX  batch5      472
# 148          NEMO      dNLS  Untreated  batch5      728
# 144          NEMO      dNLS        DOX  batch6       91
# 149          NEMO      dNLS  Untreated  batch6       40
# 150          NONO      dNLS        DOX  batch1      652
# 155          NONO      dNLS  Untreated  batch1      445
# 151          NONO      dNLS        DOX  batch2      642
# 156          NONO      dNLS  Untreated  batch2      562
# 152          NONO      dNLS        DOX  batch4      734
# 157          NONO      dNLS  Untreated  batch4      594
# 153          NONO      dNLS        DOX  batch5      741
# 158          NONO      dNLS  Untreated  batch5      743
# 154          NONO      dNLS        DOX  batch6      627
# 159          NONO      dNLS  Untreated  batch6      468
# 160         PEX14      dNLS        DOX  batch1      363
# 165         PEX14      dNLS  Untreated  batch1      465
# 161         PEX14      dNLS        DOX  batch2      285
# 166         PEX14      dNLS  Untreated  batch2      375
# 162         PEX14      dNLS        DOX  batch4      732
# 167         PEX14      dNLS  Untreated  batch4      719
# 163         PEX14      dNLS        DOX  batch5      736
# 168         PEX14      dNLS  Untreated  batch5      729
# 164         PEX14      dNLS        DOX  batch6       72
# 169         PEX14      dNLS  Untreated  batch6       30
# 170           PML      dNLS        DOX  batch1      199
# 175           PML      dNLS  Untreated  batch1      145
# 171           PML      dNLS        DOX  batch2      330
# 176           PML      dNLS  Untreated  batch2       38
# 172           PML      dNLS        DOX  batch4      711
# 177           PML      dNLS  Untreated  batch4      405
# 173           PML      dNLS        DOX  batch5      718
# 178           PML      dNLS  Untreated  batch5      729
# 174           PML      dNLS        DOX  batch6      237
# 179           PML      dNLS  Untreated  batch6       33
# 180         PSD95      dNLS        DOX  batch1      253
# 185         PSD95      dNLS  Untreated  batch1      326
# 181         PSD95      dNLS        DOX  batch2      481
# 186         PSD95      dNLS  Untreated  batch2      224
# 182         PSD95      dNLS        DOX  batch4      615
# 187         PSD95      dNLS  Untreated  batch4      578
# 183         PSD95      dNLS        DOX  batch5      690
# 188         PSD95      dNLS  Untreated  batch5      680
# 184         PSD95      dNLS        DOX  batch6      215
# 189         PSD95      dNLS  Untreated  batch6      272
# 190          PURA      dNLS        DOX  batch1      245
# 195          PURA      dNLS  Untreated  batch1      178
# 191          PURA      dNLS        DOX  batch2      263
# 196          PURA      dNLS  Untreated  batch2      286
# 192          PURA      dNLS        DOX  batch4      646
# 197          PURA      dNLS  Untreated  batch4      408
# 193          PURA      dNLS        DOX  batch5      641
# 198          PURA      dNLS  Untreated  batch5      608
# 194          PURA      dNLS        DOX  batch6      236
# 199          PURA      dNLS  Untreated  batch6      174
# 200    Phalloidin      dNLS        DOX  batch1      253
# 205    Phalloidin      dNLS  Untreated  batch1      326
# 201    Phalloidin      dNLS        DOX  batch2      481
# 206    Phalloidin      dNLS  Untreated  batch2      224
# 202    Phalloidin      dNLS        DOX  batch4      615
# 207    Phalloidin      dNLS  Untreated  batch4      579
# 203    Phalloidin      dNLS        DOX  batch5      690
# 208    Phalloidin      dNLS  Untreated  batch5      680
# 204    Phalloidin      dNLS        DOX  batch6      215
# 209    Phalloidin      dNLS  Untreated  batch6      272
# 210          SNCA      dNLS        DOX  batch1      310
# 215          SNCA      dNLS  Untreated  batch1      403
# 211          SNCA      dNLS        DOX  batch2      235
# 216          SNCA      dNLS  Untreated  batch2      309
# 212          SNCA      dNLS        DOX  batch4      587
# 217          SNCA      dNLS  Untreated  batch4      617
# 213          SNCA      dNLS        DOX  batch5      625
# 218          SNCA      dNLS  Untreated  batch5      597
# 214          SNCA      dNLS        DOX  batch6       71
# 219          SNCA      dNLS  Untreated  batch6       30
# 220           SON      dNLS        DOX  batch1      652
# 225           SON      dNLS  Untreated  batch1      445
# 221           SON      dNLS        DOX  batch2      642
# 226           SON      dNLS  Untreated  batch2      563
# 222           SON      dNLS        DOX  batch4      745
# 227           SON      dNLS  Untreated  batch4      594
# 223           SON      dNLS        DOX  batch5      746
# 228           SON      dNLS  Untreated  batch5      747
# 224           SON      dNLS        DOX  batch6      636
# 229           SON      dNLS  Untreated  batch6      472
# 230        SQSTM1      dNLS        DOX  batch1      664
# 235        SQSTM1      dNLS  Untreated  batch1      467
# 231        SQSTM1      dNLS        DOX  batch2      669
# 236        SQSTM1      dNLS  Untreated  batch2      441
# 232        SQSTM1      dNLS        DOX  batch4      713
# 237        SQSTM1      dNLS  Untreated  batch4      514
# 233        SQSTM1      dNLS        DOX  batch5      711
# 238        SQSTM1      dNLS  Untreated  batch5      715
# 234        SQSTM1      dNLS        DOX  batch6      719
# 239        SQSTM1      dNLS  Untreated  batch6      559
# 240         TDP43      dNLS        DOX  batch1      199
# 245         TDP43      dNLS  Untreated  batch1      145
# 241         TDP43      dNLS        DOX  batch2      328
# 246         TDP43      dNLS  Untreated  batch2       38
# 242         TDP43      dNLS        DOX  batch4      708
# 247         TDP43      dNLS  Untreated  batch4      405
# 243         TDP43      dNLS        DOX  batch5      717
# 248         TDP43      dNLS  Untreated  batch5      729
# 244         TDP43      dNLS        DOX  batch6      232
# 249         TDP43      dNLS  Untreated  batch6       33
# 250          TIA1      dNLS        DOX  batch1      242
# 255          TIA1      dNLS  Untreated  batch1      172
# 251          TIA1      dNLS        DOX  batch2      226
# 256          TIA1      dNLS  Untreated  batch2      208
# 252          TIA1      dNLS        DOX  batch4      494
# 257          TIA1      dNLS  Untreated  batch4      675
# 253          TIA1      dNLS        DOX  batch5      606
# 258          TIA1      dNLS  Untreated  batch5      659
# 254          TIA1      dNLS        DOX  batch6      169
# 259          TIA1      dNLS  Untreated  batch6      117
# 260        TOMM20      dNLS        DOX  batch1      240
# 265        TOMM20      dNLS  Untreated  batch1      171
# 261        TOMM20      dNLS        DOX  batch2      221
# 266        TOMM20      dNLS  Untreated  batch2      206
# 262        TOMM20      dNLS        DOX  batch4      485
# 267        TOMM20      dNLS  Untreated  batch4      654
# 263        TOMM20      dNLS        DOX  batch5      592
# 268        TOMM20      dNLS  Untreated  batch5      648
# 264        TOMM20      dNLS        DOX  batch6      167
# 269        TOMM20      dNLS  Untreated  batch6      114
# 270       Tubulin      dNLS        DOX  batch1      667
# 275       Tubulin      dNLS  Untreated  batch1      477
# 271       Tubulin      dNLS        DOX  batch2      678
# 276       Tubulin      dNLS  Untreated  batch2      447
# 272       Tubulin      dNLS        DOX  batch4      722
# 277       Tubulin      dNLS  Untreated  batch4      517
# 273       Tubulin      dNLS        DOX  batch5      716
# 278       Tubulin      dNLS  Untreated  batch5      724
# 274       Tubulin      dNLS        DOX  batch6      726
# 279       Tubulin      dNLS  Untreated  batch6      559
# 280   mitotracker      dNLS        DOX  batch1      240
# 285   mitotracker      dNLS  Untreated  batch1      171
# 281   mitotracker      dNLS        DOX  batch2      221
# 286   mitotracker      dNLS  Untreated  batch2      206
# 282   mitotracker      dNLS        DOX  batch4      485
# 287   mitotracker      dNLS  Untreated  batch4      654
# 283   mitotracker      dNLS        DOX  batch5      592
# 288   mitotracker      dNLS  Untreated  batch5      648
# 284   mitotracker      dNLS        DOX  batch6      167
# 289   mitotracker      dNLS  Untreated  batch6      114

# %%
show_filtered_out(dNLS_counts, 80)
# Out:
# Filtered out samples with less than 80 sites:
#     marker cell_line  condition   batch  n_sites
# 45   DCP1A      dNLS  Untreated  batch1       20
# 49   DCP1A      dNLS  Untreated  batch6       40
# 145   NEMO      dNLS  Untreated  batch1       20
# 149   NEMO      dNLS  Untreated  batch6       40
# 164  PEX14      dNLS        DOX  batch6       72
# 169  PEX14      dNLS  Untreated  batch6       30
# 176    PML      dNLS  Untreated  batch2       38
# 179    PML      dNLS  Untreated  batch6       33
# 214   SNCA      dNLS        DOX  batch6       71
# 219   SNCA      dNLS  Untreated  batch6       30
# 246  TDP43      dNLS  Untreated  batch2       38
# 249  TDP43      dNLS  Untreated  batch6       33

# %%
neuronsDay8_new_counts = get_counts_sites(NeuronsDay8NEWConfig())
neuronsDay8_new_counts
# Out:
# Loaded embeddings: (6420755, 192), labels: (6420755,)
# Prepared embeddings DataFrame: (6420755, 200)
#             marker        cell_line  condition   batch  n_sites
# 0           ANXA11  FUSHeterozygous  Untreated  batch1      480
# 6           ANXA11    FUSHomozygous  Untreated  batch1      377
# 12          ANXA11     FUSRevertant  Untreated  batch1      427
# 18          ANXA11             OPTN  Untreated  batch1      415
# 24          ANXA11             TBK1  Untreated  batch1      438
# 30          ANXA11            TDP43  Untreated  batch1      485
# 36          ANXA11               WT  Untreated  batch1      447
# 1           ANXA11  FUSHeterozygous  Untreated  batch2      425
# 7           ANXA11    FUSHomozygous  Untreated  batch2      431
# 13          ANXA11     FUSRevertant  Untreated  batch2      421
# 19          ANXA11             OPTN  Untreated  batch2      468
# 25          ANXA11             TBK1  Untreated  batch2      476
# 31          ANXA11            TDP43  Untreated  batch2      452
# 37          ANXA11               WT  Untreated  batch2      481
# 2           ANXA11  FUSHeterozygous  Untreated  batch3      408
# 8           ANXA11    FUSHomozygous  Untreated  batch3      472
# 14          ANXA11     FUSRevertant  Untreated  batch3      451
# 20          ANXA11             OPTN  Untreated  batch3      482
# 26          ANXA11             TBK1  Untreated  batch3      467
# 32          ANXA11            TDP43  Untreated  batch3      446
# 38          ANXA11               WT  Untreated  batch3      465
# 3           ANXA11  FUSHeterozygous  Untreated  batch7      463
# 9           ANXA11    FUSHomozygous  Untreated  batch7      484
# 15          ANXA11     FUSRevertant  Untreated  batch7      428
# 21          ANXA11             OPTN  Untreated  batch7      468
# 27          ANXA11             TBK1  Untreated  batch7      411
# 33          ANXA11            TDP43  Untreated  batch7      397
# 39          ANXA11               WT  Untreated  batch7      458
# 4           ANXA11  FUSHeterozygous  Untreated  batch8      469
# 10          ANXA11    FUSHomozygous  Untreated  batch8      484
# 16          ANXA11     FUSRevertant  Untreated  batch8      462
# 22          ANXA11             OPTN  Untreated  batch8      482
# 28          ANXA11             TBK1  Untreated  batch8      475
# 34          ANXA11            TDP43  Untreated  batch8      483
# 40          ANXA11               WT  Untreated  batch8      477
# 5           ANXA11  FUSHeterozygous  Untreated  batch9      127
# 11          ANXA11    FUSHomozygous  Untreated  batch9      104
# 17          ANXA11     FUSRevertant  Untreated  batch9      188
# 23          ANXA11             OPTN  Untreated  batch9      189
# 29          ANXA11             TBK1  Untreated  batch9      148
# 35          ANXA11            TDP43  Untreated  batch9      293
# 41          ANXA11               WT  Untreated  batch9      305
# 42            CLTC  FUSHeterozygous  Untreated  batch1      493
# 48            CLTC    FUSHomozygous  Untreated  batch1      479
# 54            CLTC     FUSRevertant  Untreated  batch1      440
# 60            CLTC             OPTN  Untreated  batch1      487
# 66            CLTC             TBK1  Untreated  batch1      499
# 72            CLTC            TDP43  Untreated  batch1      499
# 78            CLTC               WT  Untreated  batch1      496
# 43            CLTC  FUSHeterozygous  Untreated  batch2      499
# 49            CLTC    FUSHomozygous  Untreated  batch2      486
# 55            CLTC     FUSRevertant  Untreated  batch2      456
# 61            CLTC             OPTN  Untreated  batch2      498
# 67            CLTC             TBK1  Untreated  batch2      500
# 73            CLTC            TDP43  Untreated  batch2      496
# 79            CLTC               WT  Untreated  batch2      486
# 44            CLTC  FUSHeterozygous  Untreated  batch3      491
# 50            CLTC    FUSHomozygous  Untreated  batch3      500
# 56            CLTC     FUSRevertant  Untreated  batch3      474
# 62            CLTC             OPTN  Untreated  batch3      476
# 68            CLTC             TBK1  Untreated  batch3      494
# 74            CLTC            TDP43  Untreated  batch3      490
# 80            CLTC               WT  Untreated  batch3      445
# 45            CLTC  FUSHeterozygous  Untreated  batch7      361
# 51            CLTC    FUSHomozygous  Untreated  batch7      446
# 57            CLTC     FUSRevertant  Untreated  batch7      342
# 63            CLTC             OPTN  Untreated  batch7      496
# 69            CLTC             TBK1  Untreated  batch7      403
# 75            CLTC            TDP43  Untreated  batch7      491
# 81            CLTC               WT  Untreated  batch7      497
# 46            CLTC  FUSHeterozygous  Untreated  batch8      461
# 52            CLTC    FUSHomozygous  Untreated  batch8      478
# 58            CLTC     FUSRevertant  Untreated  batch8      498
# 64            CLTC             OPTN  Untreated  batch8      475
# 70            CLTC             TBK1  Untreated  batch8      469
# 76            CLTC            TDP43  Untreated  batch8      487
# 82            CLTC               WT  Untreated  batch8      409
# 47            CLTC  FUSHeterozygous  Untreated  batch9      500
# 53            CLTC    FUSHomozygous  Untreated  batch9      499
# 59            CLTC     FUSRevertant  Untreated  batch9      490
# 65            CLTC             OPTN  Untreated  batch9      473
# 71            CLTC             TBK1  Untreated  batch9      471
# 77            CLTC            TDP43  Untreated  batch9      493
# 83            CLTC               WT  Untreated  batch9      494
# 84    Calreticulin  FUSHeterozygous  Untreated  batch1      496
# 90    Calreticulin    FUSHomozygous  Untreated  batch1      494
# 96    Calreticulin     FUSRevertant  Untreated  batch1      497
# 102   Calreticulin             OPTN  Untreated  batch1      500
# 108   Calreticulin             TBK1  Untreated  batch1      496
# 114   Calreticulin            TDP43  Untreated  batch1      497
# 120   Calreticulin               WT  Untreated  batch1      499
# 85    Calreticulin  FUSHeterozygous  Untreated  batch2      498
# 91    Calreticulin    FUSHomozygous  Untreated  batch2      497
# 97    Calreticulin     FUSRevertant  Untreated  batch2      441
# 103   Calreticulin             OPTN  Untreated  batch2      446
# 109   Calreticulin             TBK1  Untreated  batch2      497
# 115   Calreticulin            TDP43  Untreated  batch2      479
# 121   Calreticulin               WT  Untreated  batch2      395
# 86    Calreticulin  FUSHeterozygous  Untreated  batch3      487
# 92    Calreticulin    FUSHomozygous  Untreated  batch3      497
# 98    Calreticulin     FUSRevertant  Untreated  batch3      493
# 104   Calreticulin             OPTN  Untreated  batch3      427
# 110   Calreticulin             TBK1  Untreated  batch3      495
# 116   Calreticulin            TDP43  Untreated  batch3      411
# 122   Calreticulin               WT  Untreated  batch3      460
# 87    Calreticulin  FUSHeterozygous  Untreated  batch7      441
# 93    Calreticulin    FUSHomozygous  Untreated  batch7      489
# 99    Calreticulin     FUSRevertant  Untreated  batch7      458
# 105   Calreticulin             OPTN  Untreated  batch7      496
# 111   Calreticulin             TBK1  Untreated  batch7      495
# 117   Calreticulin            TDP43  Untreated  batch7      496
# 123   Calreticulin               WT  Untreated  batch7      491
# 88    Calreticulin  FUSHeterozygous  Untreated  batch8      499
# 94    Calreticulin    FUSHomozygous  Untreated  batch8      500
# 100   Calreticulin     FUSRevertant  Untreated  batch8      500
# 106   Calreticulin             OPTN  Untreated  batch8      500
# 112   Calreticulin             TBK1  Untreated  batch8      498
# 118   Calreticulin            TDP43  Untreated  batch8      497
# 124   Calreticulin               WT  Untreated  batch8      500
# 89    Calreticulin  FUSHeterozygous  Untreated  batch9      495
# 95    Calreticulin    FUSHomozygous  Untreated  batch9      497
# 101   Calreticulin     FUSRevertant  Untreated  batch9      496
# 107   Calreticulin             OPTN  Untreated  batch9      249
# 113   Calreticulin             TBK1  Untreated  batch9      499
# 119   Calreticulin            TDP43  Untreated  batch9      498
# 125   Calreticulin               WT  Untreated  batch9      498
# 126           DAPI  FUSHeterozygous  Untreated  batch1     5704
# 132           DAPI    FUSHomozygous  Untreated  batch1     5359
# 138           DAPI     FUSRevertant  Untreated  batch1     5438
# 144           DAPI             OPTN  Untreated  batch1     5739
# 150           DAPI             TBK1  Untreated  batch1     5793
# 156           DAPI            TDP43  Untreated  batch1     5900
# 162           DAPI               WT  Untreated  batch1     5763
# 127           DAPI  FUSHeterozygous  Untreated  batch2     5569
# 133           DAPI    FUSHomozygous  Untreated  batch2     5623
# 139           DAPI     FUSRevertant  Untreated  batch2     5242
# 145           DAPI             OPTN  Untreated  batch2     5900
# 151           DAPI             TBK1  Untreated  batch2     5868
# 157           DAPI            TDP43  Untreated  batch2     5604
# 163           DAPI               WT  Untreated  batch2     5637
# 128           DAPI  FUSHeterozygous  Untreated  batch3     5481
# 134           DAPI    FUSHomozygous  Untreated  batch3     5616
# 140           DAPI     FUSRevertant  Untreated  batch3     5478
# 146           DAPI             OPTN  Untreated  batch3     5752
# 152           DAPI             TBK1  Untreated  batch3     5780
# 158           DAPI            TDP43  Untreated  batch3     5829
# 164           DAPI               WT  Untreated  batch3     5788
# 129           DAPI  FUSHeterozygous  Untreated  batch7     5646
# 135           DAPI    FUSHomozygous  Untreated  batch7     5733
# 141           DAPI     FUSRevertant  Untreated  batch7     5484
# 147           DAPI             OPTN  Untreated  batch7     5864
# 153           DAPI             TBK1  Untreated  batch7     5231
# 159           DAPI            TDP43  Untreated  batch7     5636
# 165           DAPI               WT  Untreated  batch7     5789
# 130           DAPI  FUSHeterozygous  Untreated  batch8     5789
# 136           DAPI    FUSHomozygous  Untreated  batch8     5935
# 142           DAPI     FUSRevertant  Untreated  batch8     5835
# 148           DAPI             OPTN  Untreated  batch8     5858
# 154           DAPI             TBK1  Untreated  batch8     5789
# 160           DAPI            TDP43  Untreated  batch8     5884
# 166           DAPI               WT  Untreated  batch8     5903
# 131           DAPI  FUSHeterozygous  Untreated  batch9     4889
# 137           DAPI    FUSHomozygous  Untreated  batch9     5115
# 143           DAPI     FUSRevertant  Untreated  batch9     5075
# 149           DAPI             OPTN  Untreated  batch9     5158
# 155           DAPI             TBK1  Untreated  batch9     5111
# 161           DAPI            TDP43  Untreated  batch9     5545
# 167           DAPI               WT  Untreated  batch9     5522
# 168          DCP1A  FUSHeterozygous  Untreated  batch1      405
# 174          DCP1A    FUSHomozygous  Untreated  batch1      464
# 180          DCP1A     FUSRevertant  Untreated  batch1      427
# 186          DCP1A             OPTN  Untreated  batch1      497
# 192          DCP1A             TBK1  Untreated  batch1      497
# 198          DCP1A            TDP43  Untreated  batch1      500
# 204          DCP1A               WT  Untreated  batch1      452
# 169          DCP1A  FUSHeterozygous  Untreated  batch2      349
# 175          DCP1A    FUSHomozygous  Untreated  batch2      498
# 181          DCP1A     FUSRevertant  Untreated  batch2      343
# 187          DCP1A             OPTN  Untreated  batch2      500
# 193          DCP1A             TBK1  Untreated  batch2      497
# 199          DCP1A            TDP43  Untreated  batch2      422
# 205          DCP1A               WT  Untreated  batch2      495
# 170          DCP1A  FUSHeterozygous  Untreated  batch3      466
# 176          DCP1A    FUSHomozygous  Untreated  batch3      492
# 182          DCP1A     FUSRevertant  Untreated  batch3      483
# 188          DCP1A             OPTN  Untreated  batch3      495
# 194          DCP1A             TBK1  Untreated  batch3      415
# 200          DCP1A            TDP43  Untreated  batch3      495
# 206          DCP1A               WT  Untreated  batch3      490
# 171          DCP1A  FUSHeterozygous  Untreated  batch7      436
# 177          DCP1A    FUSHomozygous  Untreated  batch7      476
# 183          DCP1A     FUSRevertant  Untreated  batch7      481
# 189          DCP1A             OPTN  Untreated  batch7      498
# 195          DCP1A             TBK1  Untreated  batch7      489
# 201          DCP1A            TDP43  Untreated  batch7      491
# 207          DCP1A               WT  Untreated  batch7      494
# 172          DCP1A  FUSHeterozygous  Untreated  batch8      498
# 178          DCP1A    FUSHomozygous  Untreated  batch8      481
# 184          DCP1A     FUSRevertant  Untreated  batch8      495
# 190          DCP1A             OPTN  Untreated  batch8      498
# 196          DCP1A             TBK1  Untreated  batch8      498
# 202          DCP1A            TDP43  Untreated  batch8      500
# 208          DCP1A               WT  Untreated  batch8      497
# 173          DCP1A  FUSHeterozygous  Untreated  batch9      500
# 179          DCP1A    FUSHomozygous  Untreated  batch9      500
# 185          DCP1A     FUSRevertant  Untreated  batch9      498
# 191          DCP1A             OPTN  Untreated  batch9      500
# 197          DCP1A             TBK1  Untreated  batch9      500
# 203          DCP1A            TDP43  Untreated  batch9      498
# 209          DCP1A               WT  Untreated  batch9      500
# 210           FMRP  FUSHeterozygous  Untreated  batch1      491
# 216           FMRP    FUSHomozygous  Untreated  batch1      387
# 222           FMRP     FUSRevertant  Untreated  batch1      469
# 228           FMRP             OPTN  Untreated  batch1      445
# 234           FMRP             TBK1  Untreated  batch1      387
# 240           FMRP            TDP43  Untreated  batch1      319
# 246           FMRP               WT  Untreated  batch1      389
# 211           FMRP  FUSHeterozygous  Untreated  batch2      458
# 217           FMRP    FUSHomozygous  Untreated  batch2      466
# 223           FMRP     FUSRevertant  Untreated  batch2      401
# 229           FMRP             OPTN  Untreated  batch2      465
# 235           FMRP             TBK1  Untreated  batch2      457
# 241           FMRP            TDP43  Untreated  batch2      478
# 247           FMRP               WT  Untreated  batch2      238
# 212           FMRP  FUSHeterozygous  Untreated  batch3      399
# 218           FMRP    FUSHomozygous  Untreated  batch3      460
# 224           FMRP     FUSRevertant  Untreated  batch3      362
# 230           FMRP             OPTN  Untreated  batch3      415
# 236           FMRP             TBK1  Untreated  batch3      411
# 242           FMRP            TDP43  Untreated  batch3      441
# 248           FMRP               WT  Untreated  batch3      461
# 213           FMRP  FUSHeterozygous  Untreated  batch7      349
# 219           FMRP    FUSHomozygous  Untreated  batch7      384
# 225           FMRP     FUSRevertant  Untreated  batch7      358
# 231           FMRP             OPTN  Untreated  batch7      415
# 237           FMRP             TBK1  Untreated  batch7      305
# 243           FMRP            TDP43  Untreated  batch7      383
# 249           FMRP               WT  Untreated  batch7      358
# 214           FMRP  FUSHeterozygous  Untreated  batch8      397
# 220           FMRP    FUSHomozygous  Untreated  batch8      445
# 226           FMRP     FUSRevertant  Untreated  batch8      392
# 232           FMRP             OPTN  Untreated  batch8      429
# 238           FMRP             TBK1  Untreated  batch8      354
# 244           FMRP            TDP43  Untreated  batch8      409
# 250           FMRP               WT  Untreated  batch8      414
# 215           FMRP  FUSHeterozygous  Untreated  batch9      482
# 221           FMRP    FUSHomozygous  Untreated  batch9      478
# 227           FMRP     FUSRevertant  Untreated  batch9      446
# 233           FMRP             OPTN  Untreated  batch9      474
# 239           FMRP             TBK1  Untreated  batch9      449
# 245           FMRP            TDP43  Untreated  batch9      470
# 251           FMRP               WT  Untreated  batch9      422
# 252            FUS  FUSHeterozygous  Untreated  batch1      498
# 258            FUS    FUSHomozygous  Untreated  batch1      490
# 264            FUS     FUSRevertant  Untreated  batch1      496
# 270            FUS             OPTN  Untreated  batch1      499
# 276            FUS             TBK1  Untreated  batch1      499
# 282            FUS            TDP43  Untreated  batch1      500
# 288            FUS               WT  Untreated  batch1      500
# 253            FUS  FUSHeterozygous  Untreated  batch2      495
# 259            FUS    FUSHomozygous  Untreated  batch2      496
# 265            FUS     FUSRevertant  Untreated  batch2      455
# 271            FUS             OPTN  Untreated  batch2      498
# 277            FUS             TBK1  Untreated  batch2      457
# 283            FUS            TDP43  Untreated  batch2      414
# 289            FUS               WT  Untreated  batch2      444
# 254            FUS  FUSHeterozygous  Untreated  batch3      485
# 260            FUS    FUSHomozygous  Untreated  batch3      500
# 266            FUS     FUSRevertant  Untreated  batch3      495
# 272            FUS             OPTN  Untreated  batch3      499
# 278            FUS             TBK1  Untreated  batch3      469
# 284            FUS            TDP43  Untreated  batch3      494
# 290            FUS               WT  Untreated  batch3      463
# 255            FUS  FUSHeterozygous  Untreated  batch7        3
# 261            FUS    FUSHomozygous  Untreated  batch7        5
# 267            FUS     FUSRevertant  Untreated  batch7        5
# 273            FUS             OPTN  Untreated  batch7        1
# 279            FUS             TBK1  Untreated  batch7        5
# 285            FUS            TDP43  Untreated  batch7        3
# 291            FUS               WT  Untreated  batch7        4
# 256            FUS  FUSHeterozygous  Untreated  batch8      500
# 262            FUS    FUSHomozygous  Untreated  batch8      499
# 268            FUS     FUSRevertant  Untreated  batch8      498
# 274            FUS             OPTN  Untreated  batch8      500
# 280            FUS             TBK1  Untreated  batch8      496
# 286            FUS            TDP43  Untreated  batch8      498
# 292            FUS               WT  Untreated  batch8      500
# 257            FUS  FUSHeterozygous  Untreated  batch9      500
# 263            FUS    FUSHomozygous  Untreated  batch9      497
# 269            FUS     FUSRevertant  Untreated  batch9      500
# 275            FUS             OPTN  Untreated  batch9      500
# 281            FUS             TBK1  Untreated  batch9      500
# 287            FUS            TDP43  Untreated  batch9      500
# 293            FUS               WT  Untreated  batch9      496
# 294          G3BP1  FUSHeterozygous  Untreated  batch1      496
# 300          G3BP1    FUSHomozygous  Untreated  batch1      422
# 306          G3BP1     FUSRevertant  Untreated  batch1      476
# 312          G3BP1             OPTN  Untreated  batch1      467
# 318          G3BP1             TBK1  Untreated  batch1      388
# 324          G3BP1            TDP43  Untreated  batch1      393
# 330          G3BP1               WT  Untreated  batch1      402
# 295          G3BP1  FUSHeterozygous  Untreated  batch2      468
# 301          G3BP1    FUSHomozygous  Untreated  batch2      470
# 307          G3BP1     FUSRevertant  Untreated  batch2      410
# 313          G3BP1             OPTN  Untreated  batch2      482
# 319          G3BP1             TBK1  Untreated  batch2      471
# 325          G3BP1            TDP43  Untreated  batch2      490
# 331          G3BP1               WT  Untreated  batch2      241
# 296          G3BP1  FUSHeterozygous  Untreated  batch3      421
# 302          G3BP1    FUSHomozygous  Untreated  batch3      467
# 308          G3BP1     FUSRevertant  Untreated  batch3      383
# 314          G3BP1             OPTN  Untreated  batch3      442
# 320          G3BP1             TBK1  Untreated  batch3      432
# 326          G3BP1            TDP43  Untreated  batch3      484
# 332          G3BP1               WT  Untreated  batch3      481
# 297          G3BP1  FUSHeterozygous  Untreated  batch7      426
# 303          G3BP1    FUSHomozygous  Untreated  batch7      422
# 309          G3BP1     FUSRevertant  Untreated  batch7      388
# 315          G3BP1             OPTN  Untreated  batch7      433
# 321          G3BP1             TBK1  Untreated  batch7      318
# 327          G3BP1            TDP43  Untreated  batch7      418
# 333          G3BP1               WT  Untreated  batch7      383
# 298          G3BP1  FUSHeterozygous  Untreated  batch8      461
# 304          G3BP1    FUSHomozygous  Untreated  batch8      478
# 310          G3BP1     FUSRevertant  Untreated  batch8      435
# 316          G3BP1             OPTN  Untreated  batch8      442
# 322          G3BP1             TBK1  Untreated  batch8      373
# 328          G3BP1            TDP43  Untreated  batch8      455
# 334          G3BP1               WT  Untreated  batch8      453
# 299          G3BP1  FUSHeterozygous  Untreated  batch9      492
# 305          G3BP1    FUSHomozygous  Untreated  batch9      484
# 311          G3BP1     FUSRevertant  Untreated  batch9      463
# 317          G3BP1             OPTN  Untreated  batch9      475
# 323          G3BP1             TBK1  Untreated  batch9      460
# 329          G3BP1            TDP43  Untreated  batch9      478
# 335          G3BP1               WT  Untreated  batch9      478
# 336          GM130  FUSHeterozygous  Untreated  batch1      499
# 342          GM130    FUSHomozygous  Untreated  batch1      495
# 348          GM130     FUSRevertant  Untreated  batch1      495
# 354          GM130             OPTN  Untreated  batch1      500
# 360          GM130             TBK1  Untreated  batch1      500
# 366          GM130            TDP43  Untreated  batch1      500
# 372          GM130               WT  Untreated  batch1      499
# 337          GM130  FUSHeterozygous  Untreated  batch2      496
# 343          GM130    FUSHomozygous  Untreated  batch2      493
# 349          GM130     FUSRevertant  Untreated  batch2      406
# 355          GM130             OPTN  Untreated  batch2      447
# 361          GM130             TBK1  Untreated  batch2      497
# 367          GM130            TDP43  Untreated  batch2      481
# 373          GM130               WT  Untreated  batch2      405
# 338          GM130  FUSHeterozygous  Untreated  batch3      473
# 344          GM130    FUSHomozygous  Untreated  batch3      497
# 350          GM130     FUSRevertant  Untreated  batch3      489
# 356          GM130             OPTN  Untreated  batch3      437
# 362          GM130             TBK1  Untreated  batch3      496
# 368          GM130            TDP43  Untreated  batch3      422
# 374          GM130               WT  Untreated  batch3      471
# 339          GM130  FUSHeterozygous  Untreated  batch7      500
# 345          GM130    FUSHomozygous  Untreated  batch7      499
# 351          GM130     FUSRevertant  Untreated  batch7      500
# 357          GM130             OPTN  Untreated  batch7      500
# 363          GM130             TBK1  Untreated  batch7      499
# 369          GM130            TDP43  Untreated  batch7      486
# 375          GM130               WT  Untreated  batch7      499
# 340          GM130  FUSHeterozygous  Untreated  batch8      499
# 346          GM130    FUSHomozygous  Untreated  batch8      500
# 352          GM130     FUSRevertant  Untreated  batch8      500
# 358          GM130             OPTN  Untreated  batch8      498
# 364          GM130             TBK1  Untreated  batch8      500
# 370          GM130            TDP43  Untreated  batch8      500
# 376          GM130               WT  Untreated  batch8      500
# 341          GM130  FUSHeterozygous  Untreated  batch9      500
# 347          GM130    FUSHomozygous  Untreated  batch9      499
# 353          GM130     FUSRevertant  Untreated  batch9      500
# 359          GM130             OPTN  Untreated  batch9      249
# 365          GM130             TBK1  Untreated  batch9      499
# 371          GM130            TDP43  Untreated  batch9      499
# 377          GM130               WT  Untreated  batch9      500
# 378        HNRNPA1  FUSHeterozygous  Untreated  batch1      475
# 384        HNRNPA1    FUSHomozygous  Untreated  batch1      474
# 390        HNRNPA1     FUSRevertant  Untreated  batch1      373
# 396        HNRNPA1             OPTN  Untreated  batch1      499
# 402        HNRNPA1             TBK1  Untreated  batch1      486
# 408        HNRNPA1            TDP43  Untreated  batch1      480
# 414        HNRNPA1               WT  Untreated  batch1      485
# 379        HNRNPA1  FUSHeterozygous  Untreated  batch2      491
# 385        HNRNPA1    FUSHomozygous  Untreated  batch2      485
# 391        HNRNPA1     FUSRevertant  Untreated  batch2      460
# 397        HNRNPA1             OPTN  Untreated  batch2      499
# 403        HNRNPA1             TBK1  Untreated  batch2      474
# 409        HNRNPA1            TDP43  Untreated  batch2      494
# 415        HNRNPA1               WT  Untreated  batch2      496
# 380        HNRNPA1  FUSHeterozygous  Untreated  batch3      441
# 386        HNRNPA1    FUSHomozygous  Untreated  batch3      498
# 392        HNRNPA1     FUSRevertant  Untreated  batch3      444
# 398        HNRNPA1             OPTN  Untreated  batch3      500
# 404        HNRNPA1             TBK1  Untreated  batch3      482
# 410        HNRNPA1            TDP43  Untreated  batch3      500
# 416        HNRNPA1               WT  Untreated  batch3      495
# 381        HNRNPA1  FUSHeterozygous  Untreated  batch7      452
# 387        HNRNPA1    FUSHomozygous  Untreated  batch7      493
# 393        HNRNPA1     FUSRevertant  Untreated  batch7      468
# 399        HNRNPA1             OPTN  Untreated  batch7      495
# 405        HNRNPA1             TBK1  Untreated  batch7      497
# 411        HNRNPA1            TDP43  Untreated  batch7      493
# 417        HNRNPA1               WT  Untreated  batch7      452
# 382        HNRNPA1  FUSHeterozygous  Untreated  batch8      468
# 388        HNRNPA1    FUSHomozygous  Untreated  batch8      488
# 394        HNRNPA1     FUSRevertant  Untreated  batch8      448
# 400        HNRNPA1             OPTN  Untreated  batch8      498
# 406        HNRNPA1             TBK1  Untreated  batch8      495
# 412        HNRNPA1            TDP43  Untreated  batch8      496
# 418        HNRNPA1               WT  Untreated  batch8      497
# 383        HNRNPA1  FUSHeterozygous  Untreated  batch9      470
# 389        HNRNPA1    FUSHomozygous  Untreated  batch9      495
# 395        HNRNPA1     FUSRevertant  Untreated  batch9      479
# 401        HNRNPA1             OPTN  Untreated  batch9      497
# 407        HNRNPA1             TBK1  Untreated  batch9      498
# 413        HNRNPA1            TDP43  Untreated  batch9      497
# 419        HNRNPA1               WT  Untreated  batch9      485
# 420          KIF5A  FUSHeterozygous  Untreated  batch1      376
# 426          KIF5A    FUSHomozygous  Untreated  batch1      355
# 432          KIF5A     FUSRevertant  Untreated  batch1      415
# 438          KIF5A             OPTN  Untreated  batch1      397
# 444          KIF5A             TBK1  Untreated  batch1      382
# 450          KIF5A            TDP43  Untreated  batch1      418
# 456          KIF5A               WT  Untreated  batch1      418
# 421          KIF5A  FUSHeterozygous  Untreated  batch2      436
# 427          KIF5A    FUSHomozygous  Untreated  batch2      419
# 433          KIF5A     FUSRevertant  Untreated  batch2      435
# 439          KIF5A             OPTN  Untreated  batch2      467
# 445          KIF5A             TBK1  Untreated  batch2      461
# 451          KIF5A            TDP43  Untreated  batch2      360
# 457          KIF5A               WT  Untreated  batch2      455
# 422          KIF5A  FUSHeterozygous  Untreated  batch3      404
# 428          KIF5A    FUSHomozygous  Untreated  batch3      329
# 434          KIF5A     FUSRevertant  Untreated  batch3      388
# 440          KIF5A             OPTN  Untreated  batch3      428
# 446          KIF5A             TBK1  Untreated  batch3      447
# 452          KIF5A            TDP43  Untreated  batch3      394
# 458          KIF5A               WT  Untreated  batch3      400
# 423          KIF5A  FUSHeterozygous  Untreated  batch7      392
# 429          KIF5A    FUSHomozygous  Untreated  batch7      412
# 435          KIF5A     FUSRevertant  Untreated  batch7      316
# 441          KIF5A             OPTN  Untreated  batch7      412
# 447          KIF5A             TBK1  Untreated  batch7      411
# 453          KIF5A            TDP43  Untreated  batch7      362
# 459          KIF5A               WT  Untreated  batch7      401
# 424          KIF5A  FUSHeterozygous  Untreated  batch8      371
# 430          KIF5A    FUSHomozygous  Untreated  batch8      369
# 436          KIF5A     FUSRevertant  Untreated  batch8      407
# 442          KIF5A             OPTN  Untreated  batch8      365
# 448          KIF5A             TBK1  Untreated  batch8      364
# 454          KIF5A            TDP43  Untreated  batch8      356
# 460          KIF5A               WT  Untreated  batch8      353
# 425          KIF5A  FUSHeterozygous  Untreated  batch9      430
# 431          KIF5A    FUSHomozygous  Untreated  batch9      378
# 437          KIF5A     FUSRevertant  Untreated  batch9      439
# 443          KIF5A             OPTN  Untreated  batch9      389
# 449          KIF5A             TBK1  Untreated  batch9      331
# 455          KIF5A            TDP43  Untreated  batch9      406
# 461          KIF5A               WT  Untreated  batch9      381
# 462          LAMP1  FUSHeterozygous  Untreated  batch1      148
# 468          LAMP1    FUSHomozygous  Untreated  batch1      138
# 474          LAMP1     FUSRevertant  Untreated  batch1      124
# 480          LAMP1             OPTN  Untreated  batch1      215
# 486          LAMP1             TBK1  Untreated  batch1      158
# 492          LAMP1            TDP43  Untreated  batch1      153
# 498          LAMP1               WT  Untreated  batch1      153
# 463          LAMP1  FUSHeterozygous  Untreated  batch2      187
# 469          LAMP1    FUSHomozygous  Untreated  batch2      179
# 475          LAMP1     FUSRevertant  Untreated  batch2      147
# 481          LAMP1             OPTN  Untreated  batch2      210
# 487          LAMP1             TBK1  Untreated  batch2      286
# 493          LAMP1            TDP43  Untreated  batch2      254
# 499          LAMP1               WT  Untreated  batch2      187
# 464          LAMP1  FUSHeterozygous  Untreated  batch3      186
# 470          LAMP1    FUSHomozygous  Untreated  batch3      112
# 476          LAMP1     FUSRevertant  Untreated  batch3      178
# 482          LAMP1             OPTN  Untreated  batch3      130
# 488          LAMP1             TBK1  Untreated  batch3      153
# 494          LAMP1            TDP43  Untreated  batch3       95
# 500          LAMP1               WT  Untreated  batch3      115
# 465          LAMP1  FUSHeterozygous  Untreated  batch7      233
# 471          LAMP1    FUSHomozygous  Untreated  batch7      262
# 477          LAMP1     FUSRevertant  Untreated  batch7      308
# 483          LAMP1             OPTN  Untreated  batch7      329
# 489          LAMP1             TBK1  Untreated  batch7      310
# 495          LAMP1            TDP43  Untreated  batch7      221
# 501          LAMP1               WT  Untreated  batch7      203
# 466          LAMP1  FUSHeterozygous  Untreated  batch8      294
# 472          LAMP1    FUSHomozygous  Untreated  batch8      300
# 478          LAMP1     FUSRevertant  Untreated  batch8      292
# 484          LAMP1             OPTN  Untreated  batch8      289
# 490          LAMP1             TBK1  Untreated  batch8      385
# 496          LAMP1            TDP43  Untreated  batch8      274
# 502          LAMP1               WT  Untreated  batch8      329
# 467          LAMP1  FUSHeterozygous  Untreated  batch9      110
# 473          LAMP1    FUSHomozygous  Untreated  batch9       90
# 479          LAMP1     FUSRevertant  Untreated  batch9      243
# 485          LAMP1             OPTN  Untreated  batch9      292
# 491          LAMP1             TBK1  Untreated  batch9      231
# 497          LAMP1            TDP43  Untreated  batch9      335
# 503          LAMP1               WT  Untreated  batch9      251
# 504         LSM14A  FUSHeterozygous  Untreated  batch1      476
# 510         LSM14A    FUSHomozygous  Untreated  batch1      486
# 516         LSM14A     FUSRevertant  Untreated  batch1      394
# 522         LSM14A             OPTN  Untreated  batch1      500
# 528         LSM14A             TBK1  Untreated  batch1      500
# 534         LSM14A            TDP43  Untreated  batch1      497
# 540         LSM14A               WT  Untreated  batch1      490
# 505         LSM14A  FUSHeterozygous  Untreated  batch2      487
# 511         LSM14A    FUSHomozygous  Untreated  batch2      491
# 517         LSM14A     FUSRevertant  Untreated  batch2      473
# 523         LSM14A             OPTN  Untreated  batch2      500
# 529         LSM14A             TBK1  Untreated  batch2      480
# 535         LSM14A            TDP43  Untreated  batch2      496
# 541         LSM14A               WT  Untreated  batch2      498
# 506         LSM14A  FUSHeterozygous  Untreated  batch3      446
# 512         LSM14A    FUSHomozygous  Untreated  batch3      496
# 518         LSM14A     FUSRevertant  Untreated  batch3      465
# 524         LSM14A             OPTN  Untreated  batch3      500
# 530         LSM14A             TBK1  Untreated  batch3      489
# 536         LSM14A            TDP43  Untreated  batch3      500
# 542         LSM14A               WT  Untreated  batch3      500
# 507         LSM14A  FUSHeterozygous  Untreated  batch7      482
# 513         LSM14A    FUSHomozygous  Untreated  batch7      488
# 519         LSM14A     FUSRevertant  Untreated  batch7      497
# 525         LSM14A             OPTN  Untreated  batch7      497
# 531         LSM14A             TBK1  Untreated  batch7      498
# 537         LSM14A            TDP43  Untreated  batch7      497
# 543         LSM14A               WT  Untreated  batch7      495
# 508         LSM14A  FUSHeterozygous  Untreated  batch8      500
# 514         LSM14A    FUSHomozygous  Untreated  batch8      500
# 520         LSM14A     FUSRevertant  Untreated  batch8      499
# 526         LSM14A             OPTN  Untreated  batch8      500
# 532         LSM14A             TBK1  Untreated  batch8      499
# 538         LSM14A            TDP43  Untreated  batch8      500
# 544         LSM14A               WT  Untreated  batch8      500
# 509         LSM14A  FUSHeterozygous  Untreated  batch9      500
# 515         LSM14A    FUSHomozygous  Untreated  batch9      500
# 521         LSM14A     FUSRevertant  Untreated  batch9      500
# 527         LSM14A             OPTN  Untreated  batch9      500
# 533         LSM14A             TBK1  Untreated  batch9      500
# 539         LSM14A            TDP43  Untreated  batch9      500
# 545         LSM14A               WT  Untreated  batch9      499
# 546            NCL  FUSHeterozygous  Untreated  batch1      498
# 552            NCL    FUSHomozygous  Untreated  batch1      491
# 558            NCL     FUSRevertant  Untreated  batch1      495
# 564            NCL             OPTN  Untreated  batch1      499
# 570            NCL             TBK1  Untreated  batch1      498
# 576            NCL            TDP43  Untreated  batch1      500
# 582            NCL               WT  Untreated  batch1      500
# 547            NCL  FUSHeterozygous  Untreated  batch2      496
# 553            NCL    FUSHomozygous  Untreated  batch2      481
# 559            NCL     FUSRevertant  Untreated  batch2      458
# 565            NCL             OPTN  Untreated  batch2      498
# 571            NCL             TBK1  Untreated  batch2      459
# 577            NCL            TDP43  Untreated  batch2      427
# 583            NCL               WT  Untreated  batch2      449
# 548            NCL  FUSHeterozygous  Untreated  batch3      473
# 554            NCL    FUSHomozygous  Untreated  batch3      497
# 560            NCL     FUSRevertant  Untreated  batch3      498
# 566            NCL             OPTN  Untreated  batch3      500
# 572            NCL             TBK1  Untreated  batch3      472
# 578            NCL            TDP43  Untreated  batch3      495
# 584            NCL               WT  Untreated  batch3      467
# 549            NCL  FUSHeterozygous  Untreated  batch7      430
# 555            NCL    FUSHomozygous  Untreated  batch7      481
# 561            NCL     FUSRevertant  Untreated  batch7      496
# 567            NCL             OPTN  Untreated  batch7      499
# 573            NCL             TBK1  Untreated  batch7      498
# 579            NCL            TDP43  Untreated  batch7      499
# 585            NCL               WT  Untreated  batch7      499
# 550            NCL  FUSHeterozygous  Untreated  batch8      498
# 556            NCL    FUSHomozygous  Untreated  batch8      499
# 562            NCL     FUSRevertant  Untreated  batch8      487
# 568            NCL             OPTN  Untreated  batch8      500
# 574            NCL             TBK1  Untreated  batch8      497
# 580            NCL            TDP43  Untreated  batch8      497
# 586            NCL               WT  Untreated  batch8      500
# 551            NCL  FUSHeterozygous  Untreated  batch9      496
# 557            NCL    FUSHomozygous  Untreated  batch9      500
# 563            NCL     FUSRevertant  Untreated  batch9      492
# 569            NCL             OPTN  Untreated  batch9      500
# 575            NCL             TBK1  Untreated  batch9      500
# 581            NCL            TDP43  Untreated  batch9      499
# 587            NCL               WT  Untreated  batch9      495
# 588           NEMO  FUSHeterozygous  Untreated  batch1      412
# 594           NEMO    FUSHomozygous  Untreated  batch1      461
# 600           NEMO     FUSRevertant  Untreated  batch1      439
# 606           NEMO             OPTN  Untreated  batch1      488
# 612           NEMO             TBK1  Untreated  batch1      491
# 618           NEMO            TDP43  Untreated  batch1      490
# 624           NEMO               WT  Untreated  batch1      449
# 589           NEMO  FUSHeterozygous  Untreated  batch2      346
# 595           NEMO    FUSHomozygous  Untreated  batch2      482
# 601           NEMO     FUSRevertant  Untreated  batch2      341
# 607           NEMO             OPTN  Untreated  batch2      488
# 613           NEMO             TBK1  Untreated  batch2      492
# 619           NEMO            TDP43  Untreated  batch2      420
# 625           NEMO               WT  Untreated  batch2      483
# 590           NEMO  FUSHeterozygous  Untreated  batch3      476
# 596           NEMO    FUSHomozygous  Untreated  batch3      492
# 602           NEMO     FUSRevertant  Untreated  batch3      472
# 608           NEMO             OPTN  Untreated  batch3      491
# 614           NEMO             TBK1  Untreated  batch3      435
# 620           NEMO            TDP43  Untreated  batch3      479
# 626           NEMO               WT  Untreated  batch3      490
# 591           NEMO  FUSHeterozygous  Untreated  batch7      298
# 597           NEMO    FUSHomozygous  Untreated  batch7      419
# 603           NEMO     FUSRevertant  Untreated  batch7      427
# 609           NEMO             OPTN  Untreated  batch7      477
# 615           NEMO             TBK1  Untreated  batch7      475
# 621           NEMO            TDP43  Untreated  batch7      461
# 627           NEMO               WT  Untreated  batch7      373
# 592           NEMO  FUSHeterozygous  Untreated  batch8      497
# 598           NEMO    FUSHomozygous  Untreated  batch8      479
# 604           NEMO     FUSRevertant  Untreated  batch8      496
# 610           NEMO             OPTN  Untreated  batch8      487
# 616           NEMO             TBK1  Untreated  batch8      493
# 622           NEMO            TDP43  Untreated  batch8      498
# 628           NEMO               WT  Untreated  batch8      497
# 593           NEMO  FUSHeterozygous  Untreated  batch9      498
# 599           NEMO    FUSHomozygous  Untreated  batch9      499
# 605           NEMO     FUSRevertant  Untreated  batch9      495
# 611           NEMO             OPTN  Untreated  batch9      498
# 617           NEMO             TBK1  Untreated  batch9      498
# 623           NEMO            TDP43  Untreated  batch9      499
# 629           NEMO               WT  Untreated  batch9      496
# 630           NONO  FUSHeterozygous  Untreated  batch1      485
# 636           NONO    FUSHomozygous  Untreated  batch1      405
# 642           NONO     FUSRevertant  Untreated  batch1      456
# 648           NONO             OPTN  Untreated  batch1      441
# 654           NONO             TBK1  Untreated  batch1      431
# 660           NONO            TDP43  Untreated  batch1      411
# 666           NONO               WT  Untreated  batch1      401
# 631           NONO  FUSHeterozygous  Untreated  batch2      409
# 637           NONO    FUSHomozygous  Untreated  batch2      498
# 643           NONO     FUSRevertant  Untreated  batch2      479
# 649           NONO             OPTN  Untreated  batch2      495
# 655           NONO             TBK1  Untreated  batch2      490
# 661           NONO            TDP43  Untreated  batch2      454
# 667           NONO               WT  Untreated  batch2      499
# 632           NONO  FUSHeterozygous  Untreated  batch3      366
# 638           NONO    FUSHomozygous  Untreated  batch3      368
# 644           NONO     FUSRevertant  Untreated  batch3      353
# 650           NONO             OPTN  Untreated  batch3      379
# 656           NONO             TBK1  Untreated  batch3      495
# 662           NONO            TDP43  Untreated  batch3      466
# 668           NONO               WT  Untreated  batch3      478
# 633           NONO  FUSHeterozygous  Untreated  batch7      319
# 639           NONO    FUSHomozygous  Untreated  batch7      437
# 645           NONO     FUSRevertant  Untreated  batch7      353
# 651           NONO             OPTN  Untreated  batch7      472
# 657           NONO             TBK1  Untreated  batch7      231
# 663           NONO            TDP43  Untreated  batch7      475
# 669           NONO               WT  Untreated  batch7      351
# 634           NONO  FUSHeterozygous  Untreated  batch8      409
# 640           NONO    FUSHomozygous  Untreated  batch8      484
# 646           NONO     FUSRevertant  Untreated  batch8      448
# 652           NONO             OPTN  Untreated  batch8      454
# 658           NONO             TBK1  Untreated  batch8      496
# 664           NONO            TDP43  Untreated  batch8      450
# 670           NONO               WT  Untreated  batch8      450
# 635           NONO  FUSHeterozygous  Untreated  batch9      481
# 641           NONO    FUSHomozygous  Untreated  batch9      500
# 647           NONO     FUSRevertant  Untreated  batch9      454
# 653           NONO             OPTN  Untreated  batch9      498
# 659           NONO             TBK1  Untreated  batch9      452
# 665           NONO            TDP43  Untreated  batch9      451
# 671           NONO               WT  Untreated  batch9      250
# 672          PEX14  FUSHeterozygous  Untreated  batch1      435
# 678          PEX14    FUSHomozygous  Untreated  batch1      345
# 684          PEX14     FUSRevertant  Untreated  batch1      367
# 690          PEX14             OPTN  Untreated  batch1      420
# 696          PEX14             TBK1  Untreated  batch1      391
# 702          PEX14            TDP43  Untreated  batch1      491
# 708          PEX14               WT  Untreated  batch1      477
# 673          PEX14  FUSHeterozygous  Untreated  batch2      457
# 679          PEX14    FUSHomozygous  Untreated  batch2      469
# 685          PEX14     FUSRevertant  Untreated  batch2      278
# 691          PEX14             OPTN  Untreated  batch2      491
# 697          PEX14             TBK1  Untreated  batch2      493
# 703          PEX14            TDP43  Untreated  batch2      474
# 709          PEX14               WT  Untreated  batch2      486
# 674          PEX14  FUSHeterozygous  Untreated  batch3      452
# 680          PEX14    FUSHomozygous  Untreated  batch3      486
# 686          PEX14     FUSRevertant  Untreated  batch3      367
# 692          PEX14             OPTN  Untreated  batch3      496
# 698          PEX14             TBK1  Untreated  batch3      495
# 704          PEX14            TDP43  Untreated  batch3      493
# 710          PEX14               WT  Untreated  batch3      470
# 675          PEX14  FUSHeterozygous  Untreated  batch7      387
# 681          PEX14    FUSHomozygous  Untreated  batch7      396
# 687          PEX14     FUSRevertant  Untreated  batch7      342
# 693          PEX14             OPTN  Untreated  batch7      490
# 699          PEX14             TBK1  Untreated  batch7      340
# 705          PEX14            TDP43  Untreated  batch7      483
# 711          PEX14               WT  Untreated  batch7      390
# 676          PEX14  FUSHeterozygous  Untreated  batch8      387
# 682          PEX14    FUSHomozygous  Untreated  batch8      487
# 688          PEX14     FUSRevertant  Untreated  batch8      349
# 694          PEX14             OPTN  Untreated  batch8      479
# 700          PEX14             TBK1  Untreated  batch8      493
# 706          PEX14            TDP43  Untreated  batch8      492
# 712          PEX14               WT  Untreated  batch8      493
# 677          PEX14  FUSHeterozygous  Untreated  batch9      164
# 683          PEX14    FUSHomozygous  Untreated  batch9      203
# 689          PEX14     FUSRevertant  Untreated  batch9      245
# 695          PEX14             OPTN  Untreated  batch9      275
# 701          PEX14             TBK1  Untreated  batch9      286
# 707          PEX14            TDP43  Untreated  batch9      320
# 713          PEX14               WT  Untreated  batch9      401
# 714            PML  FUSHeterozygous  Untreated  batch1      437
# 720            PML    FUSHomozygous  Untreated  batch1      446
# 726            PML     FUSRevertant  Untreated  batch1      454
# 732            PML             OPTN  Untreated  batch1      489
# 738            PML             TBK1  Untreated  batch1      489
# 744            PML            TDP43  Untreated  batch1      496
# 750            PML               WT  Untreated  batch1      492
# 715            PML  FUSHeterozygous  Untreated  batch2      434
# 721            PML    FUSHomozygous  Untreated  batch2      455
# 727            PML     FUSRevertant  Untreated  batch2      427
# 733            PML             OPTN  Untreated  batch2      476
# 739            PML             TBK1  Untreated  batch2      492
# 745            PML            TDP43  Untreated  batch2      482
# 751            PML               WT  Untreated  batch2      488
# 716            PML  FUSHeterozygous  Untreated  batch3      373
# 722            PML    FUSHomozygous  Untreated  batch3      406
# 728            PML     FUSRevertant  Untreated  batch3      446
# 734            PML             OPTN  Untreated  batch3      468
# 740            PML             TBK1  Untreated  batch3      445
# 746            PML            TDP43  Untreated  batch3      479
# 752            PML               WT  Untreated  batch3      383
# 717            PML  FUSHeterozygous  Untreated  batch7      489
# 723            PML    FUSHomozygous  Untreated  batch7      498
# 729            PML     FUSRevertant  Untreated  batch7      450
# 735            PML             OPTN  Untreated  batch7      498
# 741            PML             TBK1  Untreated  batch7      481
# 747            PML            TDP43  Untreated  batch7      494
# 753            PML               WT  Untreated  batch7      492
# 718            PML  FUSHeterozygous  Untreated  batch8      460
# 724            PML    FUSHomozygous  Untreated  batch8      490
# 730            PML     FUSRevertant  Untreated  batch8      453
# 736            PML             OPTN  Untreated  batch8      496
# 742            PML             TBK1  Untreated  batch8      421
# ...
# 978         SQSTM1     FUSRevertant  Untreated  batch1      393
# 984         SQSTM1             OPTN  Untreated  batch1      383
# 990         SQSTM1             TBK1  Untreated  batch1      336
# 996         SQSTM1            TDP43  Untreated  batch1      356
# 1002        SQSTM1               WT  Untreated  batch1      393
# 967         SQSTM1  FUSHeterozygous  Untreated  batch2      407
# 973         SQSTM1    FUSHomozygous  Untreated  batch2      386
# 979         SQSTM1     FUSRevertant  Untreated  batch2      392
# 985         SQSTM1             OPTN  Untreated  batch2      444
# 991         SQSTM1             TBK1  Untreated  batch2      439
# 997         SQSTM1            TDP43  Untreated  batch2      324
# 1003        SQSTM1               WT  Untreated  batch2      419
# 968         SQSTM1  FUSHeterozygous  Untreated  batch3      379
# 974         SQSTM1    FUSHomozygous  Untreated  batch3      327
# 980         SQSTM1     FUSRevertant  Untreated  batch3      375
# 986         SQSTM1             OPTN  Untreated  batch3      416
# 992         SQSTM1             TBK1  Untreated  batch3      403
# 998         SQSTM1            TDP43  Untreated  batch3      420
# 1004        SQSTM1               WT  Untreated  batch3      417
# 969         SQSTM1  FUSHeterozygous  Untreated  batch7      304
# 975         SQSTM1    FUSHomozygous  Untreated  batch7      337
# 981         SQSTM1     FUSRevertant  Untreated  batch7      261
# 987         SQSTM1             OPTN  Untreated  batch7      362
# 993         SQSTM1             TBK1  Untreated  batch7      375
# 999         SQSTM1            TDP43  Untreated  batch7      329
# 1005        SQSTM1               WT  Untreated  batch7      366
# 970         SQSTM1  FUSHeterozygous  Untreated  batch8      306
# 976         SQSTM1    FUSHomozygous  Untreated  batch8      339
# 982         SQSTM1     FUSRevertant  Untreated  batch8      334
# 988         SQSTM1             OPTN  Untreated  batch8      326
# 994         SQSTM1             TBK1  Untreated  batch8      356
# 1000        SQSTM1            TDP43  Untreated  batch8      305
# 1006        SQSTM1               WT  Untreated  batch8      310
# 971         SQSTM1  FUSHeterozygous  Untreated  batch9      348
# 977         SQSTM1    FUSHomozygous  Untreated  batch9      313
# 983         SQSTM1     FUSRevertant  Untreated  batch9      356
# 989         SQSTM1             OPTN  Untreated  batch9      286
# 995         SQSTM1             TBK1  Untreated  batch9      265
# 1001        SQSTM1            TDP43  Untreated  batch9      339
# 1007        SQSTM1               WT  Untreated  batch9      307
# 1008         TDP43  FUSHeterozygous  Untreated  batch1      437
# 1014         TDP43    FUSHomozygous  Untreated  batch1      414
# 1020         TDP43     FUSRevertant  Untreated  batch1      449
# 1026         TDP43             OPTN  Untreated  batch1      442
# 1032         TDP43             TBK1  Untreated  batch1      384
# 1038         TDP43            TDP43  Untreated  batch1      459
# 1044         TDP43               WT  Untreated  batch1      476
# 1009         TDP43  FUSHeterozygous  Untreated  batch2      466
# 1015         TDP43    FUSHomozygous  Untreated  batch2      471
# 1021         TDP43     FUSRevertant  Untreated  batch2      424
# 1027         TDP43             OPTN  Untreated  batch2      474
# 1033         TDP43             TBK1  Untreated  batch2      470
# 1039         TDP43            TDP43  Untreated  batch2      465
# 1045         TDP43               WT  Untreated  batch2      483
# 1010         TDP43  FUSHeterozygous  Untreated  batch3      426
# 1016         TDP43    FUSHomozygous  Untreated  batch3      423
# 1022         TDP43     FUSRevertant  Untreated  batch3      427
# 1028         TDP43             OPTN  Untreated  batch3      473
# 1034         TDP43             TBK1  Untreated  batch3      468
# 1040         TDP43            TDP43  Untreated  batch3      463
# 1046         TDP43               WT  Untreated  batch3      470
# 1011         TDP43  FUSHeterozygous  Untreated  batch7      405
# 1017         TDP43    FUSHomozygous  Untreated  batch7      474
# 1023         TDP43     FUSRevertant  Untreated  batch7      284
# 1029         TDP43             OPTN  Untreated  batch7      488
# 1035         TDP43             TBK1  Untreated  batch7      480
# 1041         TDP43            TDP43  Untreated  batch7      480
# 1047         TDP43               WT  Untreated  batch7      469
# 1012         TDP43  FUSHeterozygous  Untreated  batch8      470
# 1018         TDP43    FUSHomozygous  Untreated  batch8      479
# 1024         TDP43     FUSRevertant  Untreated  batch8      347
# 1030         TDP43             OPTN  Untreated  batch8      473
# 1036         TDP43             TBK1  Untreated  batch8      482
# 1042         TDP43            TDP43  Untreated  batch8      490
# 1048         TDP43               WT  Untreated  batch8      492
# 1013         TDP43  FUSHeterozygous  Untreated  batch9      167
# 1019         TDP43    FUSHomozygous  Untreated  batch9      333
# 1025         TDP43     FUSRevertant  Untreated  batch9      200
# 1031         TDP43             OPTN  Untreated  batch9      318
# 1037         TDP43             TBK1  Untreated  batch9      256
# 1043         TDP43            TDP43  Untreated  batch9      404
# 1049         TDP43               WT  Untreated  batch9      439
# 1050          TIA1  FUSHeterozygous  Untreated  batch1      452
# 1056          TIA1    FUSHomozygous  Untreated  batch1      427
# 1062          TIA1     FUSRevertant  Untreated  batch1      432
# 1068          TIA1             OPTN  Untreated  batch1      465
# 1074          TIA1             TBK1  Untreated  batch1      451
# 1080          TIA1            TDP43  Untreated  batch1      453
# 1086          TIA1               WT  Untreated  batch1      405
# 1051          TIA1  FUSHeterozygous  Untreated  batch2      377
# 1057          TIA1    FUSHomozygous  Untreated  batch2      246
# 1063          TIA1     FUSRevertant  Untreated  batch2      361
# 1069          TIA1             OPTN  Untreated  batch2      435
# 1075          TIA1             TBK1  Untreated  batch2      442
# 1081          TIA1            TDP43  Untreated  batch2      444
# 1087          TIA1               WT  Untreated  batch2      434
# 1052          TIA1  FUSHeterozygous  Untreated  batch3      438
# 1058          TIA1    FUSHomozygous  Untreated  batch3      445
# 1064          TIA1     FUSRevertant  Untreated  batch3      443
# 1070          TIA1             OPTN  Untreated  batch3      456
# 1076          TIA1             TBK1  Untreated  batch3      446
# 1082          TIA1            TDP43  Untreated  batch3      420
# 1088          TIA1               WT  Untreated  batch3      439
# 1053          TIA1  FUSHeterozygous  Untreated  batch7      397
# 1059          TIA1    FUSHomozygous  Untreated  batch7      407
# 1065          TIA1     FUSRevertant  Untreated  batch7      457
# 1071          TIA1             OPTN  Untreated  batch7      436
# 1077          TIA1             TBK1  Untreated  batch7      341
# 1083          TIA1            TDP43  Untreated  batch7      341
# 1089          TIA1               WT  Untreated  batch7      309
# 1054          TIA1  FUSHeterozygous  Untreated  batch8      414
# 1060          TIA1    FUSHomozygous  Untreated  batch8      431
# 1066          TIA1     FUSRevertant  Untreated  batch8      473
# 1072          TIA1             OPTN  Untreated  batch8      444
# 1078          TIA1             TBK1  Untreated  batch8      410
# 1084          TIA1            TDP43  Untreated  batch8      399
# 1090          TIA1               WT  Untreated  batch8      374
# 1055          TIA1  FUSHeterozygous  Untreated  batch9      229
# 1061          TIA1    FUSHomozygous  Untreated  batch9      256
# 1067          TIA1     FUSRevertant  Untreated  batch9      277
# 1073          TIA1             OPTN  Untreated  batch9      418
# 1079          TIA1             TBK1  Untreated  batch9      278
# 1085          TIA1            TDP43  Untreated  batch9      336
# 1091          TIA1               WT  Untreated  batch9      286
# 1092        TOMM20  FUSHeterozygous  Untreated  batch1      446
# 1098        TOMM20    FUSHomozygous  Untreated  batch1      423
# 1104        TOMM20     FUSRevertant  Untreated  batch1      445
# 1110        TOMM20             OPTN  Untreated  batch1      468
# 1116        TOMM20             TBK1  Untreated  batch1      477
# 1122        TOMM20            TDP43  Untreated  batch1      474
# 1128        TOMM20               WT  Untreated  batch1      455
# 1093        TOMM20  FUSHeterozygous  Untreated  batch2      413
# 1099        TOMM20    FUSHomozygous  Untreated  batch2      265
# 1105        TOMM20     FUSRevertant  Untreated  batch2      387
# 1111        TOMM20             OPTN  Untreated  batch2      469
# 1117        TOMM20             TBK1  Untreated  batch2      455
# 1123        TOMM20            TDP43  Untreated  batch2      445
# 1129        TOMM20               WT  Untreated  batch2      440
# 1094        TOMM20  FUSHeterozygous  Untreated  batch3      459
# 1100        TOMM20    FUSHomozygous  Untreated  batch3      471
# 1106        TOMM20     FUSRevertant  Untreated  batch3      460
# 1112        TOMM20             OPTN  Untreated  batch3      463
# 1118        TOMM20             TBK1  Untreated  batch3      462
# 1124        TOMM20            TDP43  Untreated  batch3      470
# 1130        TOMM20               WT  Untreated  batch3      476
# 1095        TOMM20  FUSHeterozygous  Untreated  batch7      489
# 1101        TOMM20    FUSHomozygous  Untreated  batch7      491
# 1107        TOMM20     FUSRevertant  Untreated  batch7      488
# 1113        TOMM20             OPTN  Untreated  batch7      497
# 1119        TOMM20             TBK1  Untreated  batch7      485
# 1125        TOMM20            TDP43  Untreated  batch7      407
# 1131        TOMM20               WT  Untreated  batch7      495
# 1096        TOMM20  FUSHeterozygous  Untreated  batch8      412
# 1102        TOMM20    FUSHomozygous  Untreated  batch8      469
# 1108        TOMM20     FUSRevertant  Untreated  batch8      451
# 1114        TOMM20             OPTN  Untreated  batch8      494
# 1120        TOMM20             TBK1  Untreated  batch8      497
# 1126        TOMM20            TDP43  Untreated  batch8      494
# 1132        TOMM20               WT  Untreated  batch8      493
# 1097        TOMM20  FUSHeterozygous  Untreated  batch9      311
# 1103        TOMM20    FUSHomozygous  Untreated  batch9      465
# 1109        TOMM20     FUSRevertant  Untreated  batch9      305
# 1115        TOMM20             OPTN  Untreated  batch9      445
# 1121        TOMM20             TBK1  Untreated  batch9      443
# 1127        TOMM20            TDP43  Untreated  batch9      476
# 1133        TOMM20               WT  Untreated  batch9      497
# 1134       Tubulin  FUSHeterozygous  Untreated  batch1      279
# 1140       Tubulin    FUSHomozygous  Untreated  batch1      248
# 1146       Tubulin     FUSRevertant  Untreated  batch1      362
# 1152       Tubulin             OPTN  Untreated  batch1      390
# 1158       Tubulin             TBK1  Untreated  batch1      344
# 1164       Tubulin            TDP43  Untreated  batch1      410
# 1170       Tubulin               WT  Untreated  batch1      410
# 1135       Tubulin  FUSHeterozygous  Untreated  batch2      414
# 1141       Tubulin    FUSHomozygous  Untreated  batch2      404
# 1147       Tubulin     FUSRevertant  Untreated  batch2      425
# 1153       Tubulin             OPTN  Untreated  batch2      461
# 1159       Tubulin             TBK1  Untreated  batch2      462
# 1165       Tubulin            TDP43  Untreated  batch2      334
# 1171       Tubulin               WT  Untreated  batch2      455
# 1136       Tubulin  FUSHeterozygous  Untreated  batch3      380
# 1142       Tubulin    FUSHomozygous  Untreated  batch3      294
# 1148       Tubulin     FUSRevertant  Untreated  batch3      377
# 1154       Tubulin             OPTN  Untreated  batch3      429
# 1160       Tubulin             TBK1  Untreated  batch3      418
# 1166       Tubulin            TDP43  Untreated  batch3      433
# 1172       Tubulin               WT  Untreated  batch3      417
# 1137       Tubulin  FUSHeterozygous  Untreated  batch7      391
# 1143       Tubulin    FUSHomozygous  Untreated  batch7      483
# 1149       Tubulin     FUSRevertant  Untreated  batch7      339
# 1155       Tubulin             OPTN  Untreated  batch7      383
# 1161       Tubulin             TBK1  Untreated  batch7      404
# 1167       Tubulin            TDP43  Untreated  batch7      365
# 1173       Tubulin               WT  Untreated  batch7      478
# 1138       Tubulin  FUSHeterozygous  Untreated  batch8      422
# 1144       Tubulin    FUSHomozygous  Untreated  batch8      477
# 1150       Tubulin     FUSRevertant  Untreated  batch8      478
# 1156       Tubulin             OPTN  Untreated  batch8      428
# 1162       Tubulin             TBK1  Untreated  batch8      446
# 1168       Tubulin            TDP43  Untreated  batch8      406
# 1174       Tubulin               WT  Untreated  batch8      441
# 1139       Tubulin  FUSHeterozygous  Untreated  batch9      490
# 1145       Tubulin    FUSHomozygous  Untreated  batch9      436
# 1151       Tubulin     FUSRevertant  Untreated  batch9      480
# 1157       Tubulin             OPTN  Untreated  batch9      459
# 1163       Tubulin             TBK1  Untreated  batch9      389
# 1169       Tubulin            TDP43  Untreated  batch9      410
# 1175       Tubulin               WT  Untreated  batch9      454
# 1176   mitotracker  FUSHeterozygous  Untreated  batch1      417
# 1182   mitotracker    FUSHomozygous  Untreated  batch1      375
# 1188   mitotracker     FUSRevertant  Untreated  batch1      340
# 1194   mitotracker             OPTN  Untreated  batch1      479
# 1200   mitotracker             TBK1  Untreated  batch1      454
# 1206   mitotracker            TDP43  Untreated  batch1      468
# 1212   mitotracker               WT  Untreated  batch1      449
# 1177   mitotracker  FUSHeterozygous  Untreated  batch2      436
# 1183   mitotracker    FUSHomozygous  Untreated  batch2      298
# 1189   mitotracker     FUSRevertant  Untreated  batch2      398
# 1195   mitotracker             OPTN  Untreated  batch2      495
# 1201   mitotracker             TBK1  Untreated  batch2      476
# 1207   mitotracker            TDP43  Untreated  batch2      484
# 1213   mitotracker               WT  Untreated  batch2      481
# 1178   mitotracker  FUSHeterozygous  Untreated  batch3      462
# 1184   mitotracker    FUSHomozygous  Untreated  batch3      475
# 1190   mitotracker     FUSRevertant  Untreated  batch3      452
# 1196   mitotracker             OPTN  Untreated  batch3      497
# 1202   mitotracker             TBK1  Untreated  batch3      494
# 1208   mitotracker            TDP43  Untreated  batch3      487
# 1214   mitotracker               WT  Untreated  batch3      496
# 1179   mitotracker  FUSHeterozygous  Untreated  batch7      487
# 1185   mitotracker    FUSHomozygous  Untreated  batch7      493
# 1191   mitotracker     FUSRevertant  Untreated  batch7      484
# 1197   mitotracker             OPTN  Untreated  batch7      487
# 1203   mitotracker             TBK1  Untreated  batch7      476
# 1209   mitotracker            TDP43  Untreated  batch7      389
# 1215   mitotracker               WT  Untreated  batch7      482
# 1180   mitotracker  FUSHeterozygous  Untreated  batch8      485
# 1186   mitotracker    FUSHomozygous  Untreated  batch8      494
# 1192   mitotracker     FUSRevertant  Untreated  batch8      480
# 1198   mitotracker             OPTN  Untreated  batch8      490
# 1204   mitotracker             TBK1  Untreated  batch8      486
# 1210   mitotracker            TDP43  Untreated  batch8      491
# 1216   mitotracker               WT  Untreated  batch8      478
# 1181   mitotracker  FUSHeterozygous  Untreated  batch9      334
# 1187   mitotracker    FUSHomozygous  Untreated  batch9      455
# 1193   mitotracker     FUSRevertant  Untreated  batch9      300
# 1199   mitotracker             OPTN  Untreated  batch9      437
# 1205   mitotracker             TBK1  Untreated  batch9      433
# 1211   mitotracker            TDP43  Untreated  batch9      466
# 1217   mitotracker               WT  Untreated  batch9      497

# %%
show_filtered_out(neuronsDay8_new_counts, 80)
# Out:
# Filtered out samples with less than 80 sites:
#     marker        cell_line  condition   batch  n_sites
# 255    FUS  FUSHeterozygous  Untreated  batch7        3
# 261    FUS    FUSHomozygous  Untreated  batch7        5
# 267    FUS     FUSRevertant  Untreated  batch7        5
# 273    FUS             OPTN  Untreated  batch7        1
# 279    FUS             TBK1  Untreated  batch7        5
# 285    FUS            TDP43  Untreated  batch7        3
# 291    FUS               WT  Untreated  batch7        4

# %%
pd.reset_option("display.max_rows")
